# %% [markdown]
# ## 【基于飞桨实现乒乓球时序动作定位大赛 ：B榜第15名方案】
# 参考：https://aistudio.baidu.com/aistudio/projectdetail/3434130?channelType=0&channel=0
# ### 赛题介绍
#
# 在众多大规模视频分析情景中，从冗长未经修剪的视频中定位并识别短时间内发生的人体动作成为一个备受关注的课题。当前针对人体动作检测的解决方案在大规模视频集上难以奏效，高效地处理大规模视频数据仍然是计算机视觉领域一个充满挑战的任务。其核心问题可以分为两部分，一是动作识别算法的复杂度仍旧较高，二是缺少能够产生更少视频提案数量的方法（更加关注短时动作本身的提案）。
#
# 这里所指的视频动作提案是指一些包含特定动作的候选视频片段。为了能够适应大规模视频分析任务，时序动作提案应该尽可能满足下面两个需求：
# （1）更高的处理效率，例如可以设计出使时序视频片段编码和打分更高效的机制；
# （2）更强的判别性能，例如可以准确定位动作发生的时间区间。
#
# 本次比赛旨在激发更多的开发者和研究人员关注并参与有关视频动作定位的研究，创建性能更出色的动作定位模型。
#
# ### 数据集介绍
#
#
# ![jupyter](BMN.png)
#
#
#
# 本次比赛的数据集包含了19-21赛季兵乓球国际比赛（世界杯、世锦赛、亚锦赛，奥运会）和国内比赛（全运会，乒超联赛）中标准单机位高清转播画面的特征信息，共包含912条视频特征文件，每个视频时长在0～6分钟不等，特征维度为2048，以pkl格式保存。我们对特征数据中面朝镜头的运动员的回合内挥拍动作进行了标注，单个动作时常在0～2秒不等，训练数据为729条标注视频，A测数据为91条视频，B测数据为92条视频，训练数据标签以json格式给出。
#
# ### 数据集预处理
#
#
# 本方案采用PaddleVideo中的BMN模型。BMN模型是百度自研，2019年ActivityNet夺冠方案，为视频动作定位问题中proposal的生成提供高效的解决方案，在PaddlePaddle上首次开源。此模型引入边界匹配(Boundary-Matching, BM)机制来评估proposal的置信度，按照proposal开始边界的位置及其长度将所有可能存在的proposal组合成一个二维的BM置信度图，图中每个点的数值代表其所对应的proposal的置信度分数。网络由三个模块组成，基础模块作为主干网络处理输入的特征序列，TEM模块预测每一个时序位置属于动作开始、动作结束的概率，PEM模块生成BM置信度图。
#
# 本赛题中的数据包含912条ppTSM抽取的视频特征，特征保存为pkl格式，文件名对应视频名称，读取pkl之后以(num_of_frames, 2048)向量形式代表单个视频特征。其中num_of_frames是不固定的，同时数量也比较大，所以pkl的文件并不能直接用于训练。同时由于乒乓球每个动作时间非常短，为了可以让模型更好的识别动作，所以这里将数据进行分割。
#
#
# 1. 首先解压数据集
# 执行以下命令解压数据集，解压之后将压缩包删除，保证项目空间小于100G。否则项目会被终止。

# %%
# %cd /home/aistudio/data/
#!tar xf data122998/Features_competition_train.tar.gz
#!tar xf data123004/Features_competition_test_A.tar.gz
#!cp data122998/label_cls14_train.json .
#!rm -rf data12*
# !tar xf Features_competition_test_B.tar.gz
# Out:
# /home/aistudio/data
# tar: Features_competition_test_B.tar.gz：无法 open: 没有那个文件或目录
# tar: Error is not recoverable: exiting now

# %%
import os
import sys
import json
import random
import pickle
import numpy as np

# %% [markdown]
# 2. 解压好数据之后，首先对label标注文件进行分割。本项目在Baseline的基础上参照[FootballAciton](https://github.com/PaddlePaddle/PaddleVideo/blob/application/FootballAction/datasets/script/get_instance_for_bmn.py)的划分方法，进一步优化训练数据。

# %%
source_path = "/home/aistudio/data/label_cls14_train.json"

# %%
import json
with open('/home/aistudio/data/label_cls14_train.json') as f:
    data = json.load(f)
f.close()

# %%
#按照9:1划分训练 测试集
l=len(data['gts'])
l=int(l*0.1)
val = {'gts': data['gts'][0:l], 'fps': 25}
jsonString = json.dumps(val, indent=4, ensure_ascii=False)
jsonFile = open('/home/aistudio/data/label_cls14_val.json', 'w')
jsonFile.write(jsonString)
jsonFile.close()

train = {'gts': data['gts'][l:], 'fps': 25}
jsonString = json.dumps(train, indent=4, ensure_ascii=False)
jsonFile = open('/home/aistudio/data/label_cls14_train.json', 'w')
jsonFile.write(jsonString)
jsonFile.close()

# %%
"""
get instance for bmn
使用winds=4的滑窗，将所有子窗口的长度之和小于winds的进行合并
合并后，父窗口代表bmn训练数据，子窗口代表tsn训练数据
"""
import os
import sys
import json
import random
import pickle
import numpy as np
import math

# for table tennis
bmn_window = 4
dataset = "/home/aistudio/data"
feat_dir = dataset + '/Features_competition_train'
out_dir = dataset + '/Input_for_bmn'
label_files = {
    'train': 'label_cls14_train.json',
    'validation': 'label_cls14_val.json'
}

global fps


def gen_gts_for_bmn(gts_data):
    """
    @param, gts_data, original gts for action detection
    @return, gts_bmn, output gts dict for bmn
    """
    fps = gts_data['fps']
    gts_bmn = {'fps': fps, 'gts': []}
    for sub_item in gts_data['gts']:
        url = sub_item['url']

        max_length = sub_item['total_frames']

        gts_bmn['gts'].append({
            'url': url,
            'total_frames': max_length,
            'root_actions': []
        })
        sub_actions = sub_item['actions']
        # 跳过没有动作的片段
        if len(sub_actions) == 0:
            continue
        # duration > bmn_window， 动作持续时间大于bmn_windows，直接删除
        for idx, sub_action in enumerate(sub_actions):
            if sub_action['end_id'] - sub_action['start_id'] > bmn_window:
                sub_actions.pop(idx)

        # 【滑动窗口，把每一个视频里的动作片段提取出来】
        root_actions = [sub_actions[0]]
        # before_id, 前一动作的最后一帧
        # after_id, 后一动作的第一帧
        before_id = 0
        for idx in range(1, len(sub_actions)):
            cur_action = sub_actions[idx]
            duration = (cur_action['end_id'] - root_actions[0]['start_id'])
            if duration > bmn_window:  # windows只能包住一个动作就包，包不住就包多个
                after_id = cur_action['start_id']
                gts_bmn['gts'][-1]['root_actions'].append({
                    'before_id':
                    before_id,
                    'after_id':
                    after_id,
                    'actions':
                    root_actions
                })
                before_id = root_actions[-1]['end_id']  #更新滑窗
                root_actions = [cur_action]
            else:
                root_actions.append(cur_action)
            if idx == len(sub_actions) - 1:
                after_id = max_length
                gts_bmn['gts'][-1]['root_actions'].append({
                    'before_id':
                    before_id,
                    'after_id':
                    after_id,
                    'actions':
                    root_actions
                })

    return gts_bmn


def combile_gts(gts_bmn, gts_process, mode):
    """
    1、bmn_window 范围内只有一个动作，只取一个目标框
    2、bmn_window 范围内有多个动作，取三个目标框(第一个动作、最后一个动作、所有动作)
    """
    global fps
    fps = gts_process['fps']
    duration_second = bmn_window * 1.0
    duration_frame = bmn_window * fps
    feature_frame = duration_frame
    for item in gts_process['gts']:
        url = item['url']
        basename = os.path.basename(url).split('.')[0]
        root_actions = item['root_actions']
        # 把每一个视频里的动作片段提取出来
        for root_action in root_actions:
            segments = []
            # all actions
            segments.append({
                'actions': root_action['actions'],
                'before_id': root_action['before_id'],
                'after_id': root_action['after_id']
            })
            if len(root_action['actions']) > 1:  #如果有多个动作，则第一个动作和最后一个动作，额外添加一次
                # first action
                segments.append({
                    'actions': [root_action['actions'][0]],
                    'before_id':
                    root_action['before_id'],
                    'after_id':
                    root_action['actions'][1]['start_id']
                })
                # last action
                segments.append({
                    'actions': [root_action['actions'][-1]],
                    'before_id':
                    root_action['actions'][-2]['end_id'],
                    'after_id':
                    root_action['after_id']
                })

            # 把动作片段处理成window size大小，以适配BMN输入
            for segment in segments:
                before_id = segment['before_id']
                after_id = segment['after_id']
                actions = segment['actions']
                # before_id到after_id太长了，从里面取window_size帧，要先确定一个起始点，然后动作都要包住
                box0 = max(actions[-1]['end_id'] - bmn_window,
                           before_id)  #确定起始点
                box1 = min(actions[0]['start_id'],
                           after_id - bmn_window)  #确实起始点
                if box0 <= box1:  # 一次检查
                    if int(box0) - int(box1) == 0:
                        cur_start = box0
                    else:
                        box0 = math.ceil(box0)
                        box1 = int(box1)
                        cur_start = random.randint(box0, box1)
                    cur_end = cur_start + bmn_window
                    cur_start = round(cur_start, 2)
                    cur_end = round(cur_end, 2)
                    name = '{}_{}_{}'.format(basename, cur_start, cur_end)
                    annotations = []
                    for action in actions:
                        label = str(1.0 * action['label_ids'][0])
                        label_name = action['label_names'][0]
                        seg0 = 1.0 * round((action['start_id'] - cur_start),
                                           2)  #存储的是到开始位置(时间: s)的距离
                        seg1 = 1.0 * round((action['end_id'] - cur_start), 2)
                        annotations.append({
                            'segment': [seg0, seg1],
                            'label': label,
                            'label_name': label_name
                        })
                    gts_bmn[name] = {
                        'duration_second': duration_second,
                        'duration_frame': duration_frame,
                        'feature_frame': feature_frame,
                        'subset': mode,
                        'annotations': annotations
                    }

    return gts_bmn


def save_feature_to_numpy(gts_bmn, folder):
    global fps
    print('save feature for bmn ...')
    if not os.path.exists(folder):
        os.mkdir(folder)
    process_gts_bmn = {}
    miss = 0
    for item, value in gts_bmn.items():
        # split to rsplit 针对文件命名修改
        basename, start_id, end_id = item.rsplit('_', 2)
        if not basename in process_gts_bmn:
            process_gts_bmn[basename] = []
        process_gts_bmn[basename].append({
            'name': item,
            'start': float(start_id),
            'end': float(end_id)
        })
    for item, values in process_gts_bmn.items():
        feat_path = os.path.join(feat_dir, item + '.pkl')
        feature_video = pickle.load(open(feat_path, 'rb'))['image_feature']
        for value in values:
            save_cut_name = os.path.join(folder, value['name'])
            a, b, c = save_cut_name.rsplit('_', 2)
            if float(b) > 360:
                print(b)
            start_frame = round(value['start'] * fps)
            end_frame = round(value['end'] * fps)
            if end_frame > len(feature_video):
                miss += 1
                continue
            feature_cut = [
                feature_video[i] for i in range(start_frame, end_frame)
            ]
            np_feature_cut = np.array(feature_cut, dtype=np.float32)
            np.save(save_cut_name, np_feature_cut)

    print('miss number (broken sample):', miss)


if __name__ == "__main__":
    if not os.path.exists(out_dir):
        os.mkdir(out_dir)
    gts_bmn = {}
    for item, value in label_files.items():
        label_file = os.path.join(dataset, value)
        gts_data = json.load(open(label_file, 'rb'))
        gts_process = gen_gts_for_bmn(gts_data)
        gts_bmn = combile_gts(gts_bmn, gts_process, item)

    with open(out_dir + '/label.json', 'w', encoding='utf-8') as f:
        data = json.dumps(gts_bmn, indent=4, ensure_ascii=False)
        f.write(data)

    save_feature_to_numpy(gts_bmn, out_dir + '/feature')
# Out:
# save feature for bmn ...
# miss number (broken sample): 108

# %%
import copy
import json
import re
import os

url = '/home/aistudio/data/Input_for_bmn/feature/'
directory = os.fsencode(url)
count = 0
target_set = []

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    target_name = filename.split('.npy')[0]
    target_set.append(target_name)
    count += 1
print('Feature size:', len(target_set))

with open('/home/aistudio/data/Input_for_bmn/label.json') as f:
    data = json.load(f)

delet_set = []
for key in data.keys():
    if not key in target_set:
        delet_set.append(key)

print('(Label) Original size:', len(data))
print('(Label) Deleted size:', len(delet_set))

for item in delet_set:
    data.pop(item, None)

print('(Label) Fixed size:', len(data))

jsonString = json.dumps(data, indent=4, ensure_ascii=False)
jsonFile = open('/home/aistudio/data/Input_for_bmn/label_fixed.json', 'w')
jsonFile.write(jsonString)
jsonFile.close()
# Out:
# Feature size: 19720
# (Label) Original size: 19828
# (Label) Deleted size: 108
# (Label) Fixed size: 19720

# %% [markdown]
# 执行完毕后，在data/Input_for_bmn/目录中生成了新的标注文件label_fixed.json。下面开始分割训练集和测试集的数据。
#
# 3. 执行以下脚本，分割训练集。

# %%
# !rm /home/aistudio/data/Features_competition_train/*.pkl

# %% [markdown]
# 执行后在data/Features_competition_train/npy目录下生成了训练用的numpy数据。

# %%
import os
import os.path as osp
import glob
import pickle
import paddle

import numpy as np

file_list = glob.glob("/home/aistudio/data/Features_competition_test_B/*.pkl")

max_frames = 9000

npy_path = ("/home/aistudio/data/Features_competition_test_B/npy/")
if not osp.exists(npy_path):
    os.makedirs(npy_path)

for f in file_list:
    video_feat = pickle.load(open(f, 'rb'))
    tensor = paddle.to_tensor(video_feat['image_feature'])
    pad_num = 9000 - tensor.shape[0]
    pad1d = paddle.nn.Pad1D([0, pad_num])
    tensor = paddle.transpose(tensor, [1, 0])
    tensor = paddle.unsqueeze(tensor, axis=0)
    tensor = pad1d(tensor)
    tensor = paddle.squeeze(tensor, axis=0)
    tensor = paddle.transpose(tensor, [1, 0])

    sps = paddle.split(tensor, num_or_sections=90, axis=0)
    for i, s in enumerate(sps):
        file_name = osp.join(npy_path, f.split('/')[-1].split('.')[0] + f"_{i}.npy")
        np.save(file_name, s.detach().numpy())
    pass
# Out:
# W0303 09:39:52.295142   152 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0303 09:39:52.301980   152 device_context.cc:465] device: 0, cuDNN Version: 7.6.

# %% [markdown]
# ### 训练模型
#
# 数据集分割好之后，可以开始训练模型，使用以下命令进行模型训练。首先需要安装PaddleVideo的依赖包。

# %%
# 从Github上下载PaddleVideo代码

#%cd ~/work/
# 从Github上下载PaddleVideo代码
#!git clone https://github.com/PaddlePaddle/PaddleVideo.git

# %%
#%cd /home/aistudio/PaddleVideo/
#!pip install -r requirements.txt
# %cd ~/work/PaddleVideo/
# 配置PaddleVideo环境
#!python3.7 -m pip install --upgrade pip
# !python3.7 -m pip install --upgrade -r requirements.txt
# Out:
# /home/aistudio/work/PaddleVideo
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://github.com/LDOUBLEV/AutoLog (from -r requirements.txt (line 22))
#   Cloning https://github.com/LDOUBLEV/AutoLog to /tmp/pip-req-build-2pe1edf7
#   Running command git clone -q https://github.com/LDOUBLEV/AutoLog /tmp/pip-req-build-2pe1edf7
#   Resolved https://github.com/LDOUBLEV/AutoLog to commit 42ce5ebc74abdd780bbd398cdf9b341c3caef240
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.19.5)
# Collecting numpy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/50/46/292cff79f5b30151b027400efdb3f740ea03271b600751b6696cf550c10d/numpy-1.21.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 4.5 MB/s
# Requirement already satisfied: pandas in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.1.5)
# Collecting pandas
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3e/0c/23764c4635dcb0a784a787498d56847b90ebf974e65f4ab4053a5d97b1a5/pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 2.0 MB/s
# Requirement already satisfied: tqdm in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (4.27.0)
# Collecting tqdm
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/81/1c/93a2b77b97cdba15a59c3d2d03e53d3292158d1106d37f579069abd90ece/tqdm-4.63.0-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 352 kB/s
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (5.1.2)
# Collecting PyYAML>=5.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/eb/5f/6e6fe6904e1a9c67bc2ca5629a69e7a5a0b17f079da838bab98a1e548b25/PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 3.0 MB/s
# Collecting opencv-python==4.2.0.32
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/34/a3/403dbaef909fee9f9f6a8eaff51d44085a14e5bb1a1ff7257117d744986a/opencv_python-4.2.0.32-cp37-cp37m-manylinux1_x86_64.whl (28.2 MB)
#      |████████████████████████████████| 28.2 MB 3.3 MB/s
# Collecting decord==0.4.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c0/0c/7d99cfcde7b85f80c9ea9b0b19441339ad3cef59ee7fa5386598db714efe/decord-0.4.2-py2.py3-none-manylinux1_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 4.7 MB/s
# Collecting av==8.0.3
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/ff/bacde7314c646a2bd2f240034809a10cc3f8b096751284d0828640fff3dd/av-8.0.3-cp37-cp37m-manylinux2010_x86_64.whl (37.2 MB)
#      |████████████████████████████████| 37.2 MB 9.8 MB/s
# Requirement already satisfied: scipy==1.6.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (1.6.3)
# Collecting ffmpeg-python==0.2.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d7/0c/56be52741f75bad4dc6555991fabd2e07b432d333da82c11ad701123888a/ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting scikit-image
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d2/d9/d16d4cbb4840e0fb3bd329b49184d240b82b649e1bd579489394fbc85c81/scikit_image-0.19.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 700 kB/s
# Requirement already satisfied: matplotlib in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (2.2.3)
# Collecting matplotlib
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bb/eb/fb97c7c75755edf10128ae3f06ba15ffb97b852740ef9311f20113f018eb/matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 2.9 MB/s
# Requirement already satisfied: paddlenlp in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 12)) (2.1.1)
# Collecting paddlenlp
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2b/ec/927e81ad9c349980b1076b2721adcc3c1bbb8f0f432af21995692350c05a/paddlenlp-2.2.4-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.8 MB/s
# Collecting lmdb
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4d/cf/3230b1c9b0bec406abb85a9332ba5805bdd03a1d24025c6bbcfb8ed71539/lmdb-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (298 kB)
#      |████████████████████████████████| 298 kB 6.3 MB/s
# Requirement already satisfied: moviepy in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (1.0.1)
# Collecting moviepy
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/18/54/01a8c4e35c75ca9724d19a7e4de9dc23f0ceb8769102c7de056113af61c3/moviepy-1.0.3.tar.gz (388 kB)
#      |████████████████████████████████| 388 kB 4.7 MB/s
#   Preparing metadata (setup.py) ... done
# Collecting SimpleITK
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ad/ce/75d95eab0bc815f478b594add92090ff664e5cbc75ab9d8e2ffbaae1dc91/SimpleITK-2.1.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 3.1 MB/s
# Collecting paddledet
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bb/27/eb6714bdc12e73544617b1b4b3481ae70bec644a722bcbedd5743531db97/paddledet-2.3.0-py3-none-any.whl (589 kB)
#      |████████████████████████████████| 589 kB 3.6 MB/s
# Requirement already satisfied: et_xmlfile in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 17)) (1.0.1)
# Collecting et_xmlfile
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting lap
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bf/64/d9fb6a75b15e783952b2fec6970f033462e67db32dc43dfbb404c14e91c2/lap-0.4.0.tar.gz (1.5 MB)
#      |████████████████████████████████| 1.5 MB 3.2 MB/s
#   Preparing metadata (setup.py) ... done
# Collecting motmetrics
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9c/28/9c3bc8e2a87f4c9e7b04ab72856ec7f9895a66681a65973ffaf9562ef879/motmetrics-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 3.8 MB/s
# Collecting xmltodict
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: openpyxl in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from -r requirements.txt (line 21)) (3.0.5)
# Collecting openpyxl
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1c/a6/8ce4d2ef2c29be3235c08bb00e0b81e29d38ebc47d82b17af681bf662b74/openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 3.9 MB/s
# Collecting einops
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/6f/fb90ccb765bc521d363f605aaddb4c4169891d431b9c6fed0451c5a533f5/einops-0.4.0-py3-none-any.whl (28 kB)
# Collecting fvcore==0.1.5.post20210630
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c9/67/1a386384816c6577a3d858a79f7ff697db176b71f5cb06ded0f2a3caeb8a/fvcore-0.1.5.post20210630.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 15.4 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from ffmpeg-python==0.2.0->-r requirements.txt (line 9)) (0.18.0)
# Collecting yacs>=0.1.6
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from fvcore==0.1.5.post20210630->-r requirements.txt (line 24)) (1.1.0)
# Requirement already satisfied: Pillow in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from fvcore==0.1.5.post20210630->-r requirements.txt (line 24)) (8.2.0)
# Requirement already satisfied: tabulate in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from fvcore==0.1.5.post20210630->-r requirements.txt (line 24)) (0.8.3)
# Collecting iopath>=0.1.7
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/af/20/65dd9bd25a1eb7fa35b5ae38d289126af065f8a0c1f6a90564f4bff0f89d/iopath-0.1.9-py3-none-any.whl (27 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 2)) (2019.3)
# Requirement already satisfied: networkx>=2.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-image->-r requirements.txt (line 10)) (2.4)
# Collecting tifffile>=2019.7.26
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d8/38/85ae5ed77598ca90558c17a2f79ddaba33173b31cf8d8f545d34d9134f0d/tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 2.4 MB/s
# Collecting PyWavelets>=1.1.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a1/9c/564511b6e1c4e1d835ed2d146670436036960d09339a8fa2921fe42dad08/PyWavelets-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 3.3 MB/s
# Requirement already satisfied: imageio>=2.4.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-image->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-image->-r requirements.txt (line 10)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (1.1.0)
# Collecting fonttools>=4.22.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1d/46/65a58d7b92905e2767000b3f6eb1d0301e9ed7d459d14461075c1db63349/fonttools-4.29.1-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 3.0 MB/s
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (3.0.7)
# Requirement already satisfied: multiprocess in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (0.70.11.1)
# Requirement already satisfied: h5py in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (2.9.0)
# Requirement already satisfied: seqeval in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (1.2.2)
# Requirement already satisfied: colorama in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (0.4.4)
# Requirement already satisfied: jieba in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (0.42.1)
# Requirement already satisfied: colorlog in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddlenlp->-r requirements.txt (line 12)) (4.1.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from moviepy->-r requirements.txt (line 14)) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from moviepy->-r requirements.txt (line 14)) (2.24.0)
# Requirement already satisfied: proglog<=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from moviepy->-r requirements.txt (line 14)) (0.1.9)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from moviepy->-r requirements.txt (line 14)) (0.3.0)
# Requirement already satisfied: Cython in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddledet->-r requirements.txt (line 16)) (0.29)
# Collecting typeguard
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9a/bb/d43e5c75054e53efce310e79d63df0ac3f25e34c926be5dffb7d283fb2a8/typeguard-2.13.3-py3-none-any.whl (17 kB)
# Collecting shapely
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9d/4d/4b0d86ed737acb29c5e627a91449470a9fb914f32640db3f1cb7ba5bc19e/Shapely-1.8.1.post1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 4.1 MB/s
# Collecting pycocotools
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/75/5c/ac61ea715d7a89ecc31c090753bde28810238225ca8b71778dfe3e6a68bc/pycocotools-2.0.4.tar.gz (106 kB)
#      |████████████████████████████████| 106 kB 4.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting terminaltables
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: sklearn in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddledet->-r requirements.txt (line 16)) (0.0)
# Requirement already satisfied: setuptools>=42.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddledet->-r requirements.txt (line 16)) (56.2.0)
# Collecting cython-bbox
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/fa/b9/fc7d60e8c3b29cc0ff24a3bb3c4b7457e10b7610fbb2893741b623487b34/cython_bbox-0.1.3.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 795 kB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: visualdl>=2.1.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from paddledet->-r requirements.txt (line 16)) (2.2.0)
# Collecting flake8-import-order
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ab/52/cf2d6e2c505644ca06de2f6f3546f1e4f2b7be34246c9e0757c6048868f9/flake8_import_order-0.18.1-py2.py3-none-any.whl (15 kB)
# Collecting pytest
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/38/93/c7c0bd1e932b287fb948eb9ce5a3d6307c9fc619db1e199f8c8bc5dad95f/pytest-7.0.1-py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 3.0 MB/s
# Requirement already satisfied: flake8 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from motmetrics->-r requirements.txt (line 19)) (4.0.1)
# Collecting pytest-benchmark
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2c/60/423a63fb190a0483d049786a121bd3dfd7d93bb5ff1bb5b5cd13e5df99a7/pytest_benchmark-3.4.1-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 15.3 MB/s
# Collecting GPUtil
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from auto-log==1.2.0->-r requirements.txt (line 22)) (5.7.2)
# Requirement already satisfied: pynvml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from auto-log==1.2.0->-r requirements.txt (line 22)) (8.0.4)
# Collecting distro
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e1/54/d08d1ad53788515392bec14d2d6e8c410bffdc127780a9a4aa8e6854d502/distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: wheel in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from auto-log==1.2.0->-r requirements.txt (line 22)) (0.36.2)
# Requirement already satisfied: six in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 11)) (1.16.0)
# Collecting portalocker
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f1/4e/1030afbf2e64e676e968bbbc82014ce4ddf1cc1ed0b492585958768cf79a/portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (2019.9.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (1.25.6)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from requests<3.0,>=2.8.1->moviepy->-r requirements.txt (line 14)) (2.8)
# Requirement already satisfied: shellcheck-py in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (0.7.1.1)
# Requirement already satisfied: pre-commit in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.21.0)
# Requirement already satisfied: protobuf>=3.11.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (3.14.0)
# Requirement already satisfied: Flask-Babel>=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: bce-python-sdk in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (0.8.53)
# Requirement already satisfied: flask>=1.1.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8->motmetrics->-r requirements.txt (line 19)) (2.8.0)
# Requirement already satisfied: importlib-metadata<4.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8->motmetrics->-r requirements.txt (line 19)) (4.2.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8->motmetrics->-r requirements.txt (line 19)) (2.4.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flake8->motmetrics->-r requirements.txt (line 19)) (0.6.1)
# Requirement already satisfied: dill>=0.3.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from multiprocess->paddlenlp->-r requirements.txt (line 12)) (0.3.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pytest->motmetrics->-r requirements.txt (line 19)) (0.13.1)
# Collecting py>=1.8.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f6/f0/10642828a8dfb741e5f3fbaac830550a518a775c7fff6f04a007259b0548/py-1.11.0-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 2.8 MB/s
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pytest->motmetrics->-r requirements.txt (line 19)) (21.4.0)
# Collecting iniconfig
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9b/dd/b3c12c6d707058fa947864b67f0c4e0c39ef8610988d7baea9578f3c48f3/iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting tomli>=1.0.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting py-cpuinfo
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e6/ba/77120e44cbe9719152415b97d5bfb29f4053ee987d6cb63f55ce7d50fadc/py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 2.8 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.21.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from seqeval->paddlenlp->-r requirements.txt (line 12)) (0.24.2)
# Requirement already satisfied: click>=5.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.1.1->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (7.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.1.1->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (2.11.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.1.1->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from flask>=1.1.1->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (0.16.0)
# Requirement already satisfied: Babel>=2.3 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Flask-Babel>=1.0.0->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from importlib-metadata<4.3->flake8->motmetrics->-r requirements.txt (line 19)) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from importlib-metadata<4.3->flake8->motmetrics->-r requirements.txt (line 19)) (3.7.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->paddlenlp->-r requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from scikit-learn>=0.21.3->seqeval->paddlenlp->-r requirements.txt (line 12)) (0.14.1)
# Requirement already satisfied: pycryptodome>=3.8.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from bce-python-sdk->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (3.9.9)
# Requirement already satisfied: identify>=1.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.4.10)
# Requirement already satisfied: nodeenv>=0.11.1 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.3.4)
# Requirement already satisfied: aspy.yaml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: cfgv>=2.0.0 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (2.0.1)
# Requirement already satisfied: toml in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (0.10.0)
# Requirement already satisfied: virtualenv>=15.2 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from pre-commit->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (16.7.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages (from Jinja2>=2.10.1->flask>=1.1.1->visualdl>=2.1.0->paddledet->-r requirements.txt (line 16)) (2.0.1)
# Building wheels for collected packages: fvcore, moviepy, lap, auto-log, cython-bbox, GPUtil, pycocotools, py-cpuinfo
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20210630-py3-none-any.whl size=60608 sha256=cca70e25d83af0e9679a27f971059dcb9f6f8543cd3bf2949cd977634a5c9d27
#   Stored in directory: /home/aistudio/.cache/pip/wheels/82/0a/8f/4e4d488bb41a361d319226089cc4ae8453e713423ea5cb7a4a
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110726 sha256=05b545fb5e4d976c25e262feff612851e1bf4115b5db67bf3dad26d2e2b9919c
#   Stored in directory: /home/aistudio/.cache/pip/wheels/19/c5/56/7bd7ec94257958e82bbcf8d4eb85a5acfae1b5eb3f4f64128a
#   Building wheel for lap (setup.py) ... done
#   Created wheel for lap: filename=lap-0.4.0-cp37-cp37m-linux_x86_64.whl size=1593864 sha256=d45d5b899febea727c5f7ce4fa38820115d260d33f3c4343be3ae50dc49f1b9f
#   Stored in directory: /home/aistudio/.cache/pip/wheels/5c/d0/d2/e331d17a999666b1e2eb99743cfa1742629f9d26c55c657001
#   Building wheel for auto-log (setup.py) ... done
#   Created wheel for auto-log: filename=auto_log-1.2.0-py3-none-any.whl size=10312 sha256=4ada86f9c6fc58c700de5d1427cc75b97e6ca334029ea6e58bfe3f1b582781cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gfdsdiic/wheels/0d/91/6f/9bfb086285373a75e632c547307c90568aef806d1ff71f7b09
#   Building wheel for cython-bbox (setup.py) ... done
#   Created wheel for cython-bbox: filename=cython_bbox-0.1.3-cp37-cp37m-linux_x86_64.whl size=61621 sha256=b12151fbd05627c4eb67efc143721daa5768516a48076dd8e2c6d0c308d0ca71
#   Stored in directory: /home/aistudio/.cache/pip/wheels/3e/b3/6a/aae8832326545645e65d643a2aaf223ffa3a7d01e1a1bae01b
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7410 sha256=bf9b68e39fce03cce839c2318072c78774c8fdd249a72f6491e19536bd61d770
#   Stored in directory: /home/aistudio/.cache/pip/wheels/8c/49/cb/e4c32bdc101f068f9f0201d1c99f4141a1faeb73b639029b7c
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.4-cp37-cp37m-linux_x86_64.whl size=273789 sha256=5ff30478558acbd058f8e6d158c1a084aa1a27fb6a8f9e3773246d90a0c84ae1
#   Stored in directory: /home/aistudio/.cache/pip/wheels/c0/01/5f/670dfd20204fc9cc6bf843db4e014acb998f411922e3abc49f
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22245 sha256=5edd2641d6425450f39d792809b1a716532ac60e1f89efe88d590f17aa634cf0
#   Stored in directory: /home/aistudio/.cache/pip/wheels/88/c7/d0/6309c7cc9929894c11fe8e516c3e2a0d0a53ee4e198eac48b7
# Successfully built fvcore moviepy lap auto-log cython-bbox GPUtil pycocotools py-cpuinfo
# Installing collected packages: tomli, PyYAML, py, numpy, iniconfig, pytest, py-cpuinfo, fonttools, xmltodict, tqdm, pytest-benchmark, portalocker, pandas, matplotlib, flake8-import-order, et-xmlfile, yacs, typeguard, tifffile, terminaltables, shapely, PyWavelets, pycocotools, openpyxl, opencv-python, motmetrics, lap, iopath, GPUtil, distro, cython-bbox, SimpleITK, scikit-image, paddlenlp, paddledet, moviepy, lmdb, fvcore, ffmpeg-python, einops, decord, av, auto-log
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.1.2
#     Uninstalling PyYAML-5.1.2:
#       Successfully uninstalled PyYAML-5.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.27.0
#     Uninstalling tqdm-4.27.0:
#       Successfully uninstalled tqdm-4.27.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 2.2.3
#     Uninstalling matplotlib-2.2.3:
#       Successfully uninstalled matplotlib-2.2.3
#   Attempting uninstall: et-xmlfile
#     Found existing installation: et-xmlfile 1.0.1
#     Uninstalling et-xmlfile-1.0.1:
#       Successfully uninstalled et-xmlfile-1.0.1
#   Attempting uninstall: openpyxl
#     Found existing installation: openpyxl 3.0.5
#     Uninstalling openpyxl-3.0.5:
#       Successfully uninstalled openpyxl-3.0.5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.1.26
#     Uninstalling opencv-python-4.1.1.26:
#       Successfully uninstalled opencv-python-4.1.1.26
#   Attempting uninstall: paddlenlp
#     Found existing installation: paddlenlp 2.1.1
#     Uninstalling paddlenlp-2.1.1:
#       Successfully uninstalled paddlenlp-2.1.1
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 1.0.1
#     Uninstalling moviepy-1.0.1:
#       Successfully uninstalled moviepy-1.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# parl 1.4.1 requires pyzmq==18.1.1, but you have pyzmq 22.3.0 which is incompatible.
# paddlefsl 1.0.0 requires numpy~=1.19.2, but you have numpy 1.21.5 which is incompatible.
# paddlefsl 1.0.0 requires tqdm~=4.27.0, but you have tqdm 4.63.0 which is incompatible.
# blackhole 1.0.1 requires numpy<=1.19.5, but you have numpy 1.21.5 which is incompatible.
# blackhole 1.0.1 requires pandas<=1.1.5,>=0.24.0, but you have pandas 1.3.5 which is incompatible.
# Successfully installed GPUtil-1.4.0 PyWavelets-1.2.0 PyYAML-6.0 SimpleITK-2.1.1 auto-log-1.2.0 av-8.0.3 cython-bbox-0.1.3 decord-0.4.2 distro-1.7.0 einops-0.4.0 et-xmlfile-1.1.0 ffmpeg-python-0.2.0 flake8-import-order-0.18.1 fonttools-4.29.1 fvcore-0.1.5.post20210630 iniconfig-1.1.1 iopath-0.1.9 lap-0.4.0 lmdb-1.3.0 matplotlib-3.5.1 motmetrics-1.2.0 moviepy-1.0.3 numpy-1.21.5 opencv-python-4.2.0.32 openpyxl-3.0.9 paddledet-2.3.0 paddlenlp-2.2.4 pandas-1.3.5 portalocker-2.4.0 py-1.11.0 py-cpuinfo-8.0.0 pycocotools-2.0.4 pytest-7.0.1 pytest-benchmark-3.4.1 scikit-image-0.19.2 shapely-1.8.1.post1 terminaltables-3.1.10 tifffile-2021.11.2 tomli-2.0.1 tqdm-4.63.0 typeguard-2.13.3 xmltodict-0.12.0 yacs-0.1.8
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/conda/envs/python35-paddle120-env/bin/python3.7 -m pip install --upgrade pip' command.

# %% [markdown]
# 开始训练模型。
# 在/home/aistudio/work/PaddleVideo/applications/TableTennis/configs/bmn_tabletennis.yaml文件中更改文件的路径
# ```
# DATASET:                                            #DATASET field
#   batch_size: 16                                 #single card bacth size
#   test_batch_size: 1
#   num_workers: 8
#   train:
#     format: "BMNDataset"
#     file_path: "/home/aistudio/data/Input_for_bmn/label_fixed.json"
#     subset: "train"
#   valid:
#     format: "BMNDataset"
#     file_path: "/home/aistudio/data/Input_for_bmn/label_fixed.json"
#     subset: "validation"
#   test:
#     format: "BMNDataset"
#     test_mode: True
#     file_path: "/home/aistudio/work/BMN/Input_for_bmn/label_fixed.json"
#     subset: "validation"
# ```
# ```
# PIPELINE:                                           #PIPELINE field
#   train:                                            #Mandotary, indicate the pipeline to deal with the training data
#     load_feat:
#       name: "LoadFeat"
#       feat_path: "/home/aistudio/data/Input_for_bmn/feature"
#     transform:                                      #Mandotary, image transfrom operator
#       - GetMatchMap:
#           tscale: 100
#       - GetVideoLabel:
#           tscale: 100
#           dscale: 100
#
#   valid:                                            #Mandotary, indicate the pipeline to deal with the training data
#     load_feat:
#       name: "LoadFeat"
#       feat_path: "/home/aistudio/data/Input_for_bmn/feature"
#     transform:                                      #Mandotary, image transfrom operator
#       - GetMatchMap:
#           tscale: 100
#       - GetVideoLabel:
#           tscale: 100
#           dscale: 100
#
# ```
# 因为bmn_window = 4
# 配置文件中的 tscale和dscale都改为100

# %%
# %cd /home/aistudio/work/PaddleVideo/
#!python main.py -c  configs/localization/bmn.yaml
# !python -B main.py  --validate -c  applications/TableTennis/configs/bmn_tabletennis.yaml
# Out:
# /home/aistudio/work/PaddleVideo
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddlenlp/transformers/funnel/modeling.py:30: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable
# [02/28 00:58:20] DALI is not installed, you can improve performance if use DALI
# [02/28 00:58:21] DATASET :
# [02/28 00:58:21]     batch_size : 16
# [02/28 00:58:21]     num_workers : 8
# [02/28 00:58:21]     test :
# [02/28 00:58:21]         file_path : /home/aistudio/work/BMN/Input_for_bmn/label_fixed.json
# [02/28 00:58:21]         format : BMNDataset
# [02/28 00:58:21]         subset : validation
# [02/28 00:58:21]         test_mode : True
# [02/28 00:58:21]     test_batch_size : 1
# [02/28 00:58:21]     train :
# [02/28 00:58:21]         file_path : /home/aistudio/data/Input_for_bmn/label_fixed.json
# [02/28 00:58:21]         format : BMNDataset
# [02/28 00:58:21]         subset : train
# [02/28 00:58:21]     valid :
# [02/28 00:58:21]         file_path : /home/aistudio/data/Input_for_bmn/label_fixed.json
# [02/28 00:58:21]         format : BMNDataset
# [02/28 00:58:21]         subset : validation
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] INFERENCE :
# [02/28 00:58:21]     dscale : 100
# [02/28 00:58:21]     feat_dim : 2048
# [02/28 00:58:21]     name : BMN_Inference_helper
# [02/28 00:58:21]     result_path : data/bmn/BMN_INFERENCE_results
# [02/28 00:58:21]     tscale : 100
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] METRIC :
# [02/28 00:58:21]     dscale : 100
# [02/28 00:58:21]     file_path : /home/aistudio/work/BMN/Input_for_bmn/label_fixed.json
# [02/28 00:58:21]     ground_truth_filename : /home/aistudio/work/BMN/Input_for_bmn/label_gts.json
# [02/28 00:58:21]     name : BMNMetric
# [02/28 00:58:21]     output_path : data/bmn/BMN_Test_output
# [02/28 00:58:21]     result_path : data/bmn/BMN_Test_results
# [02/28 00:58:21]     subset : validation
# [02/28 00:58:21]     tscale : 100
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] MODEL :
# [02/28 00:58:21]     backbone :
# [02/28 00:58:21]         dscale : 100
# [02/28 00:58:21]         feat_dim : 2048
# [02/28 00:58:21]         name : BMN
# [02/28 00:58:21]         num_sample : 32
# [02/28 00:58:21]         num_sample_perbin : 3
# [02/28 00:58:21]         prop_boundary_ratio : 0.5
# [02/28 00:58:21]         tscale : 100
# [02/28 00:58:21]     framework : BMNLocalizer
# [02/28 00:58:21]     loss :
# [02/28 00:58:21]         dscale : 100
# [02/28 00:58:21]         name : BMNLoss
# [02/28 00:58:21]         tscale : 100
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] OPTIMIZER :
# [02/28 00:58:21]     learning_rate :
# [02/28 00:58:21]         boundaries : [4200]
# [02/28 00:58:21]         iter_step : True
# [02/28 00:58:21]         name : CustomPiecewiseDecay
# [02/28 00:58:21]         values : [0.001, 0.0001]
# [02/28 00:58:21]     name : Adam
# [02/28 00:58:21]     weight_decay :
# [02/28 00:58:21]         name : L2
# [02/28 00:58:21]         value : 0.0001
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] PIPELINE :
# [02/28 00:58:21]     test :
# [02/28 00:58:21]         load_feat :
# [02/28 00:58:21]             feat_path : /home/aistudio/work/BMN/Input_for_bmn/feature
# [02/28 00:58:21]             name : LoadFeat
# [02/28 00:58:21]         transform :
# [02/28 00:58:21]             GetMatchMap :
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21]             GetVideoLabel :
# [02/28 00:58:21]                 dscale : 100
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21]     train :
# [02/28 00:58:21]         load_feat :
# [02/28 00:58:21]             feat_path : /home/aistudio/data/Input_for_bmn/feature
# [02/28 00:58:21]             name : LoadFeat
# [02/28 00:58:21]         transform :
# [02/28 00:58:21]             GetMatchMap :
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21]             GetVideoLabel :
# [02/28 00:58:21]                 dscale : 100
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21]     valid :
# [02/28 00:58:21]         load_feat :
# [02/28 00:58:21]             feat_path : /home/aistudio/data/Input_for_bmn/feature
# [02/28 00:58:21]             name : LoadFeat
# [02/28 00:58:21]         transform :
# [02/28 00:58:21]             GetMatchMap :
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21]             GetVideoLabel :
# [02/28 00:58:21]                 dscale : 100
# [02/28 00:58:21]                 tscale : 100
# [02/28 00:58:21] ------------------------------------------------------------
# [02/28 00:58:21] epochs : 30
# [02/28 00:58:21] log_level : INFO
# [02/28 00:58:21] model_name : BMN
# [02/28 00:58:21] resume_from :
# W0228 00:58:21.100800  1922 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0228 00:58:21.105274  1922 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# [02/28 00:58:28] train subset video numbers: 17851
# [02/28 00:58:28] validation subset video numbers: 1869
# [02/28 00:58:32] epoch:[  1/30 ] train step:0    loss: 2.58325 lr: 0.001000 batch_cost: 4.55066 sec, reader_cost: 1.93006 sec, ips: 3.51597 instance/sec.
# [02/28 00:58:57] epoch:[  1/30 ] train step:10   loss: 2.44589 lr: 0.001000 batch_cost: 2.45546 sec, reader_cost: 0.00034 sec, ips: 6.51610 instance/sec.
# [02/28 00:59:22] epoch:[  1/30 ] train step:20   loss: 2.06193 lr: 0.001000 batch_cost: 2.45676 sec, reader_cost: 0.00030 sec, ips: 6.51264 instance/sec.
# [02/28 00:59:46] epoch:[  1/30 ] train step:30   loss: 1.98015 lr: 0.001000 batch_cost: 2.47940 sec, reader_cost: 0.00032 sec, ips: 6.45319 instance/sec.
# [02/28 01:00:11] epoch:[  1/30 ] train step:40   loss: 1.67199 lr: 0.001000 batch_cost: 2.47873 sec, reader_cost: 0.00035 sec, ips: 6.45492 instance/sec.
# [02/28 01:00:36] epoch:[  1/30 ] train step:50   loss: 1.71767 lr: 0.001000 batch_cost: 2.50010 sec, reader_cost: 0.00030 sec, ips: 6.39974 instance/sec.
# [02/28 01:01:01] epoch:[  1/30 ] train step:60   loss: 1.46225 lr: 0.001000 batch_cost: 2.50288 sec, reader_cost: 0.00149 sec, ips: 6.39265 instance/sec.
# [02/28 01:01:26] epoch:[  1/30 ] train step:70   loss: 1.84335 lr: 0.001000 batch_cost: 2.49942 sec, reader_cost: 0.00029 sec, ips: 6.40149 instance/sec.
# [02/28 01:01:51] epoch:[  1/30 ] train step:80   loss: 1.38272 lr: 0.001000 batch_cost: 2.50145 sec, reader_cost: 0.00028 sec, ips: 6.39628 instance/sec.
# [02/28 01:02:16] epoch:[  1/30 ] train step:90   loss: 1.36718 lr: 0.001000 batch_cost: 2.50252 sec, reader_cost: 0.00028 sec, ips: 6.39355 instance/sec.
# [02/28 01:02:41] epoch:[  1/30 ] train step:100  loss: 1.46092 lr: 0.001000 batch_cost: 2.50117 sec, reader_cost: 0.00029 sec, ips: 6.39701 instance/sec.
# [02/28 01:03:06] epoch:[  1/30 ] train step:110  loss: 1.41057 lr: 0.001000 batch_cost: 2.50306 sec, reader_cost: 0.00033 sec, ips: 6.39217 instance/sec.
# [02/28 01:03:31] epoch:[  1/30 ] train step:120  loss: 1.39837 lr: 0.001000 batch_cost: 2.50189 sec, reader_cost: 0.00028 sec, ips: 6.39516 instance/sec.
# [02/28 01:03:56] epoch:[  1/30 ] train step:130  loss: 1.26076 lr: 0.001000 batch_cost: 2.50225 sec, reader_cost: 0.00028 sec, ips: 6.39424 instance/sec.
# [02/28 01:04:21] epoch:[  1/30 ] train step:140  loss: 1.18404 lr: 0.001000 batch_cost: 2.51317 sec, reader_cost: 0.00029 sec, ips: 6.36647 instance/sec.
# [02/28 01:04:46] epoch:[  1/30 ] train step:150  loss: 1.29136 lr: 0.001000 batch_cost: 2.50294 sec, reader_cost: 0.00029 sec, ips: 6.39249 instance/sec.
# [02/28 01:05:11] epoch:[  1/30 ] train step:160  loss: 1.25135 lr: 0.001000 batch_cost: 2.50186 sec, reader_cost: 0.00032 sec, ips: 6.39524 instance/sec.
# [02/28 01:05:36] epoch:[  1/30 ] train step:170  loss: 1.53254 lr: 0.001000 batch_cost: 2.50209 sec, reader_cost: 0.00029 sec, ips: 6.39465 instance/sec.
# [02/28 01:06:01] epoch:[  1/30 ] train step:180  loss: 1.34544 lr: 0.001000 batch_cost: 2.50259 sec, reader_cost: 0.00034 sec, ips: 6.39337 instance/sec.
# [02/28 01:06:26] epoch:[  1/30 ] train step:190  loss: 1.11570 lr: 0.001000 batch_cost: 2.50133 sec, reader_cost: 0.00029 sec, ips: 6.39660 instance/sec.
# [02/28 01:06:51] epoch:[  1/30 ] train step:200  loss: 1.28283 lr: 0.001000 batch_cost: 2.50226 sec, reader_cost: 0.00028 sec, ips: 6.39423 instance/sec.
# [02/28 01:07:17] epoch:[  1/30 ] train step:210  loss: 1.38971 lr: 0.001000 batch_cost: 2.50221 sec, reader_cost: 0.00028 sec, ips: 6.39434 instance/sec.
# [02/28 01:07:42] epoch:[  1/30 ] train step:220  loss: 1.17605 lr: 0.001000 batch_cost: 2.50164 sec, reader_cost: 0.00029 sec, ips: 6.39580 instance/sec.
# [02/28 01:08:07] epoch:[  1/30 ] train step:230  loss: 1.33116 lr: 0.001000 batch_cost: 2.50212 sec, reader_cost: 0.00036 sec, ips: 6.39459 instance/sec.
# [02/28 01:08:32] epoch:[  1/30 ] train step:240  loss: 1.06706 lr: 0.001000 batch_cost: 2.50056 sec, reader_cost: 0.00030 sec, ips: 6.39857 instance/sec.
# [02/28 01:08:57] epoch:[  1/30 ] train step:250  loss: 1.14749 lr: 0.001000 batch_cost: 2.50184 sec, reader_cost: 0.00029 sec, ips: 6.39529 instance/sec.
# [02/28 01:09:22] epoch:[  1/30 ] train step:260  loss: 1.25837 lr: 0.001000 batch_cost: 2.50294 sec, reader_cost: 0.00033 sec, ips: 6.39248 instance/sec.
# [02/28 01:09:47] epoch:[  1/30 ] train step:270  loss: 1.08034 lr: 0.001000 batch_cost: 2.51056 sec, reader_cost: 0.00131 sec, ips: 6.37309 instance/sec.
# [02/28 01:10:12] epoch:[  1/30 ] train step:280  loss: 1.06401 lr: 0.001000 batch_cost: 2.50259 sec, reader_cost: 0.00035 sec, ips: 6.39337 instance/sec.
# [02/28 01:10:37] epoch:[  1/30 ] train step:290  loss: 1.27950 lr: 0.001000 batch_cost: 2.50269 sec, reader_cost: 0.00034 sec, ips: 6.39313 instance/sec.
# [02/28 01:11:02] epoch:[  1/30 ] train step:300  loss: 1.17231 lr: 0.001000 batch_cost: 2.49981 sec, reader_cost: 0.00029 sec, ips: 6.40049 instance/sec.
# [02/28 01:11:27] epoch:[  1/30 ] train step:310  loss: 1.22603 lr: 0.001000 batch_cost: 2.50103 sec, reader_cost: 0.00028 sec, ips: 6.39737 instance/sec.
# [02/28 01:11:52] epoch:[  1/30 ] train step:320  loss: 1.47600 lr: 0.001000 batch_cost: 2.50123 sec, reader_cost: 0.00034 sec, ips: 6.39685 instance/sec.
# [02/28 01:12:17] epoch:[  1/30 ] train step:330  loss: 1.35850 lr: 0.001000 batch_cost: 2.50124 sec, reader_cost: 0.00028 sec, ips: 6.39684 instance/sec.
# [02/28 01:12:42] epoch:[  1/30 ] train step:340  loss: 1.83541 lr: 0.001000 batch_cost: 2.51796 sec, reader_cost: 0.00028 sec, ips: 6.35436 instance/sec.
# [02/28 01:13:07] epoch:[  1/30 ] train step:350  loss: 1.25606 lr: 0.001000 batch_cost: 2.50652 sec, reader_cost: 0.00031 sec, ips: 6.38335 instance/sec.
# [02/28 01:13:32] epoch:[  1/30 ] train step:360  loss: 1.33881 lr: 0.001000 batch_cost: 2.50098 sec, reader_cost: 0.00032 sec, ips: 6.39749 instance/sec.
# [02/28 01:13:57] epoch:[  1/30 ] train step:370  loss: 1.36148 lr: 0.001000 batch_cost: 2.50241 sec, reader_cost: 0.00027 sec, ips: 6.39383 instance/sec.
# [02/28 01:14:22] epoch:[  1/30 ] train step:380  loss: 1.15051 lr: 0.001000 batch_cost: 2.50171 sec, reader_cost: 0.00029 sec, ips: 6.39562 instance/sec.
# [02/28 01:14:47] epoch:[  1/30 ] train step:390  loss: 1.27085 lr: 0.001000 batch_cost: 2.50108 sec, reader_cost: 0.00028 sec, ips: 6.39724 instance/sec.
# [02/28 01:15:12] epoch:[  1/30 ] train step:400  loss: 1.18208 lr: 0.001000 batch_cost: 2.50560 sec, reader_cost: 0.00029 sec, ips: 6.38570 instance/sec.
# [02/28 01:15:37] epoch:[  1/30 ] train step:410  loss: 1.49507 lr: 0.001000 batch_cost: 2.50188 sec, reader_cost: 0.00029 sec, ips: 6.39519 instance/sec.
# [02/28 01:16:02] epoch:[  1/30 ] train step:420  loss: 2.09831 lr: 0.001000 batch_cost: 2.50204 sec, reader_cost: 0.00028 sec, ips: 6.39479 instance/sec.
# [02/28 01:16:27] epoch:[  1/30 ] train step:430  loss: 1.18926 lr: 0.001000 batch_cost: 2.50266 sec, reader_cost: 0.00038 sec, ips: 6.39321 instance/sec.
# [02/28 01:16:52] epoch:[  1/30 ] train step:440  loss: 1.32637 lr: 0.001000 batch_cost: 2.50317 sec, reader_cost: 0.00029 sec, ips: 6.39189 instance/sec.
# [02/28 01:17:17] epoch:[  1/30 ] train step:450  loss: 1.16147 lr: 0.001000 batch_cost: 2.50182 sec, reader_cost: 0.00029 sec, ips: 6.39536 instance/sec.
# [02/28 01:17:42] epoch:[  1/30 ] train step:460  loss: 1.11350 lr: 0.001000 batch_cost: 2.50191 sec, reader_cost: 0.00030 sec, ips: 6.39511 instance/sec.
# [02/28 01:18:07] epoch:[  1/30 ] train step:470  loss: 1.09494 lr: 0.001000 batch_cost: 2.50194 sec, reader_cost: 0.00030 sec, ips: 6.39505 instance/sec.
# [02/28 01:18:32] epoch:[  1/30 ] train step:480  loss: 1.06817 lr: 0.001000 batch_cost: 2.50459 sec, reader_cost: 0.00140 sec, ips: 6.38827 instance/sec.
# [02/28 01:18:58] epoch:[  1/30 ] train step:490  loss: 1.92443 lr: 0.001000 batch_cost: 2.50477 sec, reader_cost: 0.00142 sec, ips: 6.38781 instance/sec.
# [02/28 01:19:23] epoch:[  1/30 ] train step:500  loss: 1.14334 lr: 0.001000 batch_cost: 2.50153 sec, reader_cost: 0.00032 sec, ips: 6.39610 instance/sec.
# [02/28 01:19:48] epoch:[  1/30 ] train step:510  loss: 1.22197 lr: 0.001000 batch_cost: 2.50253 sec, reader_cost: 0.00033 sec, ips: 6.39353 instance/sec.
# [02/28 01:20:13] epoch:[  1/30 ] train step:520  loss: 1.18930 lr: 0.001000 batch_cost: 2.50146 sec, reader_cost: 0.00029 sec, ips: 6.39627 instance/sec.
# [02/28 01:20:38] epoch:[  1/30 ] train step:530  loss: 1.17441 lr: 0.001000 batch_cost: 2.50144 sec, reader_cost: 0.00033 sec, ips: 6.39631 instance/sec.
# [02/28 01:21:03] epoch:[  1/30 ] train step:540  loss: 1.15288 lr: 0.001000 batch_cost: 2.50198 sec, reader_cost: 0.00034 sec, ips: 6.39494 instance/sec.
# [02/28 01:21:28] epoch:[  1/30 ] train step:550  loss: 1.01935 lr: 0.001000 batch_cost: 2.50152 sec, reader_cost: 0.00032 sec, ips: 6.39612 instance/sec.
# [02/28 01:21:53] epoch:[  1/30 ] train step:560  loss: 1.21524 lr: 0.001000 batch_cost: 2.50189 sec, reader_cost: 0.00030 sec, ips: 6.39518 instance/sec.
# [02/28 01:22:18] epoch:[  1/30 ] train step:570  loss: 1.05964 lr: 0.001000 batch_cost: 2.50234 sec, reader_cost: 0.00033 sec, ips: 6.39402 instance/sec.
# [02/28 01:22:43] epoch:[  1/30 ] train step:580  loss: 0.94196 lr: 0.001000 batch_cost: 2.50181 sec, reader_cost: 0.00034 sec, ips: 6.39536 instance/sec.
# [02/28 01:23:08] epoch:[  1/30 ] train step:590  loss: 1.12426 lr: 0.001000 batch_cost: 2.50292 sec, reader_cost: 0.00030 sec, ips: 6.39254 instance/sec.
# [02/28 01:23:33] epoch:[  1/30 ] train step:600  loss: 1.47752 lr: 0.001000 batch_cost: 2.50328 sec, reader_cost: 0.00030 sec, ips: 6.39162 instance/sec.
# [02/28 01:23:58] epoch:[  1/30 ] train step:610  loss: 1.09474 lr: 0.001000 batch_cost: 2.50059 sec, reader_cost: 0.00030 sec, ips: 6.39850 instance/sec.
# [02/28 01:24:23] epoch:[  1/30 ] train step:620  loss: 1.00831 lr: 0.001000 batch_cost: 2.50742 sec, reader_cost: 0.00029 sec, ips: 6.38107 instance/sec.
# [02/28 01:24:48] epoch:[  1/30 ] train step:630  loss: 1.18996 lr: 0.001000 batch_cost: 2.50202 sec, reader_cost: 0.00028 sec, ips: 6.39484 instance/sec.
# [02/28 01:25:13] epoch:[  1/30 ] train step:640  loss: 1.00004 lr: 0.001000 batch_cost: 2.50158 sec, reader_cost: 0.00030 sec, ips: 6.39596 instance/sec.
# [02/28 01:25:38] epoch:[  1/30 ] train step:650  loss: 0.94425 lr: 0.001000 batch_cost: 2.50206 sec, reader_cost: 0.00029 sec, ips: 6.39474 instance/sec.
# [02/28 01:26:03] epoch:[  1/30 ] train step:660  loss: 0.83916 lr: 0.001000 batch_cost: 2.50169 sec, reader_cost: 0.00029 sec, ips: 6.39569 instance/sec.
# [02/28 01:26:28] epoch:[  1/30 ] train step:670  loss: 1.12134 lr: 0.001000 batch_cost: 2.50872 sec, reader_cost: 0.00028 sec, ips: 6.37776 instance/sec.
# [02/28 01:26:53] epoch:[  1/30 ] train step:680  loss: 1.18165 lr: 0.001000 batch_cost: 2.50345 sec, reader_cost: 0.00029 sec, ips: 6.39118 instance/sec.
# [02/28 01:27:18] epoch:[  1/30 ] train step:690  loss: 1.10053 lr: 0.001000 batch_cost: 2.50191 sec, reader_cost: 0.00031 sec, ips: 6.39512 instance/sec.
# [02/28 01:27:43] epoch:[  1/30 ] train step:700  loss: 0.96734 lr: 0.001000 batch_cost: 2.50254 sec, reader_cost: 0.00034 sec, ips: 6.39350 instance/sec.
# [02/28 01:28:08] epoch:[  1/30 ] train step:710  loss: 1.05687 lr: 0.001000 batch_cost: 2.50345 sec, reader_cost: 0.00149 sec, ips: 6.39119 instance/sec.
# [02/28 01:28:33] epoch:[  1/30 ] train step:720  loss: 1.20378 lr: 0.001000 batch_cost: 2.50256 sec, reader_cost: 0.00153 sec, ips: 6.39344 instance/sec.
# [02/28 01:28:58] epoch:[  1/30 ] train step:730  loss: 1.40503 lr: 0.001000 batch_cost: 2.51149 sec, reader_cost: 0.00032 sec, ips: 6.37073 instance/sec.
# [02/28 01:29:23] epoch:[  1/30 ] train step:740  loss: 1.01655 lr: 0.001000 batch_cost: 2.50153 sec, reader_cost: 0.00030 sec, ips: 6.39609 instance/sec.
# [02/28 01:29:48] epoch:[  1/30 ] train step:750  loss: 1.39446 lr: 0.001000 batch_cost: 2.50378 sec, reader_cost: 0.00190 sec, ips: 6.39034 instance/sec.
# [02/28 01:30:13] epoch:[  1/30 ] train step:760  loss: 1.03688 lr: 0.001000 batch_cost: 2.50256 sec, reader_cost: 0.00030 sec, ips: 6.39346 instance/sec.
# [02/28 01:30:38] epoch:[  1/30 ] train step:770  loss: 1.15139 lr: 0.001000 batch_cost: 2.50333 sec, reader_cost: 0.00030 sec, ips: 6.39149 instance/sec.
# [02/28 01:31:03] epoch:[  1/30 ] train step:780  loss: 2.68286 lr: 0.001000 batch_cost: 2.50415 sec, reader_cost: 0.00030 sec, ips: 6.38939 instance/sec.
# [02/28 01:31:28] epoch:[  1/30 ] train step:790  loss: 1.13570 lr: 0.001000 batch_cost: 2.51097 sec, reader_cost: 0.00028 sec, ips: 6.37203 instance/sec.
# [02/28 01:31:54] epoch:[  1/30 ] train step:800  loss: 1.06608 lr: 0.001000 batch_cost: 2.50410 sec, reader_cost: 0.00031 sec, ips: 6.38953 instance/sec.
# [02/28 01:32:19] epoch:[  1/30 ] train step:810  loss: 1.01601 lr: 0.001000 batch_cost: 2.50198 sec, reader_cost: 0.00030 sec, ips: 6.39492 instance/sec.
# [02/28 01:32:44] epoch:[  1/30 ] train step:820  loss: 1.14569 lr: 0.001000 batch_cost: 2.50224 sec, reader_cost: 0.00031 sec, ips: 6.39428 instance/sec.
# [02/28 01:33:09] epoch:[  1/30 ] train step:830  loss: 0.84307 lr: 0.001000 batch_cost: 2.50396 sec, reader_cost: 0.00036 sec, ips: 6.38988 instance/sec.
# [02/28 01:33:34] epoch:[  1/30 ] train step:840  loss: 1.09985 lr: 0.001000 batch_cost: 2.50108 sec, reader_cost: 0.00033 sec, ips: 6.39723 instance/sec.
# [02/28 01:33:59] epoch:[  1/30 ] train step:850  loss: 0.97759 lr: 0.001000 batch_cost: 2.50567 sec, reader_cost: 0.00030 sec, ips: 6.38551 instance/sec.
# [02/28 01:34:24] epoch:[  1/30 ] train step:860  loss: 1.01227 lr: 0.001000 batch_cost: 2.51770 sec, reader_cost: 0.00141 sec, ips: 6.35500 instance/sec.
# [02/28 01:34:49] epoch:[  1/30 ] train step:870  loss: 0.97985 lr: 0.001000 batch_cost: 2.50230 sec, reader_cost: 0.00030 sec, ips: 6.39412 instance/sec.
# [02/28 01:35:14] epoch:[  1/30 ] train step:880  loss: 1.12977 lr: 0.001000 batch_cost: 2.50396 sec, reader_cost: 0.00188 sec, ips: 6.38989 instance/sec.
# [02/28 01:35:39] epoch:[  1/30 ] train step:890  loss: 1.00101 lr: 0.001000 batch_cost: 2.50186 sec, reader_cost: 0.00032 sec, ips: 6.39525 instance/sec.
# [02/28 01:36:04] epoch:[  1/30 ] train step:900  loss: 1.02702 lr: 0.001000 batch_cost: 2.50391 sec, reader_cost: 0.00030 sec, ips: 6.39001 instance/sec.
# [02/28 01:36:29] epoch:[  1/30 ] train step:910  loss: 1.03431 lr: 0.001000 batch_cost: 2.50310 sec, reader_cost: 0.00029 sec, ips: 6.39206 instance/sec.
# [02/28 01:36:54] epoch:[  1/30 ] train step:920  loss: 1.51262 lr: 0.001000 batch_cost: 2.50162 sec, reader_cost: 0.00029 sec, ips: 6.39584 instance/sec.
# [02/28 01:37:19] epoch:[  1/30 ] train step:930  loss: 1.27418 lr: 0.001000 batch_cost: 2.50278 sec, reader_cost: 0.00030 sec, ips: 6.39290 instance/sec.
# [02/28 01:37:44] epoch:[  1/30 ] train step:940  loss: 1.11843 lr: 0.001000 batch_cost: 2.50877 sec, reader_cost: 0.00030 sec, ips: 6.37762 instance/sec.
# [02/28 01:38:09] epoch:[  1/30 ] train step:950  loss: 1.07833 lr: 0.001000 batch_cost: 2.50201 sec, reader_cost: 0.00030 sec, ips: 6.39485 instance/sec.
# [02/28 01:38:34] epoch:[  1/30 ] train step:960  loss: 1.06654 lr: 0.001000 batch_cost: 2.50383 sec, reader_cost: 0.00183 sec, ips: 6.39022 instance/sec.
# [02/28 01:38:59] epoch:[  1/30 ] train step:970  loss: 1.00683 lr: 0.001000 batch_cost: 2.50201 sec, reader_cost: 0.00029 sec, ips: 6.39485 instance/sec.
# [02/28 01:39:24] epoch:[  1/30 ] train step:980  loss: 1.50257 lr: 0.001000 batch_cost: 2.50051 sec, reader_cost: 0.00029 sec, ips: 6.39870 instance/sec.
# [02/28 01:39:49] epoch:[  1/30 ] train step:990  loss: 1.37271 lr: 0.001000 batch_cost: 2.50280 sec, reader_cost: 0.00178 sec, ips: 6.39284 instance/sec.
# [02/28 01:40:14] epoch:[  1/30 ] train step:1000 loss: 0.90293 lr: 0.001000 batch_cost: 2.50713 sec, reader_cost: 0.00028 sec, ips: 6.38180 instance/sec.
# [02/28 01:40:39] epoch:[  1/30 ] train step:1010 loss: 1.38661 lr: 0.001000 batch_cost: 2.50095 sec, reader_cost: 0.00030 sec, ips: 6.39757 instance/sec.
# [02/28 01:41:04] epoch:[  1/30 ] train step:1020 loss: 1.10266 lr: 0.001000 batch_cost: 2.50340 sec, reader_cost: 0.00181 sec, ips: 6.39132 instance/sec.
# [02/28 01:41:29] epoch:[  1/30 ] train step:1030 loss: 0.97301 lr: 0.001000 batch_cost: 2.50208 sec, reader_cost: 0.00034 sec, ips: 6.39468 instance/sec.
# [02/28 01:41:54] epoch:[  1/30 ] train step:1040 loss: 1.16362 lr: 0.001000 batch_cost: 2.50126 sec, reader_cost: 0.00029 sec, ips: 6.39679 instance/sec.
# [02/28 01:42:19] epoch:[  1/30 ] train step:1050 loss: 1.19135 lr: 0.001000 batch_cost: 2.50199 sec, reader_cost: 0.00031 sec, ips: 6.39492 instance/sec.
# [02/28 01:42:44] epoch:[  1/30 ] train step:1060 loss: 1.20433 lr: 0.001000 batch_cost: 2.50271 sec, reader_cost: 0.00029 sec, ips: 6.39306 instance/sec.
# [02/28 01:43:10] epoch:[  1/30 ] train step:1070 loss: 1.11631 lr: 0.001000 batch_cost: 2.50615 sec, reader_cost: 0.00030 sec, ips: 6.38429 instance/sec.
# [02/28 01:43:35] epoch:[  1/30 ] train step:1080 loss: 2.07445 lr: 0.001000 batch_cost: 2.51078 sec, reader_cost: 0.00030 sec, ips: 6.37252 instance/sec.
# [02/28 01:44:00] epoch:[  1/30 ] train step:1090 loss: 0.94083 lr: 0.001000 batch_cost: 2.50168 sec, reader_cost: 0.00029 sec, ips: 6.39570 instance/sec.
# [02/28 01:44:25] epoch:[  1/30 ] train step:1100 loss: 1.01248 lr: 0.001000 batch_cost: 2.50063 sec, reader_cost: 0.00027 sec, ips: 6.39838 instance/sec.
# [02/28 01:44:50] epoch:[  1/30 ] train step:1110 loss: 1.07204 lr: 0.001000 batch_cost: 2.50071 sec, reader_cost: 0.00027 sec, ips: 6.39819 instance/sec.
# [02/28 01:45:00] END epoch:1   train loss_avg: 1.25678  avg_batch_cost: 2.50106 sec, avg_reader_cost: 0.00028 sec, batch_cost_sum: 2791.79355 sec, avg_ips: 6.39016 instance/sec.
# [02/28 01:45:02] epoch:[  1/30 ] val step:0    loss: 0.99054 batch_cost: 2.31688 sec, reader_cost: 0.00000 sec, ips: 6.90583 instance/sec.
# [02/28 01:45:04] epoch:[  1/30 ] val step:10   loss: 1.03003 batch_cost: 0.17508 sec, reader_cost: 0.00000 sec, ips: 91.38726 instance/sec.
# [02/28 01:45:06] epoch:[  1/30 ] val step:20   loss: 2.06164 batch_cost: 0.13046 sec, reader_cost: 0.00000 sec, ips: 122.64136 instance/sec.
# [02/28 01:45:07] epoch:[  1/30 ] val step:30   loss: 1.43284 batch_cost: 0.17277 sec, reader_cost: 0.00000 sec, ips: 92.61121 instance/sec.
# [02/28 01:45:09] epoch:[  1/30 ] val step:40   loss: 0.78108 batch_cost: 0.18783 sec, reader_cost: 0.00000 sec, ips: 85.18321 instance/sec.
# [02/28 01:45:11] epoch:[  1/30 ] val step:50   loss: 0.83685 batch_cost: 0.18810 sec, reader_cost: 0.00000 sec, ips: 85.06098 instance/sec.
# [02/28 01:45:12] epoch:[  1/30 ] val step:60   loss: 1.11043 batch_cost: 0.12695 sec, reader_cost: 0.00000 sec, ips: 126.03763 instance/sec.
# [02/28 01:45:14] epoch:[  1/30 ] val step:70   loss: 1.19230 batch_cost: 0.17332 sec, reader_cost: 0.00000 sec, ips: 92.31476 instance/sec.
# [02/28 01:45:15] epoch:[  1/30 ] val step:80   loss: 1.75145 batch_cost: 0.12650 sec, reader_cost: 0.00000 sec, ips: 126.48566 instance/sec.
# [02/28 01:45:17] epoch:[  1/30 ] val step:90   loss: 1.08869 batch_cost: 0.17178 sec, reader_cost: 0.00000 sec, ips: 93.14414 instance/sec.
# [02/28 01:45:18] epoch:[  1/30 ] val step:100  loss: 1.30027 batch_cost: 0.12712 sec, reader_cost: 0.00000 sec, ips: 125.86956 instance/sec.
# [02/28 01:45:19] epoch:[  1/30 ] val step:110  loss: 0.84774 batch_cost: 0.12645 sec, reader_cost: 0.00000 sec, ips: 126.53360 instance/sec.
# [02/28 01:45:20] END epoch:1   val loss_avg: 1.14266 avg_batch_cost: 0.10245 sec, avg_reader_cost: 0.00000 sec, batch_cost_sum: 20.16089 sec, avg_ips: 92.85304 instance/sec.
# [02/28 01:45:25] epoch:[  2/30 ] train step:0    loss: 0.87388 lr: 0.001000 batch_cost: 4.40190 sec, reader_cost: 1.84977 sec, ips: 3.63480 instance/sec.
# [02/28 01:45:50] epoch:[  2/30 ] train step:10   loss: 1.01759 lr: 0.001000 batch_cost: 2.50126 sec, reader_cost: 0.00030 sec, ips: 6.39676 instance/sec.
# [02/28 01:46:15] epoch:[  2/30 ] train step:20   loss: 1.11342 lr: 0.001000 batch_cost: 2.50185 sec, reader_cost: 0.00030 sec, ips: 6.39528 instance/sec.
# [02/28 01:46:40] epoch:[  2/30 ] train step:30   loss: 0.99247 lr: 0.001000 batch_cost: 2.50219 sec, reader_cost: 0.00036 sec, ips: 6.39439 instance/sec.
# [02/28 01:47:05] epoch:[  2/30 ] train step:40   loss: 1.27932 lr: 0.001000 batch_cost: 2.50116 sec, reader_cost: 0.00034 sec, ips: 6.39702 instance/sec.
# [02/28 01:47:30] epoch:[  2/30 ] train step:50   loss: 1.05317 lr: 0.001000 batch_cost: 2.50131 sec, reader_cost: 0.00031 sec, ips: 6.39664 instance/sec.
# [02/28 01:47:55] epoch:[  2/30 ] train step:60   loss: 1.19859 lr: 0.001000 batch_cost: 2.50325 sec, reader_cost: 0.00201 sec, ips: 6.39170 instance/sec.
# [02/28 01:48:20] epoch:[  2/30 ] train step:70   loss: 0.95677 lr: 0.001000 batch_cost: 2.50221 sec, reader_cost: 0.00029 sec, ips: 6.39435 instance/sec.
# [02/28 01:48:45] epoch:[  2/30 ] train step:80   loss: 1.07396 lr: 0.001000 batch_cost: 2.50144 sec, reader_cost: 0.00031 sec, ips: 6.39632 instance/sec.
# [02/28 01:49:10] epoch:[  2/30 ] train step:90   loss: 0.99583 lr: 0.001000 batch_cost: 2.50168 sec, reader_cost: 0.00030 sec, ips: 6.39571 instance/sec.
# [02/28 01:49:35] epoch:[  2/30 ] train step:100  loss: 1.20278 lr: 0.001000 batch_cost: 2.50089 sec, reader_cost: 0.00032 sec, ips: 6.39772 instance/sec.
# [02/28 01:50:00] epoch:[  2/30 ] train step:110  loss: 1.08610 lr: 0.001000 batch_cost: 2.50280 sec, reader_cost: 0.00034 sec, ips: 6.39284 instance/sec.
# [02/28 01:50:25] epoch:[  2/30 ] train step:120  loss: 0.94771 lr: 0.001000 batch_cost: 2.50270 sec, reader_cost: 0.00030 sec, ips: 6.39309 instance/sec.
# [02/28 01:50:50] epoch:[  2/30 ] train step:130  loss: 1.13085 lr: 0.001000 batch_cost: 2.50370 sec, reader_cost: 0.00028 sec, ips: 6.39055 instance/sec.
# [02/28 01:51:15] epoch:[  2/30 ] train step:140  loss: 1.00917 lr: 0.001000 batch_cost: 2.50332 sec, reader_cost: 0.00030 sec, ips: 6.39152 instance/sec.
# [02/28 01:51:40] epoch:[  2/30 ] train step:150  loss: 0.97451 lr: 0.001000 batch_cost: 2.50218 sec, reader_cost: 0.00034 sec, ips: 6.39444 instance/sec.
# [02/28 01:52:05] epoch:[  2/30 ] train step:160  loss: 1.19799 lr: 0.001000 batch_cost: 2.50450 sec, reader_cost: 0.00224 sec, ips: 6.38849 instance/sec.
# [02/28 01:52:30] epoch:[  2/30 ] train step:170  loss: 0.91505 lr: 0.001000 batch_cost: 2.50302 sec, reader_cost: 0.00036 sec, ips: 6.39228 instance/sec.
# [02/28 01:52:55] epoch:[  2/30 ] train step:180  loss: 0.93769 lr: 0.001000 batch_cost: 2.50435 sec, reader_cost: 0.00036 sec, ips: 6.38889 instance/sec.
# [02/28 01:53:21] epoch:[  2/30 ] train step:190  loss: 1.10961 lr: 0.001000 batch_cost: 2.50584 sec, reader_cost: 0.00184 sec, ips: 6.38509 instance/sec.
# [02/28 01:53:46] epoch:[  2/30 ] train step:200  loss: 1.12744 lr: 0.001000 batch_cost: 2.50404 sec, reader_cost: 0.00214 sec, ips: 6.38968 instance/sec.
# [02/28 01:54:11] epoch:[  2/30 ] train step:210  loss: 1.76875 lr: 0.001000 batch_cost: 2.50156 sec, reader_cost: 0.00030 sec, ips: 6.39601 instance/sec.
# [02/28 01:54:36] epoch:[  2/30 ] train step:220  loss: 1.28542 lr: 0.001000 batch_cost: 2.50192 sec, reader_cost: 0.00030 sec, ips: 6.39508 instance/sec.
# [02/28 01:55:01] epoch:[  2/30 ] train step:230  loss: 0.91768 lr: 0.001000 batch_cost: 2.50267 sec, reader_cost: 0.00032 sec, ips: 6.39318 instance/sec.
# [02/28 01:55:26] epoch:[  2/30 ] train step:240  loss: 1.07367 lr: 0.001000 batch_cost: 2.50334 sec, reader_cost: 0.00216 sec, ips: 6.39146 instance/sec.
# [02/28 01:55:51] epoch:[  2/30 ] train step:250  loss: 0.93195 lr: 0.001000 batch_cost: 2.50127 sec, reader_cost: 0.00030 sec, ips: 6.39676 instance/sec.
# [02/28 01:56:16] epoch:[  2/30 ] train step:260  loss: 0.96505 lr: 0.001000 batch_cost: 2.50103 sec, reader_cost: 0.00034 sec, ips: 6.39738 instance/sec.
# [02/28 01:56:41] epoch:[  2/30 ] train step:270  loss: 0.86564 lr: 0.001000 batch_cost: 2.50338 sec, reader_cost: 0.00201 sec, ips: 6.39135 instance/sec.
# [02/28 01:57:06] epoch:[  2/30 ] train step:280  loss: 0.83510 lr: 0.001000 batch_cost: 2.50247 sec, reader_cost: 0.00074 sec, ips: 6.39367 instance/sec.
# [02/28 01:57:31] epoch:[  2/30 ] train step:290  loss: 1.93926 lr: 0.001000 batch_cost: 2.50302 sec, reader_cost: 0.00274 sec, ips: 6.39227 instance/sec.
# [02/28 01:57:56] epoch:[  2/30 ] train step:300  loss: 1.17967 lr: 0.001000 batch_cost: 2.49964 sec, reader_cost: 0.00030 sec, ips: 6.40092 instance/sec.
# [02/28 01:58:21] epoch:[  2/30 ] train step:310  loss: 1.13794 lr: 0.001000 batch_cost: 2.50129 sec, reader_cost: 0.00035 sec, ips: 6.39669 instance/sec.
# [02/28 01:58:46] epoch:[  2/30 ] train step:320  loss: 1.12469 lr: 0.001000 batch_cost: 2.50088 sec, reader_cost: 0.00034 sec, ips: 6.39775 instance/sec.
# [02/28 01:59:11] epoch:[  2/30 ] train step:330  loss: 1.21664 lr: 0.001000 batch_cost: 2.50212 sec, reader_cost: 0.00033 sec, ips: 6.39458 instance/sec.
# [02/28 01:59:36] epoch:[  2/30 ] train step:340  loss: 1.20985 lr: 0.001000 batch_cost: 2.50369 sec, reader_cost: 0.00177 sec, ips: 6.39058 instance/sec.
# [02/28 02:00:01] epoch:[  2/30 ] train step:350  loss: 1.26472 lr: 0.001000 batch_cost: 2.50033 sec, reader_cost: 0.00029 sec, ips: 6.39916 instance/sec.
# [02/28 02:00:26] epoch:[  2/30 ] train step:360  loss: 0.91413 lr: 0.001000 batch_cost: 2.50321 sec, reader_cost: 0.00195 sec, ips: 6.39180 instance/sec.
# [02/28 02:00:51] epoch:[  2/30 ] train step:370  loss: 0.93460 lr: 0.001000 batch_cost: 2.50687 sec, reader_cost: 0.00195 sec, ips: 6.38247 instance/sec.
# [02/28 02:01:16] epoch:[  2/30 ] train step:380  loss: 0.87826 lr: 0.001000 batch_cost: 2.50324 sec, reader_cost: 0.00211 sec, ips: 6.39171 instance/sec.
# [02/28 02:01:41] epoch:[  2/30 ] train step:390  loss: 1.38678 lr: 0.001000 batch_cost: 2.50388 sec, reader_cost: 0.00200 sec, ips: 6.39008 instance/sec.
# [02/28 02:02:06] epoch:[  2/30 ] train step:400  loss: 1.00438 lr: 0.001000 batch_cost: 2.50415 sec, reader_cost: 0.00198 sec, ips: 6.38939 instance/sec.
# [02/28 02:02:31] epoch:[  2/30 ] train step:410  loss: 0.89175 lr: 0.001000 batch_cost: 2.50409 sec, reader_cost: 0.00229 sec, ips: 6.38955 instance/sec.
# [02/28 02:02:56] epoch:[  2/30 ] train step:420  loss: 0.92308 lr: 0.001000 batch_cost: 2.50348 sec, reader_cost: 0.00207 sec, ips: 6.39111 instance/sec.
# [02/28 02:03:21] epoch:[  2/30 ] train step:430  loss: 1.32646 lr: 0.001000 batch_cost: 2.50377 sec, reader_cost: 0.00149 sec, ips: 6.39037 instance/sec.
# [02/28 02:03:46] epoch:[  2/30 ] train step:440  loss: 0.91645 lr: 0.001000 batch_cost: 2.50183 sec, reader_cost: 0.00030 sec, ips: 6.39532 instance/sec.
# [02/28 02:04:11] epoch:[  2/30 ] train step:450  loss: 1.03207 lr: 0.001000 batch_cost: 2.50259 sec, reader_cost: 0.00194 sec, ips: 6.39338 instance/sec.
# [02/28 02:04:36] epoch:[  2/30 ] train step:460  loss: 1.10855 lr: 0.001000 batch_cost: 2.50134 sec, reader_cost: 0.00031 sec, ips: 6.39658 instance/sec.
# [02/28 02:05:01] epoch:[  2/30 ] train step:470  loss: 1.04322 lr: 0.001000 batch_cost: 2.50248 sec, reader_cost: 0.00198 sec, ips: 6.39365 instance/sec.
# [02/28 02:05:26] epoch:[  2/30 ] train step:480  loss: 0.81654 lr: 0.001000 batch_cost: 2.50187 sec, reader_cost: 0.00031 sec, ips: 6.39522 instance/sec.
# [02/28 02:05:51] epoch:[  2/30 ] train step:490  loss: 1.20714 lr: 0.001000 batch_cost: 2.50070 sec, reader_cost: 0.00032 sec, ips: 6.39821 instance/sec.
# [02/28 02:06:16] epoch:[  2/30 ] train step:500  loss: 0.98392 lr: 0.001000 batch_cost: 2.50180 sec, reader_cost: 0.00030 sec, ips: 6.39540 instance/sec.
# [02/28 02:06:41] epoch:[  2/30 ] train step:510  loss: 0.91325 lr: 0.001000 batch_cost: 2.50085 sec, reader_cost: 0.00033 sec, ips: 6.39782 instance/sec.
# [02/28 02:07:06] epoch:[  2/30 ] train step:520  loss: 1.06145 lr: 0.001000 batch_cost: 2.50001 sec, reader_cost: 0.00034 sec, ips: 6.39998 instance/sec.
# [02/28 02:07:31] epoch:[  2/30 ] train step:530  loss: 1.30919 lr: 0.001000 batch_cost: 2.50374 sec, reader_cost: 0.00183 sec, ips: 6.39043 instance/sec.
# [02/28 02:07:56] epoch:[  2/30 ] train step:540  loss: 1.01096 lr: 0.001000 batch_cost: 2.50173 sec, reader_cost: 0.00031 sec, ips: 6.39557 instance/sec.
# [02/28 02:08:21] epoch:[  2/30 ] train step:550  loss: 1.03409 lr: 0.001000 batch_cost: 2.50093 sec, reader_cost: 0.00034 sec, ips: 6.39762 instance/sec.
# [02/28 02:08:46] epoch:[  2/30 ] train step:560  loss: 0.90100 lr: 0.001000 batch_cost: 2.50226 sec, reader_cost: 0.00030 sec, ips: 6.39422 instance/sec.
# [02/28 02:09:11] epoch:[  2/30 ] train step:570  loss: 1.08329 lr: 0.001000 batch_cost: 2.50292 sec, reader_cost: 0.00203 sec, ips: 6.39253 instance/sec.
# [02/28 02:09:36] epoch:[  2/30 ] train step:580  loss: 1.17209 lr: 0.001000 batch_cost: 2.50240 sec, reader_cost: 0.00189 sec, ips: 6.39386 instance/sec.
# [02/28 02:10:01] epoch:[  2/30 ] train step:590  loss: 0.95544 lr: 0.001000 batch_cost: 2.50232 sec, reader_cost: 0.00037 sec, ips: 6.39407 instance/sec.
# [02/28 02:10:26] epoch:[  2/30 ] train step:600  loss: 1.04904 lr: 0.001000 batch_cost: 2.50190 sec, reader_cost: 0.00035 sec, ips: 6.39513 instance/sec.
# [02/28 02:10:51] epoch:[  2/30 ] train step:610  loss: 1.10074 lr: 0.001000 batch_cost: 2.50063 sec, reader_cost: 0.00030 sec, ips: 6.39839 instance/sec.
# [02/28 02:11:16] epoch:[  2/30 ] train step:620  loss: 0.86685 lr: 0.001000 batch_cost: 2.50199 sec, reader_cost: 0.00031 sec, ips: 6.39492 instance/sec.
# [02/28 02:11:42] epoch:[  2/30 ] train step:630  loss: 1.21404 lr: 0.001000 batch_cost: 2.50579 sec, reader_cost: 0.00034 sec, ips: 6.38522 instance/sec.
# [02/28 02:12:07] epoch:[  2/30 ] train step:640  loss: 1.19347 lr: 0.001000 batch_cost: 2.50076 sec, reader_cost: 0.00031 sec, ips: 6.39805 instance/sec.
# [02/28 02:12:32] epoch:[  2/30 ] train step:650  loss: 1.00215 lr: 0.001000 batch_cost: 2.50376 sec, reader_cost: 0.00198 sec, ips: 6.39039 instance/sec.
# [02/28 02:12:57] epoch:[  2/30 ] train step:660  loss: 1.00748 lr: 0.001000 batch_cost: 2.50203 sec, reader_cost: 0.00031 sec, ips: 6.39480 instance/sec.
# [02/28 02:13:22] epoch:[  2/30 ] train step:670  loss: 1.01522 lr: 0.001000 batch_cost: 2.50113 sec, reader_cost: 0.00034 sec, ips: 6.39710 instance/sec.
# [02/28 02:13:47] epoch:[  2/30 ] train step:680  loss: 0.91535 lr: 0.001000 batch_cost: 2.50225 sec, reader_cost: 0.00034 sec, ips: 6.39425 instance/sec.
# [02/28 02:14:12] epoch:[  2/30 ] train step:690  loss: 0.90777 lr: 0.001000 batch_cost: 2.49996 sec, reader_cost: 0.00031 sec, ips: 6.40010 instance/sec.
# [02/28 02:14:37] epoch:[  2/30 ] train step:700  loss: 1.11795 lr: 0.001000 batch_cost: 2.50367 sec, reader_cost: 0.00202 sec, ips: 6.39061 instance/sec.
# [02/28 02:15:02] epoch:[  2/30 ] train step:710  loss: 0.95851 lr: 0.001000 batch_cost: 2.50155 sec, reader_cost: 0.00030 sec, ips: 6.39603 instance/sec.
# [02/28 02:15:27] epoch:[  2/30 ] train step:720  loss: 1.12605 lr: 0.001000 batch_cost: 2.50474 sec, reader_cost: 0.00030 sec, ips: 6.38790 instance/sec.
# [02/28 02:15:52] epoch:[  2/30 ] train step:730  loss: 1.39100 lr: 0.001000 batch_cost: 2.50249 sec, reader_cost: 0.00036 sec, ips: 6.39364 instance/sec.
# [02/28 02:16:17] epoch:[  2/30 ] train step:740  loss: 0.94730 lr: 0.001000 batch_cost: 2.50173 sec, reader_cost: 0.00034 sec, ips: 6.39558 instance/sec.
# [02/28 02:16:42] epoch:[  2/30 ] train step:750  loss: 0.94258 lr: 0.001000 batch_cost: 2.50059 sec, reader_cost: 0.00032 sec, ips: 6.39850 instance/sec.
# [02/28 02:17:07] epoch:[  2/30 ] train step:760  loss: 1.07025 lr: 0.001000 batch_cost: 2.50193 sec, reader_cost: 0.00030 sec, ips: 6.39507 instance/sec.
# [02/28 02:17:32] epoch:[  2/30 ] train step:770  loss: 1.49326 lr: 0.001000 batch_cost: 2.50419 sec, reader_cost: 0.00209 sec, ips: 6.38928 instance/sec.
# [02/28 02:17:57] epoch:[  2/30 ] train step:780  loss: 1.07280 lr: 0.001000 batch_cost: 2.50187 sec, reader_cost: 0.00031 sec, ips: 6.39523 instance/sec.
# [02/28 02:18:22] epoch:[  2/30 ] train step:790  loss: 0.81088 lr: 0.001000 batch_cost: 2.50149 sec, reader_cost: 0.00033 sec, ips: 6.39619 instance/sec.
# [02/28 02:18:47] epoch:[  2/30 ] train step:800  loss: 1.25980 lr: 0.001000 batch_cost: 2.50237 sec, reader_cost: 0.00031 sec, ips: 6.39394 instance/sec.
# [02/28 02:19:12] epoch:[  2/30 ] train step:810  loss: 1.03637 lr: 0.001000 batch_cost: 2.50024 sec, reader_cost: 0.00035 sec, ips: 6.39938 instance/sec.
# [02/28 02:19:37] epoch:[  2/30 ] train step:820  loss: 0.93101 lr: 0.001000 batch_cost: 2.50224 sec, reader_cost: 0.00030 sec, ips: 6.39428 instance/sec.
# [02/28 02:20:02] epoch:[  2/30 ] train step:830  loss: 1.17290 lr: 0.001000 batch_cost: 2.50418 sec, reader_cost: 0.00194 sec, ips: 6.38932 instance/sec.
# [02/28 02:20:27] epoch:[  2/30 ] train step:840  loss: 0.95033 lr: 0.001000 batch_cost: 2.50182 sec, reader_cost: 0.00030 sec, ips: 6.39534 instance/sec.
# [02/28 02:20:52] epoch:[  2/30 ] train step:850  loss: 1.14684 lr: 0.001000 batch_cost: 2.50132 sec, reader_cost: 0.00033 sec, ips: 6.39662 instance/sec.
# [02/28 02:21:17] epoch:[  2/30 ] train step:860  loss: 1.17661 lr: 0.001000 batch_cost: 2.50065 sec, reader_cost: 0.00030 sec, ips: 6.39834 instance/sec.
# [02/28 02:21:42] epoch:[  2/30 ] train step:870  loss: 1.02024 lr: 0.001000 batch_cost: 2.50177 sec, reader_cost: 0.00030 sec, ips: 6.39548 instance/sec.
# [02/28 02:22:07] epoch:[  2/30 ] train step:880  loss: 1.09248 lr: 0.001000 batch_cost: 2.50184 sec, reader_cost: 0.00036 sec, ips: 6.39530 instance/sec.
# [02/28 02:22:32] epoch:[  2/30 ] train step:890  loss: 0.99005 lr: 0.001000 batch_cost: 2.50117 sec, reader_cost: 0.00031 sec, ips: 6.39701 instance/sec.
# [02/28 02:22:57] epoch:[  2/30 ] train step:900  loss: 1.02722 lr: 0.001000 batch_cost: 2.50344 sec, reader_cost: 0.00205 sec, ips: 6.39120 instance/sec.
# [02/28 02:23:22] epoch:[  2/30 ] train step:910  loss: 1.00011 lr: 0.001000 batch_cost: 2.50120 sec, reader_cost: 0.00030 sec, ips: 6.39694 instance/sec.
# [02/28 02:23:47] epoch:[  2/30 ] train step:920  loss: 0.94913 lr: 0.001000 batch_cost: 2.50280 sec, reader_cost: 0.00200 sec, ips: 6.39283 instance/sec.
# [02/28 02:24:12] epoch:[  2/30 ] train step:930  loss: 1.04495 lr: 0.001000 batch_cost: 2.50324 sec, reader_cost: 0.00195 sec, ips: 6.39171 instance/sec.
# [02/28 02:24:37] epoch:[  2/30 ] train step:940  loss: 1.30861 lr: 0.001000 batch_cost: 2.50243 sec, reader_cost: 0.00032 sec, ips: 6.39377 instance/sec.
# [02/28 02:25:02] epoch:[  2/30 ] train step:950  loss: 1.57480 lr: 0.001000 batch_cost: 2.50108 sec, reader_cost: 0.00032 sec, ips: 6.39724 instance/sec.
# [02/28 02:25:27] epoch:[  2/30 ] train step:960  loss: 1.07466 lr: 0.001000 batch_cost: 2.50427 sec, reader_cost: 0.00194 sec, ips: 6.38909 instance/sec.
# [02/28 02:25:52] epoch:[  2/30 ] train step:970  loss: 1.00757 lr: 0.001000 batch_cost: 2.50190 sec, reader_cost: 0.00032 sec, ips: 6.39514 instance/sec.
# [02/28 02:26:17] epoch:[  2/30 ] train step:980  loss: 0.99039 lr: 0.001000 batch_cost: 2.50214 sec, reader_cost: 0.00030 sec, ips: 6.39453 instance/sec.
# [02/28 02:26:42] epoch:[  2/30 ] train step:990  loss: 0.92057 lr: 0.001000 batch_cost: 2.50227 sec, reader_cost: 0.00206 sec, ips: 6.39418 instance/sec.
# [02/28 02:27:07] epoch:[  2/30 ] train step:1000 loss: 1.02761 lr: 0.001000 batch_cost: 2.50296 sec, reader_cost: 0.00200 sec, ips: 6.39244 instance/sec.
# [02/28 02:27:32] epoch:[  2/30 ] train step:1010 loss: 0.91979 lr: 0.001000 batch_cost: 2.50161 sec, reader_cost: 0.00030 sec, ips: 6.39588 instance/sec.
# [02/28 02:27:57] epoch:[  2/30 ] train step:1020 loss: 1.20242 lr: 0.001000 batch_cost: 2.50109 sec, reader_cost: 0.00030 sec, ips: 6.39722 instance/sec.
# [02/28 02:28:22] epoch:[  2/30 ] train step:1030 loss: 1.01642 lr: 0.001000 batch_cost: 2.50095 sec, reader_cost: 0.00030 sec, ips: 6.39756 instance/sec.
# [02/28 02:28:48] epoch:[  2/30 ] train step:1040 loss: 1.20259 lr: 0.001000 batch_cost: 2.50216 sec, reader_cost: 0.00035 sec, ips: 6.39447 instance/sec.
# [02/28 02:29:13] epoch:[  2/30 ] train step:1050 loss: 1.11185 lr: 0.001000 batch_cost: 2.50365 sec, reader_cost: 0.00197 sec, ips: 6.39066 instance/sec.
# [02/28 02:29:38] epoch:[  2/30 ] train step:1060 loss: 1.00953 lr: 0.001000 batch_cost: 2.50302 sec, reader_cost: 0.00030 sec, ips: 6.39227 instance/sec.
# [02/28 02:30:03] epoch:[  2/30 ] train step:1070 loss: 1.02708 lr: 0.001000 batch_cost: 2.50271 sec, reader_cost: 0.00196 sec, ips: 6.39306 instance/sec.
# [02/28 02:30:28] epoch:[  2/30 ] train step:1080 loss: 1.02331 lr: 0.001000 batch_cost: 2.50294 sec, reader_cost: 0.00187 sec, ips: 6.39249 instance/sec.
# [02/28 02:30:53] epoch:[  2/30 ] train step:1090 loss: 1.32131 lr: 0.001000 batch_cost: 2.50402 sec, reader_cost: 0.00035 sec, ips: 6.38973 instance/sec.
# [02/28 02:31:18] epoch:[  2/30 ] train step:1100 loss: 0.91457 lr: 0.001000 batch_cost: 2.50034 sec, reader_cost: 0.00029 sec, ips: 6.39914 instance/sec.
# [02/28 02:31:43] epoch:[  2/30 ] train step:1110 loss: 0.86517 lr: 0.001000 batch_cost: 2.50067 sec, reader_cost: 0.00027 sec, ips: 6.39829 instance/sec.
# [02/28 02:31:53] END epoch:2   train loss_avg: 1.08152  avg_batch_cost: 2.49948 sec, avg_reader_cost: 0.00028 sec, batch_cost_sum: 2792.13703 sec, avg_ips: 6.38937 instance/sec.
# [02/28 02:31:55] epoch:[  2/30 ] val step:0    loss: 0.94671 batch_cost: 1.77395 sec, reader_cost: 0.00000 sec, ips: 9.01944 instance/sec.
# [02/28 02:31:56] epoch:[  2/30 ] val step:10   loss: 1.02832 batch_cost: 0.12849 sec, reader_cost: 0.00000 sec, ips: 124.52334 instance/sec.
# [02/28 02:31:58] epoch:[  2/30 ] val step:20   loss: 1.66789 batch_cost: 0.17017 sec, reader_cost: 0.00000 sec, ips: 94.02174 instance/sec.
# [02/28 02:31:59] epoch:[  2/30 ] val step:30   loss: 1.14394 batch_cost: 0.12652 sec, reader_cost: 0.00000 sec, ips: 126.46421 instance/sec.
# [02/28 02:32:01] epoch:[  2/30 ] val step:40   loss: 0.76611 batch_cost: 0.12544 sec, reader_cost: 0.00000 sec, ips: 127.54702 instance/sec.
# [02/28 02:32:02] epoch:[  2/30 ] val step:50   loss: 0.87427 batch_cost: 0.17350 sec, reader_cost: 0.00000 sec, ips: 92.21709 instance/sec.
# [02/28 02:32:04] epoch:[  2/30 ] val step:60   loss: 0.95226 batch_cost: 0.16172 sec, reader_cost: 0.00000 sec, ips: 98.93583 instance/sec.
# [02/28 02:32:05] epoch:[  2/30 ] val step:70   loss: 1.10337 batch_cost: 0.12635 sec, reader_cost: 0.00000 sec, ips: 126.62838 instance/sec.
# [02/28 02:32:07] epoch:[  2/30 ] val step:80   loss: 1.75394 batch_cost: 0.14816 sec, reader_cost: 0.00000 sec, ips: 107.99155 instance/sec.
# [02/28 02:32:08] epoch:[  2/30 ] val step:90   loss: 1.07974 batch_cost: 0.12635 sec, reader_cost: 0.00000 sec, ips: 126.63221 instance/sec.
# [02/28 02:32:09] epoch:[  2/30 ] val step:100  loss: 1.33889 batch_cost: 0.12579 sec, reader_cost: 0.00000 sec, ips: 127.19214 instance/sec.
# [02/28 02:32:11] epoch:[  2/30 ] val step:110  loss: 0.81313 batch_cost: 0.12362 sec, reader_cost: 0.00000 sec, ips: 129.42986 instance/sec.
# [02/28 02:32:12] END epoch:2   val loss_avg: 1.07791 avg_batch_cost: 0.10336 sec, avg_reader_cost: 0.00000 sec, batch_cost_sum: 18.58489 sec, avg_ips: 100.72699 instance/sec.
# [02/28 02:32:16] epoch:[  3/30 ] train step:0    loss: 0.99259 lr: 0.001000 batch_cost: 4.45862 sec, reader_cost: 1.90686 sec, ips: 3.58855 instance/sec.
# [02/28 02:32:41] epoch:[  3/30 ] train step:10   loss: 0.97865 lr: 0.001000 batch_cost: 2.50151 sec, reader_cost: 0.00031 sec, ips: 6.39613 instance/sec.
# [02/28 02:33:06] epoch:[  3/30 ] train step:20   loss: 0.96850 lr: 0.001000 batch_cost: 2.50222 sec, reader_cost: 0.00152 sec, ips: 6.39433 instance/sec.
# [02/28 02:33:31] epoch:[  3/30 ] train step:30   loss: 1.07435 lr: 0.001000 batch_cost: 2.50344 sec, reader_cost: 0.00159 sec, ips: 6.39120 instance/sec.
# [02/28 02:33:56] epoch:[  3/30 ] train step:40   loss: 0.94452 lr: 0.001000 batch_cost: 2.48644 sec, reader_cost: 0.00030 sec, ips: 6.43489 instance/sec.
# [02/28 02:34:21] epoch:[  3/30 ] train step:50   loss: 0.97237 lr: 0.001000 batch_cost: 2.47950 sec, reader_cost: 0.00036 sec, ips: 6.45291 instance/sec.
# [02/28 02:34:46] epoch:[  3/30 ] train step:60   loss: 1.04059 lr: 0.001000 batch_cost: 2.48027 sec, reader_cost: 0.00030 sec, ips: 6.45091 instance/sec.
# [02/28 02:35:11] epoch:[  3/30 ] train step:70   loss: 1.20639 lr: 0.001000 batch_cost: 2.48493 sec, reader_cost: 0.00032 sec, ips: 6.43881 instance/sec.
# [02/28 02:35:36] epoch:[  3/30 ] train step:80   loss: 1.13368 lr: 0.001000 batch_cost: 2.49108 sec, reader_cost: 0.00031 sec, ips: 6.42292 instance/sec.
# [02/28 02:36:00] epoch:[  3/30 ] train step:90   loss: 1.07001 lr: 0.001000 batch_cost: 2.50013 sec, reader_cost: 0.00031 sec, ips: 6.39967 instance/sec.
# [02/28 02:36:26] epoch:[  3/30 ] train step:100  loss: 1.05306 lr: 0.001000 batch_cost: 2.50067 sec, reader_cost: 0.00029 sec, ips: 6.39830 instance/sec.
# [02/28 02:36:51] epoch:[  3/30 ] train step:110  loss: 1.36063 lr: 0.001000 batch_cost: 2.50120 sec, reader_cost: 0.00035 sec, ips: 6.39693 instance/sec.
# [02/28 02:37:16] epoch:[  3/30 ] train step:120  loss: 0.98584 lr: 0.001000 batch_cost: 2.50138 sec, reader_cost: 0.00035 sec, ips: 6.39647 instance/sec.
# [02/28 02:37:40] epoch:[  3/30 ] train step:130  loss: 0.99298 lr: 0.001000 batch_cost: 2.48577 sec, reader_cost: 0.00030 sec, ips: 6.43663 instance/sec.
# [02/28 02:38:05] epoch:[  3/30 ] train step:140  loss: 1.05671 lr: 0.001000 batch_cost: 2.49460 sec, reader_cost: 0.00030 sec, ips: 6.41385 instance/sec.
# [02/28 02:38:30] epoch:[  3/30 ] train step:150  loss: 1.10982 lr: 0.001000 batch_cost: 2.50126 sec, reader_cost: 0.00035 sec, ips: 6.39679 instance/sec.
# [02/28 02:38:55] epoch:[  3/30 ] train step:160  loss: 1.09755 lr: 0.001000 batch_cost: 2.50182 sec, reader_cost: 0.00030 sec, ips: 6.39534 instance/sec.
# [02/28 02:39:20] epoch:[  3/30 ] train step:170  loss: 1.20287 lr: 0.001000 batch_cost: 2.50304 sec, reader_cost: 0.00196 sec, ips: 6.39222 instance/sec.
# [02/28 02:39:45] epoch:[  3/30 ] train step:180  loss: 1.02615 lr: 0.001000 batch_cost: 2.50117 sec, reader_cost: 0.00028 sec, ips: 6.39700 instance/sec.
# [02/28 02:40:10] epoch:[  3/30 ] train step:190  loss: 0.95356 lr: 0.001000 batch_cost: 2.50199 sec, reader_cost: 0.00031 sec, ips: 6.39491 instance/sec.
# [02/28 02:40:35] epoch:[  3/30 ] train step:200  loss: 1.00069 lr: 0.001000 batch_cost: 2.50172 sec, reader_cost: 0.00030 sec, ips: 6.39561 instance/sec.
# [02/28 02:41:00] epoch:[  3/30 ] train step:210  loss: 1.49984 lr: 0.001000 batch_cost: 2.49745 sec, reader_cost: 0.00029 sec, ips: 6.40655 instance/sec.
# [02/28 02:41:25] epoch:[  3/30 ] train step:220  loss: 1.05813 lr: 0.001000 batch_cost: 2.50090 sec, reader_cost: 0.00029 sec, ips: 6.39770 instance/sec.
# [02/28 02:41:50] epoch:[  3/30 ] train step:230  loss: 0.98682 lr: 0.001000 batch_cost: 2.50131 sec, reader_cost: 0.00033 sec, ips: 6.39666 instance/sec.
# [02/28 02:42:15] epoch:[  3/30 ] train step:240  loss: 0.78437 lr: 0.001000 batch_cost: 2.50123 sec, reader_cost: 0.00030 sec, ips: 6.39686 instance/sec.
# [02/28 02:42:40] epoch:[  3/30 ] train step:250  loss: 1.04059 lr: 0.001000 batch_cost: 2.50246 sec, reader_cost: 0.00036 sec, ips: 6.39372 instance/sec.
# [02/28 02:43:05] epoch:[  3/30 ] train step:260  loss: 0.95550 lr: 0.001000 batch_cost: 2.50277 sec, reader_cost: 0.00030 sec, ips: 6.39292 instance/sec.
# ...
# [02/28 23:38:35] epoch:[ 30/30 ] train step:220  loss: 0.62405 lr: 0.000100 batch_cost: 2.48162 sec, reader_cost: 0.00193 sec, ips: 6.44739 instance/sec.
# [02/28 23:39:00] epoch:[ 30/30 ] train step:230  loss: 0.70879 lr: 0.000100 batch_cost: 2.47910 sec, reader_cost: 0.00038 sec, ips: 6.45396 instance/sec.
# [02/28 23:39:25] epoch:[ 30/30 ] train step:240  loss: 0.64494 lr: 0.000100 batch_cost: 2.48133 sec, reader_cost: 0.00222 sec, ips: 6.44815 instance/sec.
# [02/28 23:39:49] epoch:[ 30/30 ] train step:250  loss: 0.81843 lr: 0.000100 batch_cost: 2.47960 sec, reader_cost: 0.00031 sec, ips: 6.45266 instance/sec.
# [02/28 23:40:14] epoch:[ 30/30 ] train step:260  loss: 0.57380 lr: 0.000100 batch_cost: 2.48136 sec, reader_cost: 0.00203 sec, ips: 6.44807 instance/sec.
# [02/28 23:40:39] epoch:[ 30/30 ] train step:270  loss: 0.60461 lr: 0.000100 batch_cost: 2.48128 sec, reader_cost: 0.00207 sec, ips: 6.44827 instance/sec.
# [02/28 23:41:04] epoch:[ 30/30 ] train step:280  loss: 0.76543 lr: 0.000100 batch_cost: 2.48129 sec, reader_cost: 0.00207 sec, ips: 6.44827 instance/sec.
# [02/28 23:41:29] epoch:[ 30/30 ] train step:290  loss: 0.69439 lr: 0.000100 batch_cost: 2.47956 sec, reader_cost: 0.00036 sec, ips: 6.45276 instance/sec.
# [02/28 23:41:53] epoch:[ 30/30 ] train step:300  loss: 0.65300 lr: 0.000100 batch_cost: 2.48278 sec, reader_cost: 0.00204 sec, ips: 6.44438 instance/sec.
# [02/28 23:42:18] epoch:[ 30/30 ] train step:310  loss: 0.60311 lr: 0.000100 batch_cost: 2.48148 sec, reader_cost: 0.00199 sec, ips: 6.44775 instance/sec.
# [02/28 23:42:43] epoch:[ 30/30 ] train step:320  loss: 0.68761 lr: 0.000100 batch_cost: 2.47932 sec, reader_cost: 0.00035 sec, ips: 6.45339 instance/sec.
# [02/28 23:43:08] epoch:[ 30/30 ] train step:330  loss: 0.60833 lr: 0.000100 batch_cost: 2.48181 sec, reader_cost: 0.00202 sec, ips: 6.44690 instance/sec.
# [02/28 23:43:33] epoch:[ 30/30 ] train step:340  loss: 0.57033 lr: 0.000100 batch_cost: 2.47986 sec, reader_cost: 0.00036 sec, ips: 6.45199 instance/sec.
# [02/28 23:43:58] epoch:[ 30/30 ] train step:350  loss: 0.71580 lr: 0.000100 batch_cost: 2.48317 sec, reader_cost: 0.00031 sec, ips: 6.44337 instance/sec.
# [02/28 23:44:22] epoch:[ 30/30 ] train step:360  loss: 0.72682 lr: 0.000100 batch_cost: 2.47949 sec, reader_cost: 0.00029 sec, ips: 6.45293 instance/sec.
# [02/28 23:44:47] epoch:[ 30/30 ] train step:370  loss: 0.61604 lr: 0.000100 batch_cost: 2.47871 sec, reader_cost: 0.00030 sec, ips: 6.45498 instance/sec.
# [02/28 23:45:12] epoch:[ 30/30 ] train step:380  loss: 0.67876 lr: 0.000100 batch_cost: 2.47937 sec, reader_cost: 0.00029 sec, ips: 6.45326 instance/sec.
# [02/28 23:45:37] epoch:[ 30/30 ] train step:390  loss: 0.69104 lr: 0.000100 batch_cost: 2.48025 sec, reader_cost: 0.00029 sec, ips: 6.45095 instance/sec.
# [02/28 23:46:02] epoch:[ 30/30 ] train step:400  loss: 0.68229 lr: 0.000100 batch_cost: 2.48163 sec, reader_cost: 0.00201 sec, ips: 6.44739 instance/sec.
# [02/28 23:46:26] epoch:[ 30/30 ] train step:410  loss: 0.65731 lr: 0.000100 batch_cost: 2.47947 sec, reader_cost: 0.00029 sec, ips: 6.45300 instance/sec.
# [02/28 23:46:51] epoch:[ 30/30 ] train step:420  loss: 0.79954 lr: 0.000100 batch_cost: 2.47973 sec, reader_cost: 0.00035 sec, ips: 6.45231 instance/sec.
# [02/28 23:47:16] epoch:[ 30/30 ] train step:430  loss: 0.54077 lr: 0.000100 batch_cost: 2.47907 sec, reader_cost: 0.00029 sec, ips: 6.45403 instance/sec.
# [02/28 23:47:41] epoch:[ 30/30 ] train step:440  loss: 0.77059 lr: 0.000100 batch_cost: 2.48018 sec, reader_cost: 0.00032 sec, ips: 6.45115 instance/sec.
# [02/28 23:48:06] epoch:[ 30/30 ] train step:450  loss: 0.69231 lr: 0.000100 batch_cost: 2.48121 sec, reader_cost: 0.00200 sec, ips: 6.44846 instance/sec.
# [02/28 23:48:30] epoch:[ 30/30 ] train step:460  loss: 0.69082 lr: 0.000100 batch_cost: 2.47856 sec, reader_cost: 0.00033 sec, ips: 6.45536 instance/sec.
# [02/28 23:48:55] epoch:[ 30/30 ] train step:470  loss: 0.66373 lr: 0.000100 batch_cost: 2.48037 sec, reader_cost: 0.00031 sec, ips: 6.45064 instance/sec.
# [02/28 23:49:20] epoch:[ 30/30 ] train step:480  loss: 0.68010 lr: 0.000100 batch_cost: 2.48318 sec, reader_cost: 0.00030 sec, ips: 6.44334 instance/sec.
# [02/28 23:49:45] epoch:[ 30/30 ] train step:490  loss: 0.61380 lr: 0.000100 batch_cost: 2.48030 sec, reader_cost: 0.00035 sec, ips: 6.45082 instance/sec.
# [02/28 23:50:10] epoch:[ 30/30 ] train step:500  loss: 0.63557 lr: 0.000100 batch_cost: 2.48035 sec, reader_cost: 0.00040 sec, ips: 6.45069 instance/sec.
# [02/28 23:50:34] epoch:[ 30/30 ] train step:510  loss: 0.64447 lr: 0.000100 batch_cost: 2.47917 sec, reader_cost: 0.00030 sec, ips: 6.45376 instance/sec.
# [02/28 23:50:59] epoch:[ 30/30 ] train step:520  loss: 0.72473 lr: 0.000100 batch_cost: 2.47930 sec, reader_cost: 0.00029 sec, ips: 6.45343 instance/sec.
# [02/28 23:51:24] epoch:[ 30/30 ] train step:530  loss: 0.72007 lr: 0.000100 batch_cost: 2.47960 sec, reader_cost: 0.00035 sec, ips: 6.45265 instance/sec.
# [02/28 23:51:49] epoch:[ 30/30 ] train step:540  loss: 0.73306 lr: 0.000100 batch_cost: 2.47920 sec, reader_cost: 0.00032 sec, ips: 6.45370 instance/sec.
# [02/28 23:52:14] epoch:[ 30/30 ] train step:550  loss: 0.57139 lr: 0.000100 batch_cost: 2.47822 sec, reader_cost: 0.00029 sec, ips: 6.45624 instance/sec.
# [02/28 23:52:38] epoch:[ 30/30 ] train step:560  loss: 0.63600 lr: 0.000100 batch_cost: 2.48020 sec, reader_cost: 0.00029 sec, ips: 6.45108 instance/sec.
# [02/28 23:53:03] epoch:[ 30/30 ] train step:570  loss: 0.68624 lr: 0.000100 batch_cost: 2.47988 sec, reader_cost: 0.00035 sec, ips: 6.45192 instance/sec.
# [02/28 23:53:28] epoch:[ 30/30 ] train step:580  loss: 0.68871 lr: 0.000100 batch_cost: 2.47898 sec, reader_cost: 0.00029 sec, ips: 6.45427 instance/sec.
# [02/28 23:53:53] epoch:[ 30/30 ] train step:590  loss: 0.76405 lr: 0.000100 batch_cost: 2.48176 sec, reader_cost: 0.00201 sec, ips: 6.44703 instance/sec.
# [02/28 23:54:18] epoch:[ 30/30 ] train step:600  loss: 0.66841 lr: 0.000100 batch_cost: 2.47997 sec, reader_cost: 0.00029 sec, ips: 6.45168 instance/sec.
# [02/28 23:54:42] epoch:[ 30/30 ] train step:610  loss: 0.55526 lr: 0.000100 batch_cost: 2.47934 sec, reader_cost: 0.00029 sec, ips: 6.45333 instance/sec.
# [02/28 23:55:07] epoch:[ 30/30 ] train step:620  loss: 0.67171 lr: 0.000100 batch_cost: 2.47947 sec, reader_cost: 0.00029 sec, ips: 6.45299 instance/sec.
# [02/28 23:55:32] epoch:[ 30/30 ] train step:630  loss: 0.59304 lr: 0.000100 batch_cost: 2.47925 sec, reader_cost: 0.00031 sec, ips: 6.45356 instance/sec.
# [02/28 23:55:57] epoch:[ 30/30 ] train step:640  loss: 0.79059 lr: 0.000100 batch_cost: 2.47931 sec, reader_cost: 0.00030 sec, ips: 6.45341 instance/sec.
# [02/28 23:56:21] epoch:[ 30/30 ] train step:650  loss: 0.58528 lr: 0.000100 batch_cost: 2.47926 sec, reader_cost: 0.00029 sec, ips: 6.45354 instance/sec.
# [02/28 23:56:46] epoch:[ 30/30 ] train step:660  loss: 0.69658 lr: 0.000100 batch_cost: 2.47923 sec, reader_cost: 0.00033 sec, ips: 6.45362 instance/sec.
# [02/28 23:57:11] epoch:[ 30/30 ] train step:670  loss: 0.64653 lr: 0.000100 batch_cost: 2.47939 sec, reader_cost: 0.00035 sec, ips: 6.45320 instance/sec.
# [02/28 23:57:36] epoch:[ 30/30 ] train step:680  loss: 0.70676 lr: 0.000100 batch_cost: 2.47990 sec, reader_cost: 0.00031 sec, ips: 6.45186 instance/sec.
# [02/28 23:58:01] epoch:[ 30/30 ] train step:690  loss: 0.77279 lr: 0.000100 batch_cost: 2.48157 sec, reader_cost: 0.00202 sec, ips: 6.44752 instance/sec.
# [02/28 23:58:25] epoch:[ 30/30 ] train step:700  loss: 0.62390 lr: 0.000100 batch_cost: 2.47944 sec, reader_cost: 0.00030 sec, ips: 6.45307 instance/sec.
# [02/28 23:58:50] epoch:[ 30/30 ] train step:710  loss: 1.00923 lr: 0.000100 batch_cost: 2.48180 sec, reader_cost: 0.00031 sec, ips: 6.44693 instance/sec.
# [02/28 23:59:15] epoch:[ 30/30 ] train step:720  loss: 0.76307 lr: 0.000100 batch_cost: 2.48578 sec, reader_cost: 0.00030 sec, ips: 6.43662 instance/sec.
# [02/28 23:59:40] epoch:[ 30/30 ] train step:730  loss: 0.67010 lr: 0.000100 batch_cost: 2.48338 sec, reader_cost: 0.00209 sec, ips: 6.44284 instance/sec.
# [03/01 00:00:05] epoch:[ 30/30 ] train step:740  loss: 0.66622 lr: 0.000100 batch_cost: 2.47985 sec, reader_cost: 0.00030 sec, ips: 6.45199 instance/sec.
# [03/01 00:00:30] epoch:[ 30/30 ] train step:750  loss: 0.57945 lr: 0.000100 batch_cost: 2.48095 sec, reader_cost: 0.00200 sec, ips: 6.44915 instance/sec.
# [03/01 00:00:54] epoch:[ 30/30 ] train step:760  loss: 0.65239 lr: 0.000100 batch_cost: 2.48155 sec, reader_cost: 0.00197 sec, ips: 6.44758 instance/sec.
# [03/01 00:01:19] epoch:[ 30/30 ] train step:770  loss: 0.84033 lr: 0.000100 batch_cost: 2.48197 sec, reader_cost: 0.00207 sec, ips: 6.44649 instance/sec.
# [03/01 00:01:44] epoch:[ 30/30 ] train step:780  loss: 0.57329 lr: 0.000100 batch_cost: 2.48001 sec, reader_cost: 0.00029 sec, ips: 6.45158 instance/sec.
# [03/01 00:02:09] epoch:[ 30/30 ] train step:790  loss: 0.56898 lr: 0.000100 batch_cost: 2.47968 sec, reader_cost: 0.00033 sec, ips: 6.45244 instance/sec.
# [03/01 00:02:34] epoch:[ 30/30 ] train step:800  loss: 0.71855 lr: 0.000100 batch_cost: 2.48029 sec, reader_cost: 0.00031 sec, ips: 6.45085 instance/sec.
# [03/01 00:02:58] epoch:[ 30/30 ] train step:810  loss: 0.56221 lr: 0.000100 batch_cost: 2.48152 sec, reader_cost: 0.00193 sec, ips: 6.44766 instance/sec.
# [03/01 00:03:23] epoch:[ 30/30 ] train step:820  loss: 0.64775 lr: 0.000100 batch_cost: 2.48005 sec, reader_cost: 0.00032 sec, ips: 6.45148 instance/sec.
# [03/01 00:03:48] epoch:[ 30/30 ] train step:830  loss: 0.82302 lr: 0.000100 batch_cost: 2.47950 sec, reader_cost: 0.00030 sec, ips: 6.45292 instance/sec.
# [03/01 00:04:13] epoch:[ 30/30 ] train step:840  loss: 0.79126 lr: 0.000100 batch_cost: 2.48176 sec, reader_cost: 0.00195 sec, ips: 6.44705 instance/sec.
# [03/01 00:04:38] epoch:[ 30/30 ] train step:850  loss: 0.64886 lr: 0.000100 batch_cost: 2.47971 sec, reader_cost: 0.00030 sec, ips: 6.45236 instance/sec.
# [03/01 00:05:02] epoch:[ 30/30 ] train step:860  loss: 0.83960 lr: 0.000100 batch_cost: 2.48065 sec, reader_cost: 0.00198 sec, ips: 6.44992 instance/sec.
# [03/01 00:05:27] epoch:[ 30/30 ] train step:870  loss: 0.60650 lr: 0.000100 batch_cost: 2.48029 sec, reader_cost: 0.00033 sec, ips: 6.45086 instance/sec.
# [03/01 00:05:52] epoch:[ 30/30 ] train step:880  loss: 0.71827 lr: 0.000100 batch_cost: 2.47950 sec, reader_cost: 0.00032 sec, ips: 6.45292 instance/sec.
# [03/01 00:06:17] epoch:[ 30/30 ] train step:890  loss: 0.68340 lr: 0.000100 batch_cost: 2.47985 sec, reader_cost: 0.00034 sec, ips: 6.45200 instance/sec.
# [03/01 00:06:42] epoch:[ 30/30 ] train step:900  loss: 0.64895 lr: 0.000100 batch_cost: 2.47977 sec, reader_cost: 0.00036 sec, ips: 6.45221 instance/sec.
# [03/01 00:07:06] epoch:[ 30/30 ] train step:910  loss: 0.73845 lr: 0.000100 batch_cost: 2.48197 sec, reader_cost: 0.00036 sec, ips: 6.44650 instance/sec.
# [03/01 00:07:31] epoch:[ 30/30 ] train step:920  loss: 0.67570 lr: 0.000100 batch_cost: 2.47915 sec, reader_cost: 0.00030 sec, ips: 6.45382 instance/sec.
# [03/01 00:07:56] epoch:[ 30/30 ] train step:930  loss: 0.74171 lr: 0.000100 batch_cost: 2.48259 sec, reader_cost: 0.00031 sec, ips: 6.44489 instance/sec.
# [03/01 00:08:21] epoch:[ 30/30 ] train step:940  loss: 0.72514 lr: 0.000100 batch_cost: 2.47919 sec, reader_cost: 0.00032 sec, ips: 6.45371 instance/sec.
# [03/01 00:08:46] epoch:[ 30/30 ] train step:950  loss: 0.59626 lr: 0.000100 batch_cost: 2.47960 sec, reader_cost: 0.00034 sec, ips: 6.45267 instance/sec.
# [03/01 00:09:10] epoch:[ 30/30 ] train step:960  loss: 0.49584 lr: 0.000100 batch_cost: 2.47956 sec, reader_cost: 0.00029 sec, ips: 6.45276 instance/sec.
# [03/01 00:09:35] epoch:[ 30/30 ] train step:970  loss: 0.63077 lr: 0.000100 batch_cost: 2.47930 sec, reader_cost: 0.00031 sec, ips: 6.45344 instance/sec.
# [03/01 00:10:00] epoch:[ 30/30 ] train step:980  loss: 0.75949 lr: 0.000100 batch_cost: 2.47974 sec, reader_cost: 0.00032 sec, ips: 6.45230 instance/sec.
# [03/01 00:10:25] epoch:[ 30/30 ] train step:990  loss: 0.79184 lr: 0.000100 batch_cost: 2.47960 sec, reader_cost: 0.00031 sec, ips: 6.45266 instance/sec.
# [03/01 00:10:50] epoch:[ 30/30 ] train step:1000 loss: 0.69354 lr: 0.000100 batch_cost: 2.47977 sec, reader_cost: 0.00031 sec, ips: 6.45220 instance/sec.
# [03/01 00:11:14] epoch:[ 30/30 ] train step:1010 loss: 0.80894 lr: 0.000100 batch_cost: 2.48023 sec, reader_cost: 0.00029 sec, ips: 6.45103 instance/sec.
# [03/01 00:11:39] epoch:[ 30/30 ] train step:1020 loss: 0.71626 lr: 0.000100 batch_cost: 2.47985 sec, reader_cost: 0.00032 sec, ips: 6.45201 instance/sec.
# [03/01 00:12:04] epoch:[ 30/30 ] train step:1030 loss: 0.65691 lr: 0.000100 batch_cost: 2.47873 sec, reader_cost: 0.00034 sec, ips: 6.45492 instance/sec.
# [03/01 00:12:29] epoch:[ 30/30 ] train step:1040 loss: 0.72717 lr: 0.000100 batch_cost: 2.48301 sec, reader_cost: 0.00198 sec, ips: 6.44380 instance/sec.
# [03/01 00:12:54] epoch:[ 30/30 ] train step:1050 loss: 0.76214 lr: 0.000100 batch_cost: 2.48019 sec, reader_cost: 0.00032 sec, ips: 6.45112 instance/sec.
# [03/01 00:13:19] epoch:[ 30/30 ] train step:1060 loss: 0.62630 lr: 0.000100 batch_cost: 2.47833 sec, reader_cost: 0.00030 sec, ips: 6.45596 instance/sec.
# [03/01 00:13:43] epoch:[ 30/30 ] train step:1070 loss: 0.71966 lr: 0.000100 batch_cost: 2.47974 sec, reader_cost: 0.00034 sec, ips: 6.45229 instance/sec.
# [03/01 00:14:08] epoch:[ 30/30 ] train step:1080 loss: 0.67798 lr: 0.000100 batch_cost: 2.48149 sec, reader_cost: 0.00205 sec, ips: 6.44775 instance/sec.
# [03/01 00:14:33] epoch:[ 30/30 ] train step:1090 loss: 0.78457 lr: 0.000100 batch_cost: 2.48007 sec, reader_cost: 0.00031 sec, ips: 6.45143 instance/sec.
# [03/01 00:14:58] epoch:[ 30/30 ] train step:1100 loss: 0.58571 lr: 0.000100 batch_cost: 2.47880 sec, reader_cost: 0.00029 sec, ips: 6.45474 instance/sec.
# [03/01 00:15:23] epoch:[ 30/30 ] train step:1110 loss: 0.70016 lr: 0.000100 batch_cost: 2.47830 sec, reader_cost: 0.00029 sec, ips: 6.45605 instance/sec.
# [03/01 00:15:33] END epoch:30  train loss_avg: 0.67916  avg_batch_cost: 2.48004 sec, avg_reader_cost: 0.00031 sec, batch_cost_sum: 2768.84224 sec, avg_ips: 6.44313 instance/sec.
# [03/01 00:15:35] epoch:[ 30/30 ] val step:0    loss: 0.84135 batch_cost: 1.86188 sec, reader_cost: 0.00000 sec, ips: 8.59345 instance/sec.
# [03/01 00:15:36] epoch:[ 30/30 ] val step:10   loss: 1.09575 batch_cost: 0.17273 sec, reader_cost: 0.00000 sec, ips: 92.62885 instance/sec.
# [03/01 00:15:38] epoch:[ 30/30 ] val step:20   loss: 1.91069 batch_cost: 0.12834 sec, reader_cost: 0.00000 sec, ips: 124.66838 instance/sec.
# [03/01 00:15:39] epoch:[ 30/30 ] val step:30   loss: 1.92166 batch_cost: 0.18231 sec, reader_cost: 0.00000 sec, ips: 87.76485 instance/sec.
# [03/01 00:15:41] epoch:[ 30/30 ] val step:40   loss: 0.78034 batch_cost: 0.17087 sec, reader_cost: 0.00000 sec, ips: 93.63736 instance/sec.
# [03/01 00:15:42] epoch:[ 30/30 ] val step:50   loss: 0.81149 batch_cost: 0.12585 sec, reader_cost: 0.00000 sec, ips: 127.13407 instance/sec.
# [03/01 00:15:44] epoch:[ 30/30 ] val step:60   loss: 1.08433 batch_cost: 0.17343 sec, reader_cost: 0.00000 sec, ips: 92.25867 instance/sec.
# [03/01 00:15:45] epoch:[ 30/30 ] val step:70   loss: 0.99029 batch_cost: 0.17220 sec, reader_cost: 0.00000 sec, ips: 92.91704 instance/sec.
# [03/01 00:15:47] epoch:[ 30/30 ] val step:80   loss: 1.55694 batch_cost: 0.12622 sec, reader_cost: 0.00000 sec, ips: 126.76688 instance/sec.
# [03/01 00:15:48] epoch:[ 30/30 ] val step:90   loss: 1.06381 batch_cost: 0.17402 sec, reader_cost: 0.00000 sec, ips: 91.94091 instance/sec.
# [03/01 00:15:49] epoch:[ 30/30 ] val step:100  loss: 2.62789 batch_cost: 0.12617 sec, reader_cost: 0.00000 sec, ips: 126.81359 instance/sec.
# [03/01 00:15:51] epoch:[ 30/30 ] val step:110  loss: 0.67149 batch_cost: 0.12527 sec, reader_cost: 0.00000 sec, ips: 127.72812 instance/sec.
# [03/01 00:15:52] END epoch:30  val loss_avg: 1.41355 avg_batch_cost: 0.10271 sec, avg_reader_cost: 0.00000 sec, batch_cost_sum: 18.83151 sec, avg_ips: 99.40784 instance/sec.
# [03/01 00:15:52] training BMN finished

# %% [markdown]
# 这里为了演示训练一个epoch后，停止训练导出模型。实际情况可训练多个epoch，提升模型精度。
#
# ### 模型导出
# 将训练好的模型导出用于推理预测，执行以下脚本。

# %%
# %cd /home/aistudio/
# !python work/PaddleVideo/tools/export_model.py -c  work/PaddleVideo/applications/TableTennis/configs/bmn_tabletennis.yaml -p  work/PaddleVideo/output/BMN/BMN_epoch_00025.pdparams -o PaddleVideo/inference/BMN
# Out:
# /home/aistudio
# Building model(BMN)...
# W0303 09:44:08.601502  4863 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0303 09:44:08.606859  4863 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# Loading params from (work/PaddleVideo/output/BMN/BMN_epoch_00025.pdparams)...
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:77: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return (isinstance(seq, collections.Sequence) and
# model (BMN) has been already saved in (PaddleVideo/inference/BMN).

# %% [markdown]
# ### 推理预测
#
# 使用导出的模型进行推理预测，执行以下命令。

# %%
# %cd /home/aistudio/PaddleVideo/
# !python tools/predict.py --input_file /home/aistudio/data/Features_competition_test_B/npy \
 --config configs/localization/bmn.yaml \
 --model_file inference/BMN/BMN.pdmodel \
 --params_file inference/BMN/BMN.pdiparams \
 --use_gpu=True \
 --use_tensorrt=False
# Out:
# /home/aistudio/PaddleVideo
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddlenlp/transformers/funnel/modeling.py:30: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Iterable
# [03/03 09:44:33] DALI is not installed, you can improve performance if use DALI
# Inference model(BMN)...
# W0303 09:44:35.228497  4938 analysis_predictor.cc:795] The one-time configuration of analysis predictor failed, which may be due to native predictor called first and its configurations taken effect.
# --- Running analysis [ir_graph_build_pass]
# --- Running analysis [ir_graph_clean_pass]
# --- Running analysis [ir_analysis_pass]
# --- Running IR pass [is_test_pass]
# --- Running IR pass [simplify_with_basic_ops_pass]
# --- Running IR pass [conv_affine_channel_fuse_pass]
# --- Running IR pass [conv_eltwiseadd_affine_channel_fuse_pass]
# --- Running IR pass [conv_bn_fuse_pass]
# --- Running IR pass [conv_eltwiseadd_bn_fuse_pass]
# --- Running IR pass [embedding_eltwise_layernorm_fuse_pass]
# --- Running IR pass [multihead_matmul_fuse_pass_v2]
# --- Running IR pass [squeeze2_matmul_fuse_pass]
# --- Running IR pass [reshape2_matmul_fuse_pass]
# --- Running IR pass [flatten2_matmul_fuse_pass]
# --- Running IR pass [map_matmul_v2_to_mul_pass]
# I0303 09:44:35.399802  4938 fuse_pass_base.cc:57] ---  detected 1 subgraphs
# --- Running IR pass [map_matmul_v2_to_matmul_pass]
# --- Running IR pass [map_matmul_to_mul_pass]
# --- Running IR pass [fc_fuse_pass]
# --- Running IR pass [fc_elementwise_layernorm_fuse_pass]
# --- Running IR pass [conv_elementwise_add_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add2_act_fuse_pass]
# --- Running IR pass [conv_elementwise_add_fuse_pass]
# --- Running IR pass [transpose_flatten_concat_fuse_pass]
# --- Running IR pass [runtime_context_cache_pass]
# --- Running analysis [ir_params_sync_among_devices_pass]
# I0303 09:44:35.407042  4938 ir_params_sync_among_devices_pass.cc:45] Sync params from CPU to GPU
# --- Running analysis [adjust_cudnn_workspace_size_pass]
# --- Running analysis [inference_op_replace_pass]
# --- Running analysis [memory_optimize_pass]
# I0303 09:44:35.585090  4938 memory_optimize_pass.cc:216] Cluster name : relu_1.tmp_0  size: 102400
# I0303 09:44:35.585139  4938 memory_optimize_pass.cc:216] Cluster name : feat_input  size: 819200
# I0303 09:44:35.585141  4938 memory_optimize_pass.cc:216] Cluster name : reshape2_0.tmp_0  size: 5120000
# I0303 09:44:35.585152  4938 memory_optimize_pass.cc:216] Cluster name : matmul_v2_0.tmp_0  size: 163840000
# I0303 09:44:35.585162  4938 memory_optimize_pass.cc:216] Cluster name : relu_5.tmp_0  size: 20480000
# --- Running analysis [ir_graph_to_program_pass]
# I0303 09:44:35.607283  4938 analysis_predictor.cc:714] ======= optimize end =======
# I0303 09:44:35.607959  4938 naive_executor.cc:98] ---  skip [feed], feed -> feat_input
# I0303 09:44:35.609778  4938 naive_executor.cc:98] ---  skip [sigmoid_5.tmp_0], fetch -> fetch
# I0303 09:44:35.609805  4938 naive_executor.cc:98] ---  skip [squeeze_4.tmp_0], fetch -> fetch
# I0303 09:44:35.609809  4938 naive_executor.cc:98] ---  skip [squeeze_7.tmp_0], fetch -> fetch
# W0303 09:44:35.632486  4938 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0303 09:44:35.637019  4938 device_context.cc:465] device: 0, cuDNN Version: 7.6.
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/057f73114d1d4fac9bcf3618d511e9b5_11.npy :
# {'score': 7.522357492462106e-08, 'segment': [0, 0.72]}
# {'score': 3.243553692300338e-08, 'segment': [0, 4]}
# {'score': 4.458967280013556e-09, 'segment': [0, 0.76]}
# {'score': 3.055753872160949e-09, 'segment': [0.52, 0.56]}
# {'score': 1.002591787369056e-09, 'segment': [0.56, 0.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f944704c8ec548f995270755784f4314_10.npy :
# {'score': 3.789008769672364e-05, 'segment': [0, 4]}
# {'score': 7.634938015144144e-08, 'segment': [0, 3.2]}
# {'score': 2.5737564968153492e-08, 'segment': [1.68, 4]}
# {'score': 1.9871967182893968e-08, 'segment': [0.48, 4]}
# {'score': 7.097673177526006e-09, 'segment': [0, 3.48]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3927b2feea904f42ace41b73333d4110_10.npy :
# {'score': 1.5306516161217587e-06, 'segment': [2.68, 2.84]}
# {'score': 4.1492521063446475e-07, 'segment': [0, 4]}
# {'score': 2.9063362748284465e-07, 'segment': [2.72, 2.84]}
# {'score': 2.085017570439721e-07, 'segment': [2.68, 2.8000000000000003]}
# {'score': 5.1565809027398156e-08, 'segment': [2.6, 2.84]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/cb1da46eb8fd4f44bc9c5bb7326195cb_35.npy :
# {'score': 0.0053940131329, 'segment': [3.8000000000000003, 4]}
# {'score': 0.001817272393964231, 'segment': [3.36, 4]}
# {'score': 0.0006859853325053722, 'segment': [3.84, 4]}
# {'score': 0.0002707765088416636, 'segment': [0, 4]}
# {'score': 7.547380786303084e-05, 'segment': [3.6, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/708697e09925421e80f28b0ddb6e69fd_81.npy :
# {'score': 0.015978630632162094, 'segment': [0.88, 1.44]}
# {'score': 0.015706026926636696, 'segment': [0.52, 1.36]}
# {'score': 0.00614019762724638, 'segment': [0, 1.4000000000000001]}
# {'score': 0.0021938610982501546, 'segment': [0.52, 1.48]}
# {'score': 0.0014799863645668875, 'segment': [0.88, 1.48]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/80958aaa6654414797f12e372330f793_1.npy :
# {'score': 0.6046925783157349, 'segment': [3.0, 3.84]}
# {'score': 0.2987280786037445, 'segment': [2.36, 3.8000000000000003]}
# {'score': 0.1735171377658844, 'segment': [2.68, 3.64]}
# {'score': 0.1603637933731079, 'segment': [1.8800000000000001, 3.64]}
# {'score': 0.09961496225510204, 'segment': [3.12, 3.7600000000000002]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3c9fd822fdaa4fc0ab6d6c25a831dc0b_16.npy :
# {'score': 0.0019557285122573376, 'segment': [2.36, 4]}
# {'score': 0.0002209643425885588, 'segment': [0, 4]}
# {'score': 0.00020674693463775364, 'segment': [2.08, 4]}
# {'score': 0.00013560587831307203, 'segment': [2.88, 4]}
# {'score': 3.813315197476186e-05, 'segment': [1.24, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f944704c8ec548f995270755784f4314_2.npy :
# {'score': 2.261171516693139e-07, 'segment': [0, 4]}
# {'score': 1.5370085759691676e-10, 'segment': [3.96, 4]}
# {'score': 7.804697860214205e-11, 'segment': [0, 1.44]}
# {'score': 1.4174631954300132e-11, 'segment': [0, 3.52]}
# {'score': 7.207015622144195e-12, 'segment': [0, 1.4000000000000001]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5afb37f7f6e24687bacd002a23101a0a_15.npy :
# {'score': 0.036618925631046295, 'segment': [0, 0.52]}
# {'score': 0.009382274640209383, 'segment': [0, 0.76]}
# {'score': 0.0047565505372658065, 'segment': [0, 0.44]}
# {'score': 0.001438626848163407, 'segment': [0.2, 0.76]}
# {'score': 0.000574791651643072, 'segment': [0, 0.4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3b2156fc21af456cb81431eec9e7aeea_40.npy :
# {'score': 0.0017204734031111002, 'segment': [2.4, 2.88]}
# {'score': 0.0001690869208890713, 'segment': [2.4, 2.92]}
# {'score': 3.714215199579485e-05, 'segment': [2.08, 2.64]}
# {'score': 3.678920984384604e-05, 'segment': [2.36, 2.64]}
# {'score': 1.9122416693562357e-05, 'segment': [2.36, 2.88]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/7a7d32b8c96c42569c103d7b7775f3c1_21.npy :
# {'score': 1.0671597010514233e-06, 'segment': [0, 4]}
# {'score': 3.667948362817697e-07, 'segment': [2.88, 4]}
# {'score': 4.7802047987627657e-08, 'segment': [3.12, 4]}
# {'score': 4.1174954894165e-08, 'segment': [2.52, 4]}
# {'score': 1.662851900618989e-08, 'segment': [3.48, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c255edad12054e329222cfd2d08a968c_29.npy :
# {'score': 1.3846597823885531e-07, 'segment': [0, 4]}
# {'score': 1.71161218531779e-08, 'segment': [3.7600000000000002, 4]}
# {'score': 2.5744548715067594e-09, 'segment': [0, 3.2]}
# {'score': 2.5645210399716234e-09, 'segment': [0, 0.48]}
# {'score': 1.6972098639042978e-09, 'segment': [3.84, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/42305a62416a4697962a93f935d968f4_39.npy :
# {'score': 1.4984078688939917e-07, 'segment': [0, 4]}
# {'score': 3.188669239762021e-08, 'segment': [3.36, 4]}
# {'score': 1.1331426463812022e-08, 'segment': [2.68, 4]}
# {'score': 4.947083810815644e-09, 'segment': [3.52, 4]}
# {'score': 2.3416817374055654e-09, 'segment': [2.68, 2.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f6b672c952734e1b811b7fc3b59f5825_41.npy :
# {'score': 3.5200559977965895e-07, 'segment': [0, 4]}
# {'score': 2.470256776909707e-10, 'segment': [3.2800000000000002, 4]}
# {'score': 9.352897623049472e-11, 'segment': [3.84, 4]}
# {'score': 8.528668049567756e-11, 'segment': [0, 2.16]}
# {'score': 4.092463520843914e-11, 'segment': [1.12, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/654eded26e2f49dbbe34a11d51c44a56_36.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c255edad12054e329222cfd2d08a968c_5.npy :
# {'score': 0.0037594761233776808, 'segment': [2.08, 2.88]}
# {'score': 0.0002737282960680278, 'segment': [2.08, 2.84]}
# {'score': 0.00023778319882694632, 'segment': [2.68, 2.88]}
# {'score': 0.0001623816933715716, 'segment': [0, 4]}
# {'score': 0.00011189831275260076, 'segment': [0, 0.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/210dda53a231423aa0202e5c4b8182f7_3.npy :
# {'score': 1.7169622879009694e-07, 'segment': [0, 4]}
# {'score': 6.287818599126638e-10, 'segment': [1.6, 4]}
# {'score': 4.417032573034163e-10, 'segment': [2.56, 4]}
# {'score': 5.0808723167055364e-11, 'segment': [1.56, 4]}
# {'score': 3.030928980018999e-11, 'segment': [0.64, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/30f514982d9c46d090d0fb246af763c6_16.npy :
# {'score': 0.6662378907203674, 'segment': [1.96, 2.84]}
# {'score': 0.5858375430107117, 'segment': [2.0, 2.52]}
# {'score': 0.33023059368133545, 'segment': [0.4, 2.7600000000000002]}
# {'score': 0.11919704079627991, 'segment': [0.6, 2.12]}
# {'score': 0.11347987502813339, 'segment': [1.6, 2.56]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/a946b48ac6a746f58cc768cd6255bca0_7.npy :
# {'score': 7.705066309426911e-07, 'segment': [0, 4]}
# {'score': 4.115202068000201e-10, 'segment': [0, 2.16]}
# {'score': 1.875780225590873e-10, 'segment': [0, 3.08]}
# {'score': 9.030419467759287e-11, 'segment': [0, 1.48]}
# {'score': 5.936735825162742e-11, 'segment': [3.2, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e17eb57b27044f83a726f7adc99d992e_30.npy :
# {'score': 6.038313949829899e-05, 'segment': [0, 4]}
# {'score': 4.752615723191411e-07, 'segment': [0, 3.6]}
# {'score': 4.636565620330657e-07, 'segment': [0.48, 4]}
# {'score': 1.5229748839828972e-07, 'segment': [0, 1.52]}
# {'score': 2.8928149653839026e-08, 'segment': [0.56, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d41f7085f6d74cbca86d73b33a4e3f6d_65.npy :
# {'score': 0.0001605689903954044, 'segment': [0, 4]}
# {'score': 4.2312044001846516e-07, 'segment': [3.04, 4]}
# {'score': 1.9735915657292935e-07, 'segment': [0.44, 4]}
# {'score': 1.42254052093449e-07, 'segment': [2.04, 4]}
# {'score': 4.562076227898615e-08, 'segment': [1.08, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/9eea1566444f4fcdaafc1ce792752899_12.npy :
# {'score': 6.27898160132645e-08, 'segment': [0, 4]}
# {'score': 5.6208513538047455e-11, 'segment': [2.72, 4]}
# {'score': 5.168678332556631e-11, 'segment': [1.12, 4]}
# {'score': 4.9316283695644e-11, 'segment': [0, 0.04]}
# {'score': 2.3039051569306856e-11, 'segment': [0, 3.52]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3f185aade62c48aaa360f9229f062682_64.npy :
# {'score': 2.3168822735897265e-06, 'segment': [2.84, 4]}
# {'score': 1.441956783310161e-06, 'segment': [3.52, 4]}
# {'score': 1.842692980922326e-07, 'segment': [2.88, 4]}
# {'score': 1.398139328367554e-07, 'segment': [3.56, 4]}
# {'score': 5.921712897816178e-08, 'segment': [3.7600000000000002, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d517fbe2c4674e2886e05b0127c4907c_77.npy :
# {'score': 0.7266555428504944, 'segment': [2.24, 2.88]}
# {'score': 0.6266526579856873, 'segment': [3.2, 4]}
# {'score': 0.5727862119674683, 'segment': [3.16, 3.72]}
# {'score': 0.5532525181770325, 'segment': [2.08, 2.72]}
# {'score': 0.5216927528381348, 'segment': [0.36, 1.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c255edad12054e329222cfd2d08a968c_24.npy :
# {'score': 0.0002999707357957959, 'segment': [2.72, 4]}
# {'score': 0.00011622878082562238, 'segment': [0, 4]}
# {'score': 2.6041200118618732e-05, 'segment': [2.7600000000000002, 4]}
# {'score': 3.952840633427586e-06, 'segment': [3.0, 4]}
# {'score': 2.5517792892060243e-06, 'segment': [3.88, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/21a8679d8928402eadd987541cd48d5e_36.npy :
# {'score': 1.0073211154093542e-09, 'segment': [0, 4]}
# {'score': 2.753301926727847e-12, 'segment': [0, 0.04]}
# {'score': 1.8941235298969294e-12, 'segment': [3.96, 4]}
# {'score': 4.4686482162173413e-13, 'segment': [2.7600000000000002, 4]}
# {'score': 3.0468290108769114e-13, 'segment': [3.68, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8729a808f7784226a5b1eb2cd2ae9906_47.npy :
# {'score': 0.009585588239133358, 'segment': [0, 1.04]}
# {'score': 0.001825836836360395, 'segment': [0, 0.64]}
# {'score': 0.0012267674319446087, 'segment': [0, 0.16]}
# {'score': 0.0009775527795796042, 'segment': [0, 1.2]}
# {'score': 0.0009298372315242887, 'segment': [0, 0.32]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f6b672c952734e1b811b7fc3b59f5825_83.npy :
# {'score': 5.379360956681012e-09, 'segment': [0, 4]}
# {'score': 5.862094143438412e-11, 'segment': [3.16, 4]}
# {'score': 1.7227132914632293e-11, 'segment': [3.96, 4]}
# {'score': 1.553985932989388e-11, 'segment': [3.52, 4]}
# {'score': 7.002343583445425e-12, 'segment': [2.2800000000000002, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/654eded26e2f49dbbe34a11d51c44a56_82.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/21a8679d8928402eadd987541cd48d5e_9.npy :
# {'score': 1.5591494957334362e-05, 'segment': [3.44, 4]}
# {'score': 1.3987691090733279e-05, 'segment': [0, 4]}
# {'score': 3.4753766158246435e-06, 'segment': [3.84, 4]}
# {'score': 1.595881476315704e-06, 'segment': [3.2, 4]}
# {'score': 7.448180667779525e-07, 'segment': [0, 0.96]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b4b7d4cc49ac4e1eb62d64c6a7d2c477_60.npy :
# {'score': 1.9061862985836342e-05, 'segment': [0, 0.48]}
# {'score': 8.987349839196653e-07, 'segment': [0, 0.52]}
# {'score': 4.021344965860465e-08, 'segment': [0, 0.36]}
# {'score': 1.9820146912596925e-10, 'segment': [0, 0.16]}
# {'score': 9.747280760308286e-11, 'segment': [0, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e7d593344d174e4da41f5af61bf56fe5_81.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c69d4d8e6e1041f49b290602732094f1_53.npy :
# {'score': 0.4598696529865265, 'segment': [3.56, 4]}
# {'score': 0.23857571184635162, 'segment': [2.96, 4]}
# {'score': 0.06368412193132618, 'segment': [3.64, 4]}
# {'score': 0.029903502687219852, 'segment': [2.56, 4]}
# {'score': 0.023543527349829674, 'segment': [3.84, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f13db99292654cb9a0972991f5a04e22_13.npy :
# {'score': 1.117343344958499e-05, 'segment': [0, 4]}
# {'score': 5.1134074752212655e-09, 'segment': [3.96, 4]}
# {'score': 1.7837900045947208e-09, 'segment': [2.24, 4]}
# {'score': 4.863143946182056e-10, 'segment': [0.16, 4]}
# {'score': 3.3624192319337e-10, 'segment': [0, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/07bb92c132974cb7adb4b0ad19a87833_12.npy :
# {'score': 0.004225244279950857, 'segment': [0, 0.64]}
# {'score': 0.0023112245835363865, 'segment': [0, 0.36]}
# {'score': 0.0021888772025704384, 'segment': [0, 0.2]}
# {'score': 0.0006909705698490143, 'segment': [0.04, 1.0]}
# {'score': 0.0004852344864048064, 'segment': [0.08, 0.28]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b8ca97fad75f4d2494a4aa95deea7d2b_58.npy :
# {'score': 1.293207105845795e-07, 'segment': [0, 4]}
# {'score': 3.651877064636544e-11, 'segment': [2.68, 4]}
# {'score': 2.4531281520023818e-11, 'segment': [3.52, 4]}
# {'score': 9.69029630842888e-12, 'segment': [3.16, 4]}
# {'score': 5.238983726008062e-12, 'segment': [3.84, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1543002a31f440fb9548da584e713784_79.npy :
# {'score': 0.00016798394790384918, 'segment': [3.52, 4]}
# {'score': 1.874642352805007e-05, 'segment': [3.6, 4]}
# {'score': 4.674267457163103e-06, 'segment': [3.44, 4]}
# {'score': 5.361544970531146e-07, 'segment': [3.16, 4]}
# {'score': 4.961165081152869e-07, 'segment': [3.56, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/ee0e8101162e42b1a915769be2fb54fe_39.npy :
# {'score': 7.532413292210549e-06, 'segment': [0, 4]}
# {'score': 2.3915777092042845e-06, 'segment': [3.48, 4]}
# {'score': 7.39376162073313e-07, 'segment': [2.92, 4]}
# {'score': 1.7193245901073564e-07, 'segment': [3.44, 4]}
# {'score': 4.168516554159396e-08, 'segment': [3.48, 3.7600000000000002]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8818f8ad29e646c68f182eb4f70e717f_68.npy :
# {'score': 0.0009121982147917151, 'segment': [3.4, 4]}
# {'score': 9.994528557258823e-05, 'segment': [3.44, 4]}
# {'score': 7.510925807004691e-06, 'segment': [3.36, 4]}
# {'score': 4.927145255351206e-06, 'segment': [2.56, 4]}
# {'score': 1.0190045713898144e-06, 'segment': [0, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f6b672c952734e1b811b7fc3b59f5825_33.npy :
# {'score': 3.017929941506736e-07, 'segment': [0, 4]}
# {'score': 7.453010986147035e-10, 'segment': [3.84, 4]}
# {'score': 3.747653229413395e-12, 'segment': [0, 1.96]}
# {'score': 3.0184266544552862e-12, 'segment': [3.2800000000000002, 4]}
# {'score': 8.179398732456613e-13, 'segment': [0.16, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/dfb5a171b2ef400a832e5ee7583a5342_81.npy :
# {'score': 1.5614840549460496e-06, 'segment': [0, 4]}
# {'score': 1.571011054579685e-08, 'segment': [2.48, 4]}
# {'score': 1.3255155195679436e-08, 'segment': [0.72, 4]}
# {'score': 8.668340711892597e-09, 'segment': [3.7600000000000002, 4]}
# {'score': 2.0496828678773227e-09, 'segment': [1.4000000000000001, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/258b0fe4dc8643b1af032818f592d4ab_35.npy :
# {'score': 0.7691382169723511, 'segment': [3.4, 4]}
# {'score': 0.6697893142700195, 'segment': [2.16, 4]}
# {'score': 0.2853979468345642, 'segment': [2.96, 4]}
# {'score': 0.13077194974972076, 'segment': [3.52, 3.96]}
# {'score': 0.10391321778297424, 'segment': [1.44, 3.96]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e7d593344d174e4da41f5af61bf56fe5_82.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5192c733730446bfba0c0f2fe722e847_73.npy :
# {'score': 2.3675378542975523e-05, 'segment': [0, 4]}
# {'score': 8.741461670069839e-07, 'segment': [1.28, 4]}
# {'score': 1.8894887432452379e-07, 'segment': [2.08, 4]}
# {'score': 7.021531396753476e-08, 'segment': [1.16, 4]}
# {'score': 2.1370469668897296e-08, 'segment': [0.32, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e17eb57b27044f83a726f7adc99d992e_29.npy :
# {'score': 0.000384399201720953, 'segment': [0, 4]}
# {'score': 0.00015569083916489035, 'segment': [1.2, 4]}
# {'score': 1.3224350836098855e-05, 'segment': [1.24, 4]}
# {'score': 1.0851537281556267e-06, 'segment': [1.16, 4]}
# {'score': 2.5216052974132516e-07, 'segment': [0.16, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b5543a88eded46b9bb8e5ad9346696cc_79.npy :
# {'score': 0.0005846710992045701, 'segment': [0, 0.64]}
# {'score': 0.00010924661910394207, 'segment': [0, 0.24]}
# {'score': 4.4597670910267595e-05, 'segment': [0, 0.68]}
# {'score': 1.1678524189962172e-05, 'segment': [0, 0.4]}
# {'score': 1.0283642027368108e-05, 'segment': [0, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/ab1dfb52fc2f49a3a9dd9439a969ec30_18.npy :
# {'score': 0.00040902916225604713, 'segment': [2.08, 2.6]}
# {'score': 2.6229074661303177e-05, 'segment': [2.08, 2.64]}
# {'score': 1.617266025277786e-05, 'segment': [1.08, 2.64]}
# {'score': 5.826537744724192e-06, 'segment': [0, 2.64]}
# {'score': 1.295077936447342e-06, 'segment': [0, 1.92]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/6f0f599755844336bfba15e5e7c5a758_55.npy :
# {'score': 2.5120381906162947e-05, 'segment': [0, 4]}
# {'score': 1.9472236090223305e-06, 'segment': [1.6, 4]}
# {'score': 9.353586278848525e-07, 'segment': [2.2, 4]}
# {'score': 1.5761575866690691e-07, 'segment': [3.2, 4]}
# {'score': 1.110706762119662e-07, 'segment': [1.6400000000000001, 1.68]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/6f0f599755844336bfba15e5e7c5a758_28.npy :
# {'score': 0.5804396867752075, 'segment': [2.32, 3.6]}
# {'score': 0.4151115119457245, 'segment': [2.84, 3.8000000000000003]}
# {'score': 0.262992799282074, 'segment': [3.2, 3.7600000000000002]}
# {'score': 0.15122774243354797, 'segment': [2.72, 3.52]}
# {'score': 0.11067761480808258, 'segment': [3.0, 3.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5192c733730446bfba0c0f2fe722e847_87.npy :
# {'score': 0.008271779865026474, 'segment': [2.68, 4]}
# {'score': 0.00021588201343547553, 'segment': [3.16, 4]}
# {'score': 5.921975753153674e-05, 'segment': [0, 4]}
# {'score': 2.663449806652954e-05, 'segment': [2.84, 4]}
# {'score': 2.5232835534595183e-06, 'segment': [2.32, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f13db99292654cb9a0972991f5a04e22_88.npy :
# {'score': 0.7309675812721252, 'segment': [0, 0.72]}
# {'score': 0.415804922580719, 'segment': [0, 0.4]}
# {'score': 0.13327113205823185, 'segment': [0.08, 0.52]}
# {'score': 0.12459169328212738, 'segment': [1.04, 1.6400000000000001]}
# {'score': 0.06630310591346884, 'segment': [0, 0.76]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/6f501723d5a24c9680d9a8d237afdadf_60.npy :
# {'score': 1.6438765015891477e-08, 'segment': [0, 4]}
# {'score': 7.351995123805466e-10, 'segment': [1.48, 4]}
# {'score': 9.890101931864237e-11, 'segment': [0.44, 4]}
# {'score': 5.60825390004397e-11, 'segment': [1.44, 4]}
# {'score': 8.574013027340399e-12, 'segment': [0, 0.04]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3c9fd822fdaa4fc0ab6d6c25a831dc0b_19.npy :
# {'score': 8.169750032038792e-08, 'segment': [0, 4]}
# {'score': 9.568800612980155e-11, 'segment': [0.6, 4]}
# {'score': 3.912961274443738e-11, 'segment': [2.84, 4]}
# {'score': 3.6055141511281974e-11, 'segment': [3.96, 4]}
# {'score': 3.42462481983663e-11, 'segment': [0, 1.6400000000000001]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/85760f00dfa745359a8ad48f5d375fd9_76.npy :
# {'score': 0.02231154404580593, 'segment': [2.96, 4]}
# {'score': 0.005782994907349348, 'segment': [3.68, 4]}
# {'score': 0.002073163507230617, 'segment': [3.0, 4]}
# {'score': 0.0005860441591833333, 'segment': [3.72, 4]}
# {'score': 0.00019289387273602188, 'segment': [0, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b5543a88eded46b9bb8e5ad9346696cc_2.npy :
# {'score': 0.12665948271751404, 'segment': [0, 1.0]}
# {'score': 0.01567324623465538, 'segment': [0, 2.36]}
# {'score': 0.008202128429698733, 'segment': [0, 1.04]}
# {'score': 0.005558410193771124, 'segment': [0, 0.56]}
# {'score': 0.0021024320740252733, 'segment': [0, 1.68]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/758811836ae54795b4fef6311b1b9287_61.npy :
# {'score': 1.3854844382876763e-07, 'segment': [0, 4]}
# {'score': 3.130959935759847e-10, 'segment': [2.84, 4]}
# {'score': 4.615137048352562e-11, 'segment': [3.16, 4]}
# {'score': 2.8300424503857613e-11, 'segment': [3.8000000000000003, 4]}
# {'score': 2.612900347476188e-11, 'segment': [1.6, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c27ae95d3b7a418193fc8a828db1a1d9_53.npy :
# {'score': 0.002340790582820773, 'segment': [0, 4]}
# {'score': 2.2683920178678818e-05, 'segment': [1.84, 4]}
# {'score': 1.463558078285132e-06, 'segment': [0, 0.28]}
# {'score': 1.3216670140536735e-06, 'segment': [3.68, 4]}
# {'score': 1.2817545027554861e-06, 'segment': [1.44, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/9a366e6b8978477e8a3cd90c073d1f01_37.npy :
# {'score': 8.98722532838292e-07, 'segment': [0.96, 4]}
# {'score': 8.206338293348381e-07, 'segment': [0, 4]}
# {'score': 8.103040016749219e-08, 'segment': [3.64, 4]}
# {'score': 6.36336233689155e-08, 'segment': [0.92, 4]}
# {'score': 5.2954089113654845e-08, 'segment': [1.52, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5afb37f7f6e24687bacd002a23101a0a_89.npy :
# {'score': 0.0024313104804605246, 'segment': [0.24, 4]}
# {'score': 0.0001960821999425592, 'segment': [0.2, 4]}
# {'score': 1.1622336153054504e-05, 'segment': [0.28, 4]}
# {'score': 6.97143832439906e-07, 'segment': [0.8, 4]}
# {'score': 3.453326559075928e-07, 'segment': [0, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/58e0ffc7c65b4f51b0e7e8d30b51479c_17.npy :
# {'score': 0.2439923733472824, 'segment': [1.28, 4]}
# {'score': 0.20533958077430725, 'segment': [2.12, 4]}
# {'score': 0.0683213472366333, 'segment': [1.12, 3.48]}
# {'score': 0.037932638078927994, 'segment': [3.52, 4]}
# {'score': 0.03777443245053291, 'segment': [2.72, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c27ae95d3b7a418193fc8a828db1a1d9_46.npy :
# {'score': 0.733900785446167, 'segment': [3.44, 4]}
# {'score': 0.7238911986351013, 'segment': [0.68, 1.24]}
# {'score': 0.6847070455551147, 'segment': [2.72, 3.16]}
# {'score': 0.6553385853767395, 'segment': [1.84, 2.4]}
# {'score': 0.6062573194503784, 'segment': [2.6, 3.04]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e7d593344d174e4da41f5af61bf56fe5_21.npy :
# {'score': 9.605087143427227e-06, 'segment': [1.24, 4]}
# {'score': 8.519107723259367e-06, 'segment': [2.44, 4]}
# {'score': 8.933729587686515e-07, 'segment': [1.32, 4]}
# {'score': 8.781238989286066e-07, 'segment': [0, 4]}
# {'score': 6.100788515309589e-07, 'segment': [2.36, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b14c5b11a31d418e959c289ea69b5519_68.npy :
# {'score': 2.493851297913352e-06, 'segment': [0, 4]}
# {'score': 1.511319709379677e-07, 'segment': [3.36, 4]}
# {'score': 8.392393624490069e-08, 'segment': [0, 0.4]}
# {'score': 3.04806242468203e-08, 'segment': [0, 0.08]}
# {'score': 2.864206294361793e-08, 'segment': [0, 0.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8fd4f6414e1e43b4bdce436a998e093a_14.npy :
# {'score': 0.18807335197925568, 'segment': [1.4000000000000001, 2.84]}
# {'score': 0.173709899187088, 'segment': [0, 2.12]}
# {'score': 0.14531497657299042, 'segment': [1.36, 2.12]}
# {'score': 0.038562238216400146, 'segment': [1.6, 2.24]}
# {'score': 0.03103121090892386, 'segment': [1.36, 2.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d517fbe2c4674e2886e05b0127c4907c_32.npy :
# {'score': 2.940875845069968e-07, 'segment': [0, 4]}
# {'score': 2.293434278044515e-07, 'segment': [0, 3.48]}
# {'score': 1.16427088414639e-07, 'segment': [0, 0.6]}
# {'score': 6.365513627315522e-08, 'segment': [0, 1.24]}
# {'score': 2.914006103083011e-08, 'segment': [0, 0.24]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5192c733730446bfba0c0f2fe722e847_81.npy :
# {'score': 0.00026540097314864397, 'segment': [3.52, 4]}
# {'score': 0.00017836796178016812, 'segment': [1.84, 4]}
# {'score': 0.0001464358501834795, 'segment': [0, 4]}
# {'score': 0.00013509317068383098, 'segment': [3.8000000000000003, 4]}
# {'score': 2.3171153237212242e-05, 'segment': [3.36, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/58e0ffc7c65b4f51b0e7e8d30b51479c_41.npy :
# {'score': 0.7227988839149475, 'segment': [2.04, 2.56]}
# {'score': 0.6770487427711487, 'segment': [0.92, 1.44]}
# {'score': 0.6573120355606079, 'segment': [1.8, 2.48]}
# {'score': 0.5133440494537354, 'segment': [0.6, 1.32]}
# {'score': 0.27441102266311646, 'segment': [0.84, 1.24]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/572b44d2723642428b60fac24416a727_34.npy :
# {'score': 0.6913741827011108, 'segment': [0.4, 1.12]}
# {'score': 0.6788758039474487, 'segment': [1.56, 2.12]}
# {'score': 0.662413477897644, 'segment': [1.76, 2.2]}
# {'score': 0.635313093662262, 'segment': [1.6, 2.44]}
# {'score': 0.4620245099067688, 'segment': [1.8800000000000001, 2.4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/4d92cc4a3cab4dd29d67c06cfa36bddb_83.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/ff35f365439649a6b026ec370685e551_46.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/69ae1c7a478f4716b8c46a9a82f1fe94_10.npy :
# {'score': 0.6910858154296875, 'segment': [1.16, 1.6400000000000001]}
# {'score': 0.6391537189483643, 'segment': [0, 0.6]}
# {'score': 0.5578505992889404, 'segment': [1.0, 1.52]}
# {'score': 0.42136383056640625, 'segment': [0, 0.36]}
# {'score': 0.3459377884864807, 'segment': [1.32, 1.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/80958aaa6654414797f12e372330f793_29.npy :
# {'score': 6.396929165930487e-06, 'segment': [0, 4]}
# {'score': 1.0546609985340183e-07, 'segment': [3.2, 4]}
# {'score': 8.060781908625358e-08, 'segment': [0.64, 4]}
# {'score': 5.6653895796898723e-08, 'segment': [0, 0.04]}
# {'score': 4.574803824652918e-08, 'segment': [1.28, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f13db99292654cb9a0972991f5a04e22_17.npy :
# {'score': 9.433747618459165e-05, 'segment': [0, 4]}
# {'score': 1.6120813597808592e-05, 'segment': [0.88, 4]}
# {'score': 1.18408379421453e-05, 'segment': [1.48, 4]}
# {'score': 3.1544445348029887e-06, 'segment': [0.08, 4]}
# {'score': 2.121435272783856e-06, 'segment': [2.08, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3927b2feea904f42ace41b73333d4110_78.npy :
# {'score': 5.3246199058776256e-06, 'segment': [0, 0.24]}
# {'score': 3.540040324878646e-06, 'segment': [0, 4]}
# {'score': 6.485143025206695e-07, 'segment': [0, 0.2]}
# {'score': 7.606438146012806e-08, 'segment': [0, 0.44]}
# {'score': 6.799427646769701e-08, 'segment': [0, 0.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/158cfaf7a1c8409da5e761c4e8c62277_17.npy :
# {'score': 0.00043954653665423393, 'segment': [0, 4]}
# {'score': 7.469711500518498e-07, 'segment': [0.04, 4]}
# {'score': 6.899866775711416e-07, 'segment': [0.72, 4]}
# {'score': 2.5144572646240704e-07, 'segment': [0, 1.12]}
# {'score': 2.234796028233177e-07, 'segment': [0, 2.08]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/158cfaf7a1c8409da5e761c4e8c62277_45.npy :
# {'score': 1.4219510546809033e-07, 'segment': [0, 4]}
# {'score': 1.4458894082025608e-09, 'segment': [0, 0.16]}
# {'score': 7.419010961129402e-10, 'segment': [0, 0.08]}
# {'score': 9.859155158942201e-11, 'segment': [0, 0.48]}
# {'score': 6.236444000107255e-11, 'segment': [0, 1.48]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/2a8fff4d41764654ae0dddae7033bb88_78.npy :
# {'score': 4.8245315298345304e-08, 'segment': [0, 4]}
# {'score': 3.4158316175592063e-09, 'segment': [0, 0.2]}
# {'score': 9.987676241607346e-10, 'segment': [0, 0.08]}
# {'score': 3.54510421018972e-10, 'segment': [0, 3.56]}
# {'score': 2.6213006765196667e-10, 'segment': [3.96, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/30f514982d9c46d090d0fb246af763c6_28.npy :
# {'score': 9.318854949924571e-07, 'segment': [0, 4]}
# {'score': 1.162936325016517e-08, 'segment': [3.2800000000000002, 4]}
# {'score': 1.7646467210009063e-09, 'segment': [3.04, 4]}
# {'score': 2.54476157932223e-10, 'segment': [3.24, 4]}
# {'score': 9.07730765553616e-11, 'segment': [2.48, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8818f8ad29e646c68f182eb4f70e717f_65.npy :
# {'score': 6.006544595038577e-08, 'segment': [0, 4]}
# {'score': 7.801375656590892e-10, 'segment': [3.68, 4]}
# {'score': 1.0576937242712248e-10, 'segment': [3.96, 4]}
# {'score': 8.958616104064394e-11, 'segment': [3.52, 4]}
# {'score': 6.482522502770835e-11, 'segment': [3.72, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e7d593344d174e4da41f5af61bf56fe5_13.npy :
# {'score': 0.7232061624526978, 'segment': [0.12, 0.72]}
# {'score': 0.4205675423145294, 'segment': [0, 0.52]}
# {'score': 0.30051809549331665, 'segment': [1.04, 1.52]}
# {'score': 0.2038416862487793, 'segment': [0.2, 0.56]}
# {'score': 0.18494847810460116, 'segment': [0, 0.88]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e17eb57b27044f83a726f7adc99d992e_64.npy :
# {'score': 8.609631230171999e-09, 'segment': [0, 4]}
# {'score': 2.383460651067537e-10, 'segment': [2.68, 4]}
# {'score': 3.085009678271966e-11, 'segment': [3.3200000000000003, 4]}
# {'score': 2.026960543854983e-11, 'segment': [0, 3.56]}
# {'score': 5.8525058560437985e-12, 'segment': [2.84, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b5543a88eded46b9bb8e5ad9346696cc_72.npy :
# {'score': 0.04290363937616348, 'segment': [2.72, 3.52]}
# {'score': 0.02669479325413704, 'segment': [1.52, 3.48]}
# {'score': 0.006337265484035015, 'segment': [2.08, 3.48]}
# {'score': 0.0040430159132964225, 'segment': [2.72, 3.48]}
# {'score': 0.002842705306764736, 'segment': [1.2, 3.48]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/afd03d630b6e4a868037fdf78925f4d2_66.npy :
# {'score': 1.0889227723964723e-06, 'segment': [0, 0.48]}
# {'score': 4.88452769786818e-07, 'segment': [0, 0.24]}
# {'score': 3.490108042569773e-07, 'segment': [0, 4]}
# {'score': 7.795036574701227e-08, 'segment': [0, 0.16]}
# {'score': 3.338502643812524e-08, 'segment': [0, 0.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/6f501723d5a24c9680d9a8d237afdadf_29.npy :
# {'score': 2.883928829078286e-08, 'segment': [0, 4]}
# {'score': 6.719585443626386e-10, 'segment': [0, 0.04]}
# {'score': 1.2647775882168588e-10, 'segment': [3.96, 4]}
# {'score': 7.447388294197837e-12, 'segment': [0, 3.8000000000000003]}
# {'score': 6.690740409626139e-12, 'segment': [0, 0.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c65345af9a3d47a880dcaa12e8c5655d_32.npy :
# {'score': 1.3999525663166423e-06, 'segment': [0, 4]}
# {'score': 2.7007232006326376e-07, 'segment': [2.6, 4]}
# {'score': 4.727884928001913e-08, 'segment': [3.36, 4]}
# {'score': 1.6880369077628642e-08, 'segment': [2.56, 4]}
# {'score': 3.797941072747335e-09, 'segment': [0.8, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1543002a31f440fb9548da584e713784_85.npy :
# {'score': 1.9989590782643063e-06, 'segment': [0, 4]}
# {'score': 2.1495314683761535e-07, 'segment': [0, 0.2]}
# {'score': 3.6571605322401923e-08, 'segment': [0, 0.24]}
# {'score': 1.2308350783030164e-08, 'segment': [3.16, 4]}
# {'score': 9.785372056594365e-09, 'segment': [0, 0.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/054580f7258e41d0b43dfde10a1eb942_60.npy :
# {'score': 9.736510264701792e-07, 'segment': [0, 4]}
# {'score': 4.3473447064457105e-10, 'segment': [0, 3.56]}
# {'score': 1.1349816225747489e-10, 'segment': [0.52, 4]}
# {'score': 1.0296253433184077e-10, 'segment': [0, 3.0]}
# {'score': 2.5195701902271223e-11, 'segment': [0, 3.88]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/58e0ffc7c65b4f51b0e7e8d30b51479c_35.npy :
# {'score': 1.695998253126163e-05, 'segment': [0, 4]}
# {'score': 7.404904778240962e-08, 'segment': [3.68, 4]}
# {'score': 2.1470029309966776e-08, 'segment': [2.88, 4]}
# {'score': 1.9031730857932416e-08, 'segment': [3.36, 4]}
# {'score': 1.3115891484005715e-08, 'segment': [0.52, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b5543a88eded46b9bb8e5ad9346696cc_6.npy :
# {'score': 2.7170259272679687e-05, 'segment': [0, 4]}
# {'score': 2.406176804470306e-07, 'segment': [0, 3.36]}
# {'score': 2.2286729972620378e-07, 'segment': [1.48, 4]}
# {'score': 1.001981431159038e-07, 'segment': [2.08, 4]}
# {'score': 8.395009132300402e-08, 'segment': [0.48, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/85a24864079f4456894537f3186fdbbf_53.npy :
# {'score': 1.7481829672760796e-06, 'segment': [0, 4]}
# {'score': 1.3689815432371688e-06, 'segment': [0, 0.48]}
# {'score': 1.325317526834624e-07, 'segment': [0, 0.16]}
# {'score': 1.2793250489399104e-07, 'segment': [0, 0.52]}
# {'score': 2.8559533404859394e-08, 'segment': [0, 1.48]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/572b44d2723642428b60fac24416a727_49.npy :
# {'score': 4.470793101063464e-06, 'segment': [0, 4]}
# {'score': 2.4925892461169497e-08, 'segment': [2.56, 4]}
# {'score': 5.401918214334743e-09, 'segment': [0, 3.72]}
# {'score': 3.4362062261514024e-09, 'segment': [2.84, 4]}
# {'score': 4.5198106368715685e-10, 'segment': [1.44, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/30f514982d9c46d090d0fb246af763c6_64.npy :
# {'score': 1.352074434635142e-07, 'segment': [0, 4]}
# {'score': 5.495853772075066e-10, 'segment': [0.52, 4]}
# {'score': 1.8079697461370614e-10, 'segment': [0, 0.04]}
# {'score': 7.786744166127235e-11, 'segment': [1.08, 4]}
# {'score': 2.323595309217108e-11, 'segment': [0, 3.56]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/dfb5a171b2ef400a832e5ee7583a5342_85.npy :
# {'score': 0.730086624622345, 'segment': [1.4000000000000001, 1.92]}
# {'score': 0.32720282673835754, 'segment': [1.28, 1.76]}
# {'score': 0.24089671671390533, 'segment': [1.56, 2.04]}
# {'score': 0.1451507483707041, 'segment': [1.48, 1.84]}
# {'score': 0.054790256271535775, 'segment': [1.36, 1.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/4465ea724e614d52ba740a8fa4e4e345_21.npy :
# {'score': 0.02078203856945038, 'segment': [3.48, 4]}
# {'score': 0.0077818576246500015, 'segment': [0, 4]}
# {'score': 0.0022666869345600235, 'segment': [3.2, 4]}
# {'score': 0.0021602380486922174, 'segment': [3.52, 4]}
# {'score': 0.0014516557566821575, 'segment': [0.44, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/bbe2589af6574fa492e0eab317d82e69_3.npy :
# {'score': 4.3886950152227655e-05, 'segment': [0, 0.76]}
# {'score': 5.938338451262485e-06, 'segment': [0, 0.52]}
# {'score': 3.299484887975268e-06, 'segment': [0, 4]}
# {'score': 1.6727520915083005e-06, 'segment': [0, 0.16]}
# {'score': 9.022408719246303e-07, 'segment': [0, 0.44]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/07bb92c132974cb7adb4b0ad19a87833_43.npy :
# {'score': 1.0584165011096047e-07, 'segment': [0, 4]}
# {'score': 9.849736581912794e-10, 'segment': [0, 0.04]}
# {'score': 3.4156052985956364e-11, 'segment': [1.32, 4]}
# {'score': 2.0141600193257503e-11, 'segment': [0, 0.08]}
# {'score': 8.054794319086767e-12, 'segment': [0.36, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/467ec2a9514a4c75b733ca1afd979ec9_19.npy :
# {'score': 0.023142458871006966, 'segment': [1.76, 4]}
# {'score': 0.0019338180242548483, 'segment': [1.8, 4]}
# {'score': 0.0016688856994733214, 'segment': [0, 4]}
# {'score': 0.00034646838321350515, 'segment': [0.96, 4]}
# {'score': 0.0001597355597890753, 'segment': [1.84, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f6b672c952734e1b811b7fc3b59f5825_85.npy :
# {'score': 6.351530146275763e-08, 'segment': [0, 4]}
# {'score': 2.1461583621373848e-09, 'segment': [2.48, 4]}
# {'score': 1.5934648045501376e-10, 'segment': [0.84, 4]}
# {'score': 7.18130763188718e-11, 'segment': [3.96, 4]}
# {'score': 6.770588256710397e-11, 'segment': [2.84, 2.88]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/85886e3bb7d841c487890a47d68f0375_14.npy :
# {'score': 0.19635815918445587, 'segment': [0, 0.36]}
# {'score': 0.16290704905986786, 'segment': [0, 0.96]}
# {'score': 0.021670741751829238, 'segment': [0, 0.32]}
# {'score': 0.012822463177144527, 'segment': [0, 0.16]}
# {'score': 0.011226475028777305, 'segment': [0, 0.92]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/258b0fe4dc8643b1af032818f592d4ab_14.npy :
# {'score': 0.7783941030502319, 'segment': [0.04, 0.64]}
# {'score': 0.29587945342063904, 'segment': [0.2, 0.56]}
# {'score': 0.11742217385796123, 'segment': [0.08, 0.72]}
# {'score': 0.017572995320582475, 'segment': [0, 0.64]}
# {'score': 0.013641574420034885, 'segment': [0, 0.36]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/38ea214a5b524c93aed2c86e0be99571_41.npy :
# {'score': 9.571164264343679e-05, 'segment': [0, 4]}
# {'score': 2.7685435270541348e-05, 'segment': [2.48, 4]}
# {'score': 4.845715466217371e-06, 'segment': [3.16, 4]}
# {'score': 2.4637431824258623e-06, 'segment': [2.52, 4]}
# {'score': 1.370213430393523e-07, 'segment': [2.44, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/38ea214a5b524c93aed2c86e0be99571_60.npy :
# {'score': 1.8370901466724376e-09, 'segment': [0, 4]}
# {'score': 1.9369761350418457e-10, 'segment': [3.96, 4]}
# {'score': 1.2794128603776933e-11, 'segment': [3.16, 4]}
# {'score': 1.5171058853624686e-12, 'segment': [1.72, 4]}
# {'score': 1.1785641906847388e-12, 'segment': [0.88, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8408dbe31c43436780723fc47a714123_46.npy :
# {'score': 4.10859456678736e-07, 'segment': [0, 4]}
# {'score': 4.1130898686958517e-10, 'segment': [3.24, 4]}
# {'score': 1.5679485487751776e-10, 'segment': [3.92, 4]}
# {'score': 7.100633275802792e-11, 'segment': [0.72, 4]}
# {'score': 6.60337340363526e-11, 'segment': [2.52, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/758811836ae54795b4fef6311b1b9287_76.npy :
# {'score': 2.9369077765295515e-06, 'segment': [0, 4]}
# {'score': 1.0017412677143511e-07, 'segment': [0, 0.76]}
# {'score': 3.623253164164453e-08, 'segment': [0, 2.32]}
# {'score': 1.5135885433892327e-08, 'segment': [0, 1.4000000000000001]}
# {'score': 1.0560696371758592e-08, 'segment': [0, 0.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b4b7d4cc49ac4e1eb62d64c6a7d2c477_57.npy :
# {'score': 1.7857908005680656e-06, 'segment': [0, 4]}
# {'score': 5.492115651151153e-10, 'segment': [3.52, 4]}
# {'score': 1.5523561602837077e-10, 'segment': [3.88, 4]}
# {'score': 8.7543583493499e-11, 'segment': [2.88, 4]}
# {'score': 8.456227384989745e-11, 'segment': [0.64, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8fd4f6414e1e43b4bdce436a998e093a_3.npy :
# {'score': 2.423142177576665e-06, 'segment': [0, 4]}
# {'score': 4.156533783827854e-09, 'segment': [0, 2.64]}
# {'score': 7.361240506043032e-10, 'segment': [0, 0.24]}
# {'score': 4.132726660888153e-10, 'segment': [2.08, 4]}
# {'score': 3.691996985910606e-10, 'segment': [3.8000000000000003, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3420c6f5635541ffbd0857a1d171f9a7_76.npy :
# {'score': 3.758363891392946e-05, 'segment': [0, 4]}
# {'score': 5.849042736372212e-06, 'segment': [0, 0.08]}
# {'score': 4.5490542106563225e-06, 'segment': [0, 0.16]}
# {'score': 9.770119504537433e-07, 'segment': [0.04, 0.08]}
# {'score': 8.103253890112683e-07, 'segment': [0.72, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/86338686b5554b88850b2d09f024c27b_67.npy :
# {'score': 1.0078502782562282e-05, 'segment': [0, 0.88]}
# {'score': 2.6442864964337787e-06, 'segment': [0, 4]}
# {'score': 7.644986136947866e-07, 'segment': [0, 0.84]}
# {'score': 1.6529303081824764e-07, 'segment': [0.96, 1.08]}
# {'score': 9.675365898697941e-08, 'segment': [0, 1.08]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b5543a88eded46b9bb8e5ad9346696cc_65.npy :
# {'score': 2.089239023916889e-05, 'segment': [0, 1.44]}
# {'score': 3.97330359191983e-06, 'segment': [0, 2.4]}
# {'score': 3.971636239101436e-06, 'segment': [0, 1.16]}
# {'score': 9.545142364163268e-07, 'segment': [0, 1.76]}
# {'score': 3.590959352095524e-07, 'segment': [0, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8515e5a9e8764f1db6b617666bba4166_21.npy :
# {'score': 2.6199542091376316e-08, 'segment': [0, 0.52]}
# {'score': 4.9327684159550245e-09, 'segment': [0, 4]}
# {'score': 3.4573284960982027e-09, 'segment': [0, 0.36]}
# {'score': 2.861528347608555e-09, 'segment': [0, 1.68]}
# {'score': 5.895305037356308e-10, 'segment': [0, 0.56]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/6f501723d5a24c9680d9a8d237afdadf_11.npy :
# {'score': 1.1638368135891142e-07, 'segment': [0, 4]}
# {'score': 2.047653380188308e-09, 'segment': [1.8800000000000001, 4]}
# {'score': 3.1127841970679526e-10, 'segment': [2.56, 4]}
# {'score': 1.6184157570977713e-10, 'segment': [1.6, 4]}
# {'score': 1.338055499733315e-10, 'segment': [3.16, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/758811836ae54795b4fef6311b1b9287_52.npy :
# {'score': 9.696927918412257e-07, 'segment': [0, 0.32]}
# {'score': 6.558893232977425e-07, 'segment': [0, 0.68]}
# {'score': 6.760805604244524e-08, 'segment': [0, 4]}
# {'score': 1.6813917004275165e-08, 'segment': [0, 0.96]}
# {'score': 2.7660258528072745e-09, 'segment': [0, 0.08]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/05d1855aafd3401998f49ef16fa39da3_3.npy :
# {'score': 0.00018274989270139486, 'segment': [0, 4]}
# {'score': 4.905297464574687e-05, 'segment': [2.48, 4]}
# {'score': 4.3733489292208105e-05, 'segment': [3.08, 4]}
# {'score': 2.805954500217922e-05, 'segment': [3.48, 4]}
# {'score': 9.85251972451806e-06, 'segment': [1.76, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/86338686b5554b88850b2d09f024c27b_21.npy :
# {'score': 0.7934438586235046, 'segment': [3.64, 4]}
# {'score': 0.7655717134475708, 'segment': [0.44, 0.88]}
# {'score': 0.7366749048233032, 'segment': [1.24, 1.84]}
# {'score': 0.7228067517280579, 'segment': [2.72, 3.2800000000000002]}
# {'score': 0.6820430159568787, 'segment': [2.16, 3.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/654eded26e2f49dbbe34a11d51c44a56_66.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/4d92cc4a3cab4dd29d67c06cfa36bddb_69.npy :
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d41f7085f6d74cbca86d73b33a4e3f6d_66.npy :
# {'score': 0.6653532385826111, 'segment': [0.76, 1.2]}
# {'score': 0.5528689622879028, 'segment': [0.4, 1.16]}
# {'score': 0.5298050045967102, 'segment': [0.64, 1.08]}
# {'score': 0.3989337086677551, 'segment': [0.92, 1.24]}
# {'score': 0.25882235169410706, 'segment': [0.88, 1.12]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/38ea214a5b524c93aed2c86e0be99571_12.npy :
# {'score': 2.963440920211724e-06, 'segment': [3.52, 4]}
# {'score': 3.283488794360903e-07, 'segment': [3.48, 4]}
# {'score': 1.628463337510766e-07, 'segment': [2.84, 4]}
# {'score': 4.335412384648407e-08, 'segment': [0, 4]}
# {'score': 2.612928809824211e-08, 'segment': [3.56, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/80958aaa6654414797f12e372330f793_72.npy :
# {'score': 0.7919169068336487, 'segment': [0.16, 0.76]}
# {'score': 0.44358623027801514, 'segment': [0, 1.0]}
# {'score': 0.3527771830558777, 'segment': [0, 0.6]}
# {'score': 0.24468913674354553, 'segment': [0.16, 0.52]}
# {'score': 0.13219532437914613, 'segment': [0.24, 0.68]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c255edad12054e329222cfd2d08a968c_68.npy :
# ...
# {'score': 4.3432549223787476e-12, 'segment': [0, 3.56]}
# {'score': 1.0600207777516912e-12, 'segment': [0, 0.08]}
# {'score': 3.102305055012084e-13, 'segment': [0.12, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/98f9cb7fdddd44be9645cf4797681bc0_31.npy :
# {'score': 0.7775328159332275, 'segment': [2.24, 2.84]}
# {'score': 0.6881718039512634, 'segment': [3.12, 4]}
# {'score': 0.43583714962005615, 'segment': [2.0, 2.72]}
# {'score': 0.3572481870651245, 'segment': [2.32, 2.68]}
# {'score': 0.23608671128749847, 'segment': [3.48, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c81660f7884a469abb41554586799781_87.npy :
# {'score': 8.63966731490251e-10, 'segment': [0, 4]}
# {'score': 5.80279227446745e-11, 'segment': [3.96, 4]}
# {'score': 1.599962697051982e-11, 'segment': [2.56, 4]}
# {'score': 1.0357645730679765e-12, 'segment': [3.2, 4]}
# {'score': 8.131932408559279e-13, 'segment': [2.6, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e17eb57b27044f83a726f7adc99d992e_28.npy :
# {'score': 2.1957248463877477e-06, 'segment': [0, 4]}
# {'score': 1.3810379186907085e-06, 'segment': [0, 0.28]}
# {'score': 4.701257410033577e-07, 'segment': [0, 0.16]}
# {'score': 3.1668452038502437e-07, 'segment': [0, 0.52]}
# {'score': 9.292703140317826e-08, 'segment': [0.16, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d517fbe2c4674e2886e05b0127c4907c_79.npy :
# {'score': 5.848521595908096e-07, 'segment': [0, 4]}
# {'score': 2.36268835607234e-08, 'segment': [2.2, 4]}
# {'score': 4.712786161320537e-09, 'segment': [1.0, 4]}
# {'score': 4.041460943682296e-09, 'segment': [2.2, 2.64]}
# {'score': 3.99684241259024e-09, 'segment': [1.84, 2.36]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1609d62a3ec2450bb17468dd17ff9191_27.npy :
# {'score': 0.1134069412946701, 'segment': [0, 0.28]}
# {'score': 0.01598227662971801, 'segment': [0, 0.32]}
# {'score': 0.0033027308489622553, 'segment': [0, 0.24]}
# {'score': 0.0005367574404267227, 'segment': [0, 0.36]}
# {'score': 0.0004914928242148841, 'segment': [0, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8818f8ad29e646c68f182eb4f70e717f_54.npy :
# {'score': 2.2752212316845544e-05, 'segment': [0, 4]}
# {'score': 9.940545169229154e-07, 'segment': [0, 2.6]}
# {'score': 8.371189383851964e-08, 'segment': [0, 2.68]}
# {'score': 7.0105368373020955e-09, 'segment': [0, 2.64]}
# {'score': 6.649106154554829e-09, 'segment': [0, 3.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/3927b2feea904f42ace41b73333d4110_66.npy :
# {'score': 8.351577889698092e-06, 'segment': [2.72, 4]}
# {'score': 1.3809202528136666e-06, 'segment': [0, 4]}
# {'score': 6.466863043187873e-07, 'segment': [3.04, 4]}
# {'score': 1.4223757650033482e-07, 'segment': [2.68, 4]}
# {'score': 9.879595097572746e-08, 'segment': [3.68, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b4b7d4cc49ac4e1eb62d64c6a7d2c477_43.npy :
# {'score': 0.064925417304039, 'segment': [1.6, 1.96]}
# {'score': 0.015993760722796922, 'segment': [1.44, 1.96]}
# {'score': 0.005523640292892514, 'segment': [1.68, 1.96]}
# {'score': 0.004855074919760227, 'segment': [0, 0.76]}
# {'score': 0.0013982298551127315, 'segment': [1.6, 2.4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/85760f00dfa745359a8ad48f5d375fd9_24.npy :
# {'score': 0.20841336250305176, 'segment': [1.76, 2.08]}
# {'score': 0.04055197164416313, 'segment': [1.16, 1.92]}
# {'score': 0.027032749717403277, 'segment': [1.72, 2.08]}
# {'score': 0.005003295838832855, 'segment': [1.72, 1.92]}
# {'score': 0.004401940092119148, 'segment': [1.16, 1.84]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8515e5a9e8764f1db6b617666bba4166_80.npy :
# {'score': 1.0334969374525826e-05, 'segment': [3.16, 4]}
# {'score': 8.526239489778065e-07, 'segment': [3.12, 4]}
# {'score': 7.653624152226257e-07, 'segment': [0.52, 0.56]}
# {'score': 7.475429129044642e-07, 'segment': [0, 4]}
# {'score': 5.14740690960025e-07, 'segment': [0.56, 0.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/c65345af9a3d47a880dcaa12e8c5655d_36.npy :
# {'score': 0.7315608263015747, 'segment': [3.08, 4]}
# {'score': 0.7097873091697693, 'segment': [2.24, 2.72]}
# {'score': 0.6992576122283936, 'segment': [1.2, 1.76]}
# {'score': 0.6738015413284302, 'segment': [0.56, 1.76]}
# {'score': 0.5389649271965027, 'segment': [3.16, 3.72]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8729a808f7784226a5b1eb2cd2ae9906_84.npy :
# {'score': 7.570092293462949e-06, 'segment': [0, 4]}
# {'score': 6.735828605997085e-08, 'segment': [1.8, 4]}
# {'score': 5.121462365309526e-08, 'segment': [0.96, 4]}
# {'score': 1.2173018149042036e-08, 'segment': [3.3200000000000003, 4]}
# {'score': 5.9402714016477606e-09, 'segment': [2.08, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/758811836ae54795b4fef6311b1b9287_40.npy :
# {'score': 2.122834956708175e-07, 'segment': [1.68, 4]}
# {'score': 4.766661731991917e-08, 'segment': [2.7600000000000002, 4]}
# {'score': 2.635873030953917e-08, 'segment': [3.68, 4]}
# {'score': 2.5276122120513813e-08, 'segment': [1.8800000000000001, 4]}
# {'score': 1.762630041923785e-08, 'segment': [3.2, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/e17eb57b27044f83a726f7adc99d992e_76.npy :
# {'score': 1.8491667219677765e-07, 'segment': [0, 4]}
# {'score': 8.527227257637549e-10, 'segment': [3.2, 4]}
# {'score': 7.072021857013056e-10, 'segment': [0.92, 4]}
# {'score': 4.4785739006236724e-10, 'segment': [3.52, 4]}
# {'score': 3.8352110376393966e-10, 'segment': [1.56, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/dfb5a171b2ef400a832e5ee7583a5342_50.npy :
# {'score': 4.891470695156386e-08, 'segment': [0, 4]}
# {'score': 2.836830548247349e-09, 'segment': [3.52, 4]}
# {'score': 1.5421730559239677e-09, 'segment': [2.6, 4]}
# {'score': 1.2980019096401541e-10, 'segment': [2.72, 4]}
# {'score': 9.426513736254805e-11, 'segment': [0, 3.6]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/dfb5a171b2ef400a832e5ee7583a5342_39.npy :
# {'score': 8.364191330656467e-07, 'segment': [0, 4]}
# {'score': 6.997205592718103e-11, 'segment': [0, 3.0]}
# {'score': 8.810585074014998e-12, 'segment': [3.92, 4]}
# {'score': 4.968186018833309e-12, 'segment': [3.84, 4]}
# {'score': 4.366500078788098e-12, 'segment': [0, 2.96]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b4b7d4cc49ac4e1eb62d64c6a7d2c477_84.npy :
# {'score': 3.3757385153876385e-06, 'segment': [0, 4]}
# {'score': 1.1920756293193335e-07, 'segment': [2.36, 4]}
# {'score': 7.689259007293003e-08, 'segment': [2.36, 2.4]}
# {'score': 7.318415384816035e-08, 'segment': [2.4, 2.44]}
# {'score': 4.02831616952426e-08, 'segment': [0, 2.44]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/708697e09925421e80f28b0ddb6e69fd_62.npy :
# {'score': 3.092126803494466e-07, 'segment': [0, 4]}
# {'score': 6.317804057687226e-10, 'segment': [2.04, 4]}
# {'score': 6.868902668877297e-11, 'segment': [1.16, 4]}
# {'score': 3.351490629810839e-11, 'segment': [2.0, 4]}
# {'score': 2.764904104279875e-11, 'segment': [0, 2.92]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5192c733730446bfba0c0f2fe722e847_11.npy :
# {'score': 0.0015385393053293228, 'segment': [2.0, 4]}
# {'score': 0.0001517432872560624, 'segment': [1.68, 4]}
# {'score': 2.221179412292968e-05, 'segment': [2.04, 4]}
# {'score': 1.5094802620296832e-05, 'segment': [0, 4]}
# {'score': 9.165167284663767e-06, 'segment': [3.8000000000000003, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/cffb89402d024a76a9a9d1f21db751af_56.npy :
# {'score': 9.19133866239541e-11, 'segment': [0, 4]}
# {'score': 1.6663871617219467e-13, 'segment': [0, 0.04]}
# {'score': 1.3545979930199709e-13, 'segment': [3.96, 4]}
# {'score': 4.3813550129059584e-17, 'segment': [3.36, 4]}
# {'score': 1.8482295305035786e-17, 'segment': [2.72, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1841993a73504e9e8624b728133b81ff_77.npy :
# {'score': 0.00100634153932333, 'segment': [0, 4]}
# {'score': 2.7901009161723778e-05, 'segment': [3.12, 4]}
# {'score': 1.525307925476227e-05, 'segment': [2.12, 4]}
# {'score': 2.1879718588024843e-06, 'segment': [0.88, 4]}
# {'score': 1.1045973926989028e-06, 'segment': [2.16, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/548b2b16ce4b46938f1e7507d664456a_5.npy :
# {'score': 0.7061539888381958, 'segment': [3.0, 3.48]}
# {'score': 0.5373272895812988, 'segment': [1.8, 2.52]}
# {'score': 0.4611712694168091, 'segment': [1.04, 2.52]}
# {'score': 0.45039334893226624, 'segment': [2.7600000000000002, 3.4]}
# {'score': 0.3608807921409607, 'segment': [1.44, 2.44]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/258b0fe4dc8643b1af032818f592d4ab_41.npy :
# {'score': 4.2221859342106427e-10, 'segment': [0, 4]}
# {'score': 2.276386544541875e-12, 'segment': [1.92, 4]}
# {'score': 1.7318360287510437e-12, 'segment': [2.12, 2.16]}
# {'score': 1.7046133385031914e-12, 'segment': [0, 2.16]}
# {'score': 5.311558484710766e-13, 'segment': [0, 0.2]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/057f73114d1d4fac9bcf3618d511e9b5_63.npy :
# {'score': 1.1480319805912131e-08, 'segment': [0, 4]}
# {'score': 4.2604864081141613e-10, 'segment': [3.2, 4]}
# {'score': 8.700078808009842e-11, 'segment': [2.88, 4]}
# {'score': 7.471680218973376e-11, 'segment': [1.48, 4]}
# {'score': 1.8790621379845263e-11, 'segment': [3.48, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/572b44d2723642428b60fac24416a727_2.npy :
# {'score': 0.3058632016181946, 'segment': [2.16, 3.3200000000000003]}
# {'score': 0.274554044008255, 'segment': [2.08, 2.36]}
# {'score': 0.2541525959968567, 'segment': [2.68, 3.3200000000000003]}
# {'score': 0.12847523391246796, 'segment': [2.16, 4]}
# {'score': 0.11634942889213562, 'segment': [2.16, 2.44]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/b117bb687e394f1cabe5c7378992e512_32.npy :
# {'score': 3.6929141060682014e-05, 'segment': [0, 4]}
# {'score': 2.601057076390134e-06, 'segment': [1.16, 1.2]}
# {'score': 1.3390521189649007e-06, 'segment': [1.2, 1.24]}
# {'score': 7.230152618831198e-07, 'segment': [1.16, 1.24]}
# {'score': 3.2308403774550243e-07, 'segment': [1.12, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/8515e5a9e8764f1db6b617666bba4166_15.npy :
# {'score': 4.4686598243970366e-07, 'segment': [0, 4]}
# {'score': 1.6241335742961382e-07, 'segment': [2.36, 4]}
# {'score': 5.3399016763933105e-08, 'segment': [3.7600000000000002, 4]}
# {'score': 2.602519266758918e-08, 'segment': [3.2, 4]}
# {'score': 6.580113909740799e-09, 'segment': [3.8000000000000003, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f13db99292654cb9a0972991f5a04e22_37.npy :
# {'score': 2.9553518743341556e-08, 'segment': [0, 4]}
# {'score': 1.7908595717486264e-09, 'segment': [0.84, 0.88]}
# {'score': 1.0772277514448092e-09, 'segment': [0.88, 0.92]}
# {'score': 4.867714009648694e-10, 'segment': [0.8, 0.84]}
# {'score': 4.147949761446057e-10, 'segment': [0, 2.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/176f895bbe534b319d8b5df4fc843f15_14.npy :
# {'score': 0.06119932234287262, 'segment': [3.0, 4]}
# {'score': 0.05791066586971283, 'segment': [1.92, 4]}
# {'score': 0.04493490606546402, 'segment': [3.56, 4]}
# {'score': 0.00835496168152375, 'segment': [2.32, 4]}
# {'score': 0.0021796120575835755, 'segment': [3.6, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/f9b1c88c3c7f4a3f8023d8b8e2031ffb_84.npy :
# {'score': 2.47491061600158e-05, 'segment': [3.24, 4]}
# {'score': 7.0741511990490835e-06, 'segment': [0, 4]}
# {'score': 2.4976970672140434e-06, 'segment': [3.2800000000000002, 4]}
# {'score': 2.6888014478082795e-07, 'segment': [3.48, 4]}
# {'score': 8.560119299672888e-08, 'segment': [3.2, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/708697e09925421e80f28b0ddb6e69fd_10.npy :
# {'score': 5.135185574545176e-07, 'segment': [0, 4]}
# {'score': 1.930753416140651e-11, 'segment': [0, 3.92]}
# {'score': 1.6045565917610638e-11, 'segment': [1.2, 4]}
# {'score': 6.91072416306171e-12, 'segment': [2.36, 4]}
# {'score': 6.28837953930983e-12, 'segment': [0, 2.84]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1543002a31f440fb9548da584e713784_21.npy :
# {'score': 4.513479780143825e-06, 'segment': [0, 4]}
# {'score': 1.6039643924159463e-06, 'segment': [3.08, 4]}
# {'score': 1.225765799972578e-07, 'segment': [0, 3.6]}
# {'score': 5.8607721342696095e-08, 'segment': [3.44, 4]}
# {'score': 4.4719641323354153e-08, 'segment': [3.44, 3.64]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/d25ab25a350842a1b8e2e1695c244299_83.npy :
# {'score': 0.0003175284946337342, 'segment': [3.4, 4]}
# {'score': 0.00015564128989353776, 'segment': [3.68, 4]}
# {'score': 4.616708974936046e-05, 'segment': [0, 4]}
# {'score': 3.249715111290194e-05, 'segment': [3.36, 4]}
# {'score': 1.8923740369768617e-05, 'segment': [3.64, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/5afb37f7f6e24687bacd002a23101a0a_65.npy :
# {'score': 9.447823856589821e-08, 'segment': [0, 4]}
# {'score': 6.129873691973486e-11, 'segment': [1.08, 4]}
# {'score': 3.969099354739214e-11, 'segment': [3.96, 4]}
# {'score': 5.166772078587419e-12, 'segment': [1.04, 4]}
# {'score': 5.068433520105664e-12, 'segment': [3.3200000000000003, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/2f51b9d79570479988a1516a342483bf_79.npy :
# {'score': 0.42077502608299255, 'segment': [0, 0.72]}
# {'score': 0.19559027254581451, 'segment': [0.04, 0.48]}
# {'score': 0.08937250822782516, 'segment': [0, 0.28]}
# {'score': 0.0698731621109651, 'segment': [0.08, 0.96]}
# {'score': 0.034495338797569275, 'segment': [0, 0.16]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/7a7d32b8c96c42569c103d7b7775f3c1_23.npy :
# {'score': 9.088681508728769e-06, 'segment': [0, 0.36]}
# {'score': 7.615342383360257e-06, 'segment': [0, 0.72]}
# {'score': 1.147597804326991e-06, 'segment': [0, 0.32]}
# {'score': 5.777389446848247e-07, 'segment': [0, 4]}
# {'score': 4.829153359284434e-07, 'segment': [0, 0.76]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/42305a62416a4697962a93f935d968f4_33.npy :
# {'score': 1.316726638833643e-07, 'segment': [0, 4]}
# {'score': 2.6045997358892237e-08, 'segment': [3.96, 4]}
# {'score': 3.821692295957746e-09, 'segment': [2.64, 4]}
# {'score': 1.3190883940694675e-09, 'segment': [3.68, 4]}
# {'score': 7.465605911249895e-10, 'segment': [3.3200000000000003, 4]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/057f73114d1d4fac9bcf3618d511e9b5_82.npy :
# {'score': 1.2445402930438831e-08, 'segment': [0, 4]}
# {'score': 1.3561607392631458e-10, 'segment': [1.08, 4]}
# {'score': 1.05206120531478e-11, 'segment': [0.92, 4]}
# {'score': 9.660391410426517e-12, 'segment': [1.92, 4]}
# {'score': 6.556617661995778e-12, 'segment': [0, 3.56]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/1543002a31f440fb9548da584e713784_14.npy :
# {'score': 0.7900081276893616, 'segment': [0, 0.6]}
# {'score': 0.7523949146270752, 'segment': [1.08, 1.84]}
# {'score': 0.568285346031189, 'segment': [2.32, 2.88]}
# {'score': 0.4454319179058075, 'segment': [0.92, 1.6400000000000001]}
# {'score': 0.3145444095134735, 'segment': [0.08, 0.44]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/dfb5a171b2ef400a832e5ee7583a5342_18.npy :
# {'score': 1.50128357745416e-06, 'segment': [0, 4]}
# {'score': 1.4170534745616692e-09, 'segment': [0, 2.08]}
# {'score': 9.57134704826501e-10, 'segment': [0, 0.92]}
# {'score': 8.995640343734124e-10, 'segment': [0, 0.56]}
# {'score': 7.838749649380361e-10, 'segment': [0, 1.52]}
# Current video file: /home/aistudio/data/Features_competition_test_B/npy/25d45c48dfa341e694ac0927137f7edc_79.npy :

# %% [markdown]
# 上面程序输出的json文件是分割后的预测结果，还需要将这些文件组合到一起。执行以下脚本：

# %%
import os
import json
import glob

json_path = "/home/aistudio/data/Features_competition_test_B/npy/"
json_files = glob.glob(os.path.join(json_path, '*_*.json'))

# %%
len(json_files)
# Out:
# 8280

# %%
submit_dic = {"version": None,
              "results": {},
              "external_data": {}
              }
results = submit_dic['results']
for json_file in json_files:
    j = json.load(open(json_file, 'r'))
    old_video_name = list(j.keys())[0]
    video_name = list(j.keys())[0].split('/')[-1].split('.')[0]
    video_name, video_no = video_name.split('_')
    start_id = int(video_no) * 4
    if len(j[old_video_name]) == 0:
        continue
    for i, top in enumerate(j[old_video_name]):
        if video_name in results.keys():
            results[video_name].append({'score': round(top['score'], 2),
                                        'segment': [round(top['segment'][0] + start_id, 2), round(top['segment'][1] + start_id, 2)]})
        else:
            results[video_name] = [{'score':round(top['score'], 2),
                                        'segment': [round(top['segment'][0] + start_id, 2), round(top['segment'][1] + start_id, 2)]}]

json.dump(submit_dic, open('/home/aistudio/submission.json', 'w', encoding='utf-8'))

# %% [markdown]
# 最后会在用户目录生成submission.json文件，压缩后下载提交即可。

# %%
# %cd /home/aistudio/
# !zip submission.zip submission.json
# Out:
# /home/aistudio
# updating: submission.json (deflated 91%)

# %% [raw]
# ### ### 优化思路
#
# 1. 可以增加训练的epoch数量30。
# 2. 可以调整学习率策略，比如warmup和余弦退火等。
# 飞桨可以提供免费算力，大力支持
